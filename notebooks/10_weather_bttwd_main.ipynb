# %% [markdown]
# weatherAUS 数据集 BT-TWD 可行性实验
#
# 本 notebook 按步骤运行：加载配置 → 读取数据 → 预处理 → 桶树划分 → 基线与 BTTWD k 折实验 → 桶级分析。

# %%
# 步骤0：环境与路径设置
import os, sys
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['Microsoft YaHei']
plt.rcParams['axes.unicode_minus'] = False

# 将项目根目录加入路径，便于导入 bttwdlib
root_path = os.path.abspath(os.path.join(os.getcwd(), '..'))
if root_path not in sys.path:
    sys.path.append(root_path)

from bttwdlib import (
    load_yaml_cfg,
    show_cfg,
    load_dataset,
    prepare_features_and_labels,
    BucketTree,
    run_kfold_experiments,
    log_info,
    set_global_seed,
)

cfg_path = Path(root_path) / "configs" / "weatherAUS_bttwd.yaml"
cfg = load_yaml_cfg(cfg_path)
set_global_seed(cfg.get('SEED', {}).get('global_seed', 42))
log_info('【步骤0摘要】环境准备完毕，路径与随机种子已设置。')
# Out:
# 【INFO】【2025-12-15 19:12:26】【配置加载】已读取 e:\yan\组\三支决策\机器学习\BT_TWD\configs\weatherAUS_bttwd.yaml
# 【INFO】【2025-12-15 19:12:31】【步骤0摘要】环境准备完毕，路径与随机种子已设置。

# %%
# 步骤1：加载配置
show_cfg(cfg)
log_info('【步骤1摘要】配置文件加载完成，关键参数检查通过。')
# Out:
# 【INFO】【2025-12-15 19:12:31】【配置-数据】数据集=weatherAUS, k折=5, 目标列=RainTomorrow, 正类="Yes"
# 【INFO】【2025-12-15 19:12:31】【配置-BTTWD】阈值模式=bucket_wise, 全局模型=xgb, 桶内模型=none, 后验估计器(兼容字段)=logreg
# 【INFO】【2025-12-15 19:12:31】【配置-基线】LogReg启用=True, RandomForest启用=True, KNN启用=True, XGBoost启用=True
# 【INFO】【2025-12-15 19:12:31】【步骤1摘要】配置文件加载完成，关键参数检查通过。

# %%
# 步骤2：加载原始数据
df_raw, target_col_model = load_dataset(cfg)  # 这里返回的是用于建模的标签列，例如 "label"

display(df_raw.head())
print("用于建模的标签列:", target_col_model)

# 1）画 0/1 标签（流失/未流失）的比例
class_counts = df_raw[target_col_model].value_counts(normalize=True)
ax = class_counts.plot(kind='bar', title='流失 vs 未流失比例')
plt.ylabel('比例')

fig_path = os.path.join(root_path, cfg['OUTPUT']['figs_dir'], 'class_distribution.png')
os.makedirs(os.path.dirname(fig_path), exist_ok=True)
plt.savefig(fig_path, bbox_inches='tight')
plt.close()

# 2）如果想看原始标签列的分布，可以另外单独分析：
raw_target_col = cfg['DATA']['target_col']  # 这里是原始标签列
print("原始目标列:", raw_target_col)
print(df_raw[raw_target_col].describe())

log_info('【步骤2摘要】Telco Churn 原始数据加载与基本统计完成。')
# Out:
# 【INFO】【2025-12-15 19:12:31】【数据加载】文本表格 ..\data\weather\weatherAUS.csv 已读取，样本数=145460，列数=23
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[3], line 2
#       1 # 步骤2：加载原始数据
# ----> 2 df_raw, target_col_model = load_dataset(cfg)  # 这里返回的是用于建模的标签列，例如 "label"
#       4 display(df_raw.head())
#       5 print("用于建模的标签列:", target_col_model)
#
# File e:\yan\组\三支决策\机器学习\BT_TWD\bttwdlib\data_loader.py:335, in load_dataset(cfg)
#     333 negative_label = data_cfg.get("negative_label")
#     334 if not target_mapped and positive_label is not None and target_col in df.columns:
# --> 335     df = _map_target_with_config(df, target_col, data_cfg)
#     336     target_mapped = True
#     338 if positive_label is not None and target_col in df.columns:
#
# File e:\yan\组\三支决策\机器学习\BT_TWD\bttwdlib\data_loader.py:56, in _map_target_with_config(df, target_col, data_cfg, extra_mapping)
#      53     df[target_col] = df[target_col].fillna(0)
#      54 after = len(df)
# ---> 56 df[target_col] = df[target_col].astype(int)
#      58 log_info(
#      59     f"【数据加载】标签列 {target_col} 已处理完成："
#      60     f"dropna_target={dropna_target}, "
#    (...)
#      63     f"正类比例={df[target_col].mean():.2%}"
#      64 )
#      66 return df
#
# File d:\Anaconda3\Lib\site-packages\pandas\core\generic.py:6665, in NDFrame.astype(self, dtype, copy, errors)
#    6659     results = [
#    6660         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6661     ]
#    6663 else:
#    6664     # else, only a single dtype is given
# -> 6665     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6666     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6667     return res.__finalize__(self, method="astype")
#
# File d:\Anaconda3\Lib\site-packages\pandas\core\internals\managers.py:449, in BaseBlockManager.astype(self, dtype, copy, errors)
#     446 elif using_copy_on_write():
#     447     copy = False
# --> 449 return self.apply(
#     450     "astype",
#     451     dtype=dtype,
#     452     copy=copy,
#     453     errors=errors,
#     454     using_cow=using_copy_on_write(),
#     455 )
#
# File d:\Anaconda3\Lib\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File d:\Anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:784, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     781         raise ValueError("Can not squeeze with more than one column.")
#     782     values = values[0, :]  # type: ignore[call-overload]
# --> 784 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     786 new_values = maybe_coerce_values(new_values)
#     788 refs = None
#
# File d:\Anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File d:\Anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File d:\Anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:101, in _astype_nansafe(arr, dtype, copy, skipna)
#      96     return lib.ensure_string_array(
#      97         arr, skipna=skipna, convert_na_value=False
#      98     ).reshape(shape)
#     100 elif np.issubdtype(arr.dtype, np.floating) and dtype.kind in "iu":
# --> 101     return _astype_float_to_int_nansafe(arr, dtype, copy)
#     103 elif arr.dtype == object:
#     104     # if we have a datetime/timedelta array of objects
#     105     # then coerce to datetime64[ns] and use DatetimeArray.astype
#     107     if lib.is_np_dtype(dtype, "M"):
#
# File d:\Anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:145, in _astype_float_to_int_nansafe(values, dtype, copy)
#     141 """
#     142 astype with a check preventing converting NaN to an meaningless integer value.
#     143 """
#     144 if not np.isfinite(values).all():
# --> 145     raise IntCastingNaNError(
#     146         "Cannot convert non-finite values (NA or inf) to integer"
#     147     )
#     148 if dtype.kind == "u":
#     149     # GH#45151
#     150     if not (values >= 0).all():
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer

# %%
# 步骤3：预处理与特征工程
X, y, meta = prepare_features_and_labels(df_raw, cfg)
log_info(f'【预处理】编码特征维度={X.shape[1]}，样本数={X.shape[0]}')
log_info(f"【步骤3摘要】特征预处理完成：连续={len(meta['continuous_cols'])}，类别={len(meta['categorical_cols'])}，编码维度={X.shape[1]}。")
# Out:
# 【INFO】【2025-12-12 21:27:23】【预处理】连续特征=7个，类别特征=9个
# 【INFO】【2025-12-12 21:27:23】【预处理】编码后维度=45
# 【INFO】【2025-12-12 21:27:23】【预处理】编码特征维度=45，样本数=25000
# 【INFO】【2025-12-12 21:27:23】【步骤3摘要】特征预处理完成：连续=7，类别=9，编码维度=45。

# %%
# 步骤4：构建桶树并检查划分
feature_cols_for_bucket = [c for c in df_raw.columns if c != target_col_model]

bucket_tree = BucketTree(
    cfg['BTTWD']['bucket_levels'],
    feature_names=feature_cols_for_bucket
)

bucket_ids_full = bucket_tree.assign_buckets(df_raw[feature_cols_for_bucket])

bucket_df = bucket_ids_full.value_counts().reset_index()
bucket_df.columns = ['bucket_id', 'count']

bucket_df['pos_rate'] = (
    df_raw.groupby(bucket_ids_full)[target_col_model]
    .apply(lambda s: (s == 1).mean())
    .values
)
display(bucket_df.head())
bucket_df.set_index('bucket_id')['count'].plot(kind='bar', figsize=(12,4), title='桶样本数分布')
fig_bucket = os.path.join(root_path, cfg['OUTPUT']['figs_dir'], 'bucket_metrics_bar.png')
plt.savefig(fig_bucket, bbox_inches='tight')
plt.close()
log_info(f'【步骤4摘要】桶树划分完成，共有 {bucket_ids_full.nunique()} 个叶子桶。')
# Out:
# 【INFO】【2025-12-12 21:27:23】【桶树】已为样本生成桶ID，共 45 个组合
#                                            bucket_id  count  pos_rate
# 0  L1_age=young_old|L2_medical_specialty=Others|L...   3671  0.333333
# 1  L1_age=young_old|L2_medical_specialty=Others|L...   2874  0.440860
# 2  L1_age=mid_age|L2_medical_specialty=Others|L3_...   2148  0.403636
# 3  L1_age=mid_age|L2_medical_specialty=Others|L3_...   1464  0.471429
# 4  L1_age=oldest|L2_medical_specialty=Others|L3_t...   1315  0.471299
# 【INFO】【2025-12-12 21:27:24】【步骤4摘要】桶树划分完成，共有 45 个叶子桶。

# %%
# 步骤5：运行基线模型 k 折实验
# 基线部分在 run_kfold_experiments 内统一调度
log_info('【步骤5】基线模型将在整体交叉验证中一并运行。')
log_info('【步骤5摘要】基线模型性能将作为后续对比基准。')
# Out:
# 【INFO】【2025-12-12 21:27:24】【步骤5】基线模型将在整体交叉验证中一并运行。
# 【INFO】【2025-12-12 21:27:24】【步骤5摘要】基线模型性能将作为后续对比基准。

# %%
import numpy as np
import pandas as pd

print("y 全局标签分布：", np.unique(y, return_counts=True))

print("原始标签列分布：")
print(df_raw[cfg['DATA']['target_col']].value_counts())
# Out:
# y 全局标签分布： (array([0, 1]), array([13246, 11754], dtype=int64))
# 原始标签列分布：
# readmitted
# 0    13246
# 1    11754
# Name: count, dtype: int64

# %%
# 步骤6：运行 BTTWD k 折实验（含基线）
results = run_kfold_experiments(X, y, df_raw.drop(columns=[cfg['DATA']['target_col']]), cfg)
summary_df = pd.read_csv(os.path.join(root_path, cfg['OUTPUT']['results_dir'], 'metrics_kfold_summary.csv'))
display(summary_df)
summary_df.plot(x='model', kind='bar', figsize=(8,4), title='模型指标对比')
fig_compare = os.path.join(root_path, cfg['OUTPUT']['figs_dir'], 'metrics_compare.png')
plt.savefig(fig_compare, bbox_inches='tight')
plt.close()
log_info('【步骤6摘要】BTTWD 与基线的 k 折结果已生成并保存。')
# Out:
# 【INFO】【2025-12-12 21:27:24】【基线-LogReg】使用决策阈值=0.200（fixed 模式）
# e:\yan\组\三支决策\机器学习\BT_TWD\bttwdlib\baselines.py:103: RuntimeWarning: Mean of empty slice
#   summary[f"{col}_mean"] = float(np.nanmean(arr))
# d:\Anaconda3\Lib\site-packages\numpy\lib\nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# 【INFO】【2025-12-12 21:27:25】【基线-LogReg】整体指标：AUC_mean=0.646, AUC_std=0.003, BAC_mean=0.501, BAC_std=0.000, BND_ratio_mean=0.000, BND_ratio_std=0.000, F1_mean=0.640, F1_std=0.000, Kappa_mean=0.001, Kappa_std=0.001, MCC_mean=0.018, MCC_std=0.010, POS_Coverage_mean=nan, POS_Coverage_std=nan, Precision_mean=0.470, Precision_std=0.000, Recall_mean=1.000, Recall_std=0.000, Regret_mean=0.529, Regret_std=0.000
# 【INFO】【2025-12-12 21:27:25】【基线-RF】使用决策阈值=0.200（fixed 模式）
# e:\yan\组\三支决策\机器学习\BT_TWD\bttwdlib\baselines.py:103: RuntimeWarning: Mean of empty slice
#   summary[f"{col}_mean"] = float(np.nanmean(arr))
# d:\Anaconda3\Lib\site-packages\numpy\lib\nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# 【INFO】【2025-12-12 21:27:31】【基线-RF】整体指标：AUC_mean=0.639, AUC_std=0.005, BAC_mean=0.508, BAC_std=0.000, BND_ratio_mean=0.000, BND_ratio_std=0.000, F1_mean=0.641, F1_std=0.001, Kappa_mean=0.015, Kappa_std=0.001, MCC_mean=0.057, MCC_std=0.004, POS_Coverage_mean=nan, POS_Coverage_std=nan, Precision_mean=0.474, Precision_std=0.000, Recall_mean=0.989, Recall_std=0.002, Regret_mean=0.531, Regret_std=0.002
# 【INFO】【2025-12-12 21:27:31】【基线-KNN】使用决策阈值=0.200（fixed 模式）
# e:\yan\组\三支决策\机器学习\BT_TWD\bttwdlib\baselines.py:103: RuntimeWarning: Mean of empty slice
#   summary[f"{col}_mean"] = float(np.nanmean(arr))
# d:\Anaconda3\Lib\site-packages\numpy\lib\nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# C:\Users\xzq20.HUANLI\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:158: UserWarning: [21:27:33] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 【INFO】【2025-12-12 21:27:33】【基线-KNN】整体指标：AUC_mean=0.585, AUC_std=0.003, BAC_mean=0.536, BAC_std=0.003, BND_ratio_mean=0.000, BND_ratio_std=0.000, F1_mean=0.622, F1_std=0.002, Kappa_mean=0.069, Kappa_std=0.005, MCC_mean=0.091, MCC_std=0.007, POS_Coverage_mean=nan, POS_Coverage_std=nan, Precision_mean=0.492, Precision_std=0.002, Recall_mean=0.843, Recall_std=0.005, Regret_mean=0.630, Regret_std=0.006
# 【INFO】【2025-12-12 21:27:33】【基线-XGB】使用决策阈值=0.200（fixed 模式）
# C:\Users\xzq20.HUANLI\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:158: UserWarning: [21:27:34] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\xzq20.HUANLI\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:158: UserWarning: [21:27:34] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\xzq20.HUANLI\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:158: UserWarning: [21:27:34] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\xzq20.HUANLI\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:158: UserWarning: [21:27:34] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# e:\yan\组\三支决策\机器学习\BT_TWD\bttwdlib\baselines.py:103: RuntimeWarning: Mean of empty slice
#   summary[f"{col}_mean"] = float(np.nanmean(arr))
# d:\Anaconda3\Lib\site-packages\numpy\lib\nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# C:\Users\xzq20.HUANLI\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:158: UserWarning: [21:27:35] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 【INFO】【2025-12-12 21:27:35】【基线-XGB】整体指标：AUC_mean=0.656, AUC_std=0.005, BAC_mean=0.511, BAC_std=0.002, BND_ratio_mean=0.000, BND_ratio_std=0.000, F1_mean=0.642, F1_std=0.001, Kappa_mean=0.022, Kappa_std=0.003, MCC_mean=0.073, MCC_std=0.009, POS_Coverage_mean=nan, POS_Coverage_std=nan, Precision_mean=0.476, Precision_std=0.001, Recall_mean=0.987, Recall_std=0.001, Regret_mean=0.529, Regret_std=0.002
# 【INFO】【2025-12-12 21:27:35】【K折实验】正在执行第 1/5 折...
# 【INFO】【2025-12-12 21:27:35】[BT] 使用桶评分配置：mode=f1_regret_bnd, f1_weight=1.0, regret_weight=1.0, bnd_weight=0.5
# 【INFO】【2025-12-12 21:27:35】【BTTWD】全局模型训练完成，用于兜底预测
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=ROOT，level=0，parent_id=ROOT，split_name=ROOT，split_type=ROOT，split_rule="all"，n_samples=20000
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=mid_age，level=1，parent_id=ROOT，split_name=L1_age，split_type=category_group，split_rule="mid_age"，n_samples=5571
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=oldest，level=1，parent_id=ROOT，split_name=L1_age，split_type=category_group，split_rule="oldest"，n_samples=4205
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=young_old，level=1，parent_id=ROOT，split_name=L1_age，split_type=category_group，split_rule="young_old"，n_samples=10224
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=mid_age|L2_medical_specialty=Cardio，level=2，parent_id=L1_age=mid_age，split_name=L2_medical_specialty，split_type=category_group，split_rule="Cardio"，n_samples=323
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=mid_age|L2_medical_specialty=InternalMed，level=2，parent_id=L1_age=mid_age，split_name=L2_medical_specialty，split_type=category_group，split_rule="InternalMed"，n_samples=776
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=mid_age|L2_medical_specialty=Others，level=2，parent_id=L1_age=mid_age，split_name=L2_medical_specialty，split_type=category_group，split_rule="Others"，n_samples=3313
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=mid_age|L2_medical_specialty=PrimaryCare，level=2，parent_id=L1_age=mid_age，split_name=L2_medical_specialty，split_type=category_group，split_rule="PrimaryCare"，n_samples=470
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=mid_age|L2_medical_specialty=Surgery_Trauma，level=2，parent_id=L1_age=mid_age，split_name=L2_medical_specialty，split_type=category_group，split_rule="Surgery_Trauma"，n_samples=689
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=oldest|L2_medical_specialty=Cardio，level=2，parent_id=L1_age=oldest，split_name=L2_medical_specialty，split_type=category_group，split_rule="Cardio"，n_samples=167
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=oldest|L2_medical_specialty=InternalMed，level=2，parent_id=L1_age=oldest，split_name=L2_medical_specialty，split_type=category_group，split_rule="InternalMed"，n_samples=668
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=oldest|L2_medical_specialty=Others，level=2，parent_id=L1_age=oldest，split_name=L2_medical_specialty，split_type=category_group，split_rule="Others"，n_samples=2475
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=oldest|L2_medical_specialty=PrimaryCare，level=2，parent_id=L1_age=oldest，split_name=L2_medical_specialty，split_type=category_group，split_rule="PrimaryCare"，n_samples=339
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=oldest|L2_medical_specialty=Surgery_Trauma，level=2，parent_id=L1_age=oldest，split_name=L2_medical_specialty，split_type=category_group，split_rule="Surgery_Trauma"，n_samples=556
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=young_old|L2_medical_specialty=Cardio，level=2，parent_id=L1_age=young_old，split_name=L2_medical_specialty，split_type=category_group，split_rule="Cardio"，n_samples=661
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=young_old|L2_medical_specialty=InternalMed，level=2，parent_id=L1_age=young_old，split_name=L2_medical_specialty，split_type=category_group，split_rule="InternalMed"，n_samples=1419
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=young_old|L2_medical_specialty=Others，level=2，parent_id=L1_age=young_old，split_name=L2_medical_specialty，split_type=category_group，split_rule="Others"，n_samples=6225
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=young_old|L2_medical_specialty=PrimaryCare，level=2，parent_id=L1_age=young_old，split_name=L2_medical_specialty，split_type=category_group，split_rule="PrimaryCare"，n_samples=715
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=young_old|L2_medical_specialty=Surgery_Trauma，level=2，parent_id=L1_age=young_old，split_name=L2_medical_specialty，split_type=category_group，split_rule="Surgery_Trauma"，n_samples=1204
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=mid_age|L2_medical_specialty=Cardio|L3_time_in_hospital=short_stay，level=3，parent_id=L1_age=mid_age|L2_medical_specialty=Cardio，split_name=L3_time_in_hospital，split_type=numeric_bin，split_rule="short_stay"，n_samples=216
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=mid_age|L2_medical_specialty=Cardio|L3_time_in_hospital=others，level=3，parent_id=L1_age=mid_age|L2_medical_specialty=Cardio，split_name=L3_time_in_hospital，split_type=numeric_bin，split_rule="others"，n_samples=107
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=mid_age|L2_medical_specialty=InternalMed|L3_time_in_hospital=long_stay，level=3，parent_id=L1_age=mid_age|L2_medical_specialty=InternalMed，split_name=L3_time_in_hospital，split_type=numeric_bin，split_rule="long_stay"，n_samples=107
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=mid_age|L2_medical_specialty=InternalMed|L3_time_in_hospital=mid_stay，level=3，parent_id=L1_age=mid_age|L2_medical_specialty=InternalMed，split_name=L3_time_in_hospital，split_type=numeric_bin，split_rule="mid_stay"，n_samples=258
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=mid_age|L2_medical_specialty=InternalMed|L3_time_in_hospital=short_stay，level=3，parent_id=L1_age=mid_age|L2_medical_specialty=InternalMed，split_name=L3_time_in_hospital，split_type=numeric_bin，split_rule="short_stay"，n_samples=411
# [INFO][BT][2025-12-12 21:27:35] 桶 bucket_id=L1_age=mid_age|L2_medical_specialty=Others 命中 stop_split_labels=['OTHER', 'OTHERS', 'OTHER_CARRIER', 'OTHER_DEST', 'OTHER_ORIGIN', 'Other', 'OtherType', 'Others', 'no_internet', 'other', 'others']，不再细分
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=mid_age|L2_medical_specialty=PrimaryCare|L3_time_in_hospital=mid_stay，level=3，parent_id=L1_age=mid_age|L2_medical_specialty=PrimaryCare，split_name=L3_time_in_hospital，split_type=numeric_bin，split_rule="mid_stay"，n_samples=159
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=mid_age|L2_medical_specialty=PrimaryCare|L3_time_in_hospital=short_stay，level=3，parent_id=L1_age=mid_age|L2_medical_specialty=PrimaryCare，split_name=L3_time_in_hospital，split_type=numeric_bin，split_rule="short_stay"，n_samples=262
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=mid_age|L2_medical_specialty=PrimaryCare|L3_time_in_hospital=others，level=3，parent_id=L1_age=mid_age|L2_medical_specialty=PrimaryCare，split_name=L3_time_in_hospital，split_type=numeric_bin，split_rule="others"，n_samples=49
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=mid_age|L2_medical_specialty=Surgery_Trauma|L3_time_in_hospital=mid_stay，level=3，parent_id=L1_age=mid_age|L2_medical_specialty=Surgery_Trauma，split_name=L3_time_in_hospital，split_type=numeric_bin，split_rule="mid_stay"，n_samples=241
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=mid_age|L2_medical_specialty=Surgery_Trauma|L3_time_in_hospital=short_stay，level=3，parent_id=L1_age=mid_age|L2_medical_specialty=Surgery_Trauma，split_name=L3_time_in_hospital，split_type=numeric_bin，split_rule="short_stay"，n_samples=375
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=mid_age|L2_medical_specialty=Surgery_Trauma|L3_time_in_hospital=others，level=3，parent_id=L1_age=mid_age|L2_medical_specialty=Surgery_Trauma，split_name=L3_time_in_hospital，split_type=numeric_bin，split_rule="others"，n_samples=73
# [INFO][BT][2025-12-12 21:27:35] 桶 bucket_id=L1_age=oldest|L2_medical_specialty=Cardio 样本不足（n=167 < min_bucket_size=100），不再细分
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=oldest|L2_medical_specialty=InternalMed|L3_time_in_hospital=long_stay，level=3，parent_id=L1_age=oldest|L2_medical_specialty=InternalMed，split_name=L3_time_in_hospital，split_type=numeric_bin，split_rule="long_stay"，n_samples=153
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=oldest|L2_medical_specialty=InternalMed|L3_time_in_hospital=mid_stay，level=3，parent_id=L1_age=oldest|L2_medical_specialty=InternalMed，split_name=L3_time_in_hospital，split_type=numeric_bin，split_rule="mid_stay"，n_samples=289
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=oldest|L2_medical_specialty=InternalMed|L3_time_in_hospital=short_stay，level=3，parent_id=L1_age=oldest|L2_medical_specialty=InternalMed，split_name=L3_time_in_hospital，split_type=numeric_bin，split_rule="short_stay"，n_samples=226
# [INFO][BT][2025-12-12 21:27:35] 桶 bucket_id=L1_age=oldest|L2_medical_specialty=Others 命中 stop_split_labels=['OTHER', 'OTHERS', 'OTHER_CARRIER', 'OTHER_DEST', 'OTHER_ORIGIN', 'Other', 'OtherType', 'Others', 'no_internet', 'other', 'others']，不再细分
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=oldest|L2_medical_specialty=PrimaryCare|L3_time_in_hospital=mid_stay，level=3，parent_id=L1_age=oldest|L2_medical_specialty=PrimaryCare，split_name=L3_time_in_hospital，split_type=numeric_bin，split_rule="mid_stay"，n_samples=142
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=oldest|L2_medical_specialty=PrimaryCare|L3_time_in_hospital=short_stay，level=3，parent_id=L1_age=oldest|L2_medical_specialty=PrimaryCare，split_name=L3_time_in_hospital，split_type=numeric_bin，split_rule="short_stay"，n_samples=144
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=oldest|L2_medical_specialty=PrimaryCare|L3_time_in_hospital=others，level=3，parent_id=L1_age=oldest|L2_medical_specialty=PrimaryCare，split_name=L3_time_in_hospital，split_type=numeric_bin，split_rule="others"，n_samples=53
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=oldest|L2_medical_specialty=Surgery_Trauma|L3_time_in_hospital=mid_stay，level=3，parent_id=L1_age=oldest|L2_medical_specialty=Surgery_Trauma，split_name=L3_time_in_hospital，split_type=numeric_bin，split_rule="mid_stay"，n_samples=247
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=oldest|L2_medical_specialty=Surgery_Trauma|L3_time_in_hospital=short_stay，level=3，parent_id=L1_age=oldest|L2_medical_specialty=Surgery_Trauma，split_name=L3_time_in_hospital，split_type=numeric_bin，split_rule="short_stay"，n_samples=214
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=oldest|L2_medical_specialty=Surgery_Trauma|L3_time_in_hospital=others，level=3，parent_id=L1_age=oldest|L2_medical_specialty=Surgery_Trauma，split_name=L3_time_in_hospital，split_type=numeric_bin，split_rule="others"，n_samples=95
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=young_old|L2_medical_specialty=Cardio|L3_time_in_hospital=mid_stay，level=3，parent_id=L1_age=young_old|L2_medical_specialty=Cardio，split_name=L3_time_in_hospital，split_type=numeric_bin，split_rule="mid_stay"，n_samples=194
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=young_old|L2_medical_specialty=Cardio|L3_time_in_hospital=short_stay，level=3，parent_id=L1_age=young_old|L2_medical_specialty=Cardio，split_name=L3_time_in_hospital，split_type=numeric_bin，split_rule="short_stay"，n_samples=388
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=young_old|L2_medical_specialty=Cardio|L3_time_in_hospital=others，level=3，parent_id=L1_age=young_old|L2_medical_specialty=Cardio，split_name=L3_time_in_hospital，split_type=numeric_bin，split_rule="others"，n_samples=79
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=young_old|L2_medical_specialty=InternalMed|L3_time_in_hospital=long_stay，level=3，parent_id=L1_age=young_old|L2_medical_specialty=InternalMed，split_name=L3_time_in_hospital，split_type=numeric_bin，split_rule="long_stay"，n_samples=266
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=young_old|L2_medical_specialty=InternalMed|L3_time_in_hospital=mid_stay，level=3，parent_id=L1_age=young_old|L2_medical_specialty=InternalMed，split_name=L3_time_in_hospital，split_type=numeric_bin，split_rule="mid_stay"，n_samples=566
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=young_old|L2_medical_specialty=InternalMed|L3_time_in_hospital=short_stay，level=3，parent_id=L1_age=young_old|L2_medical_specialty=InternalMed，split_name=L3_time_in_hospital，split_type=numeric_bin，split_rule="short_stay"，n_samples=587
# [INFO][BT][2025-12-12 21:27:35] 桶 bucket_id=L1_age=young_old|L2_medical_specialty=Others 命中 stop_split_labels=['OTHER', 'OTHERS', 'OTHER_CARRIER', 'OTHER_DEST', 'OTHER_ORIGIN', 'Other', 'OtherType', 'Others', 'no_internet', 'other', 'others']，不再细分
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=young_old|L2_medical_specialty=PrimaryCare|L3_time_in_hospital=long_stay，level=3，parent_id=L1_age=young_old|L2_medical_specialty=PrimaryCare，split_name=L3_time_in_hospital，split_type=numeric_bin，split_rule="long_stay"，n_samples=117
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=young_old|L2_medical_specialty=PrimaryCare|L3_time_in_hospital=mid_stay，level=3，parent_id=L1_age=young_old|L2_medical_specialty=PrimaryCare，split_name=L3_time_in_hospital，split_type=numeric_bin，split_rule="mid_stay"，n_samples=267
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=young_old|L2_medical_specialty=PrimaryCare|L3_time_in_hospital=short_stay，level=3，parent_id=L1_age=young_old|L2_medical_specialty=PrimaryCare，split_name=L3_time_in_hospital，split_type=numeric_bin，split_rule="short_stay"，n_samples=331
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=young_old|L2_medical_specialty=Surgery_Trauma|L3_time_in_hospital=long_stay，level=3，parent_id=L1_age=young_old|L2_medical_specialty=Surgery_Trauma，split_name=L3_time_in_hospital，split_type=numeric_bin，split_rule="long_stay"，n_samples=220
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=young_old|L2_medical_specialty=Surgery_Trauma|L3_time_in_hospital=mid_stay，level=3，parent_id=L1_age=young_old|L2_medical_specialty=Surgery_Trauma，split_name=L3_time_in_hospital，split_type=numeric_bin，split_rule="mid_stay"，n_samples=508
# [INFO][BT][2025-12-12 21:27:35] 创建桶 bucket_id=L1_age=young_old|L2_medical_specialty=Surgery_Trauma|L3_time_in_hospital=short_stay，level=3，parent_id=L1_age=young_old|L2_medical_specialty=Surgery_Trauma，split_name=L3_time_in_hospital，split_type=numeric_bin，split_rule="short_stay"，n_samples=476
# [INFO][BT][2025-12-12 21:27:36] 桶树构建完成：总桶数=51，最大层数=3，叶子桶数=36
# 【INFO】【2025-12-12 21:27:36】【BTTWD】bucket_estimator=none：不训练桶内局部模型，仅使用全局模型概率做桶内阈值搜索
# e:\yan\组\三支决策\机器学习\BT_TWD\bttwdlib\bucket_gain.py:27: RuntimeWarning: compute_bucket_score: metric 'F1' is missing or NaN, defaulting to 0.0.
#   warnings.warn(
# e:\yan\组\三支决策\机器学习\BT_TWD\bttwdlib\bucket_gain.py:27: RuntimeWarning: compute_bucket_score: metric 'BND_ratio' is missing or NaN, defaulting to 0.0.
#   warnings.warn(
# 【INFO】【2025-12-12 21:27:37】【阈值】桶 ROOT（n_val=1198）使用本地阈值 α=0.3000, β=0.1000
# [INFO][BT][2025-12-12 21:27:37] 桶 bucket_id=ROOT level=0：
#     n_train=2799, n_val=1198,
#     BAC=0.453, F1=0.654, AUC=0.656,
#     Regret=0.513, BND_ratio=0.144, POS_coverage=0.856,
#     Score(f1_regret_bnd )=0.069
# 【INFO】【2025-12-12 21:27:37】【阈值】桶 L1_age=mid_age 标记为弱桶，阈值将回退使用 ROOT 的阈值
# [INFO][BT][2025-12-12 21:27:37] 桶 bucket_id=L1_age=mid_age level=1：
#     n_train=787, n_val=396,
#     BAC=0.381, F1=0.627, AUC=0.682,
#     Regret=0.528, BND_ratio=0.422, POS_coverage=0.525,
#     Score(f1_regret_bnd )=-0.112
# [INFO][BT][2025-12-12 21:27:37] 桶 bucket_id=L1_age=mid_age：
#     parent_id=ROOT，parent_Score=0.069, bucket_Score=-0.112,
#     Gain=-0.181, is_weak=True
# 【INFO】【2025-12-12 21:27:37】【阈值】桶 L1_age=oldest（n_val=300）使用本地阈值 α=0.2000, β=0.0000
# [INFO][BT][2025-12-12 21:27:37] 桶 bucket_id=L1_age=oldest level=1：
#     n_train=579, n_val=300,
#     BAC=0.496, F1=0.648, AUC=0.610,
#     Regret=0.520, BND_ratio=0.023, POS_coverage=0.977,
#     Score(f1_regret_bnd )=0.117
# [INFO][BT][2025-12-12 21:27:37] 桶 bucket_id=L1_age=oldest：
#     parent_id=ROOT，parent_Score=0.069, bucket_Score=0.117,
#     Gain=+0.047, is_weak=False
# 【INFO】【2025-12-12 21:27:37】【阈值】桶 L1_age=young_old（n_val=612）使用本地阈值 α=0.2000, β=0.0000
# [INFO][BT][2025-12-12 21:27:37] 桶 bucket_id=L1_age=young_old level=1：
#     n_train=1428, n_val=612,
#     BAC=0.495, F1=0.648, AUC=0.645,
#     Regret=0.520, BND_ratio=0.023, POS_coverage=0.977,
#     Score(f1_regret_bnd )=0.116
# [INFO][BT][2025-12-12 21:27:37] 桶 bucket_id=L1_age=young_old：
#     parent_id=ROOT，parent_Score=0.069, bucket_Score=0.116,
#     Gain=+0.047, is_weak=False
# 【INFO】【2025-12-12 21:27:38】【阈值】桶 L1_age=mid_age|L2_medical_specialty=Cardio（n_val=90）使用本地阈值 α=0.3000, β=0.0000
# [INFO][BT][2025-12-12 21:27:38] 桶 bucket_id=L1_age=mid_age|L2_medical_specialty=Cardio level=2：
#     n_train=113, n_val=90,
#     BAC=0.397, F1=0.608, AUC=0.633,
#     Regret=0.550, BND_ratio=0.300, POS_coverage=0.700,
#     Score(f1_regret_bnd )=-0.092
# [INFO][BT][2025-12-12 21:27:38] 桶 bucket_id=L1_age=mid_age|L2_medical_specialty=Cardio：
#     parent_id=L1_age=mid_age，parent_Score=-0.112, bucket_Score=-0.092,
#     Gain=+0.020, is_weak=False
# 【INFO】【2025-12-12 21:27:38】【阈值】桶 L1_age=mid_age|L2_medical_specialty=InternalMed 标记为弱桶，阈值将回退使用 L1_age=mid_age 的阈值
# [INFO][BT][2025-12-12 21:27:38] 桶 bucket_id=L1_age=mid_age|L2_medical_specialty=InternalMed level=2：
#     n_train=170, n_val=127,
#     BAC=0.320, F1=0.609, AUC=0.678,
#     Regret=0.535, BND_ratio=0.528, POS_coverage=0.465,
#     Score(f1_regret_bnd )=-0.191
# [INFO][BT][2025-12-12 21:27:38] 桶 bucket_id=L1_age=mid_age|L2_medical_specialty=InternalMed：
#     parent_id=L1_age=mid_age，parent_Score=-0.112, bucket_Score=-0.191,
#     Gain=-0.079, is_weak=True
# 【INFO】【2025-12-12 21:27:38】【阈值】桶 L1_age=mid_age|L2_medical_specialty=Others（n_val=962）使用本地阈值 α=0.4000, β=0.2000
# [INFO][BT][2025-12-12 21:27:38] 桶 bucket_id=L1_age=mid_age|L2_medical_specialty=Others level=2：
#     n_train=2351, n_val=962,
#     BAC=0.399, F1=0.616, AUC=0.688,
#     Regret=0.534, BND_ratio=0.369, POS_coverage=0.571,
#     Score(f1_regret_bnd )=-0.103
# [INFO][BT][2025-12-12 21:27:38] 桶 bucket_id=L1_age=mid_age|L2_medical_specialty=Others：
#     parent_id=L1_age=mid_age，parent_Score=-0.112, bucket_Score=-0.103,
#     Gain=+0.009, is_weak=False
# 【INFO】【2025-12-12 21:27:38】【阈值】桶 L1_age=mid_age|L2_medical_specialty=PrimaryCare（n_val=139）使用本地阈值 α=0.3000, β=0.0000
# [INFO][BT][2025-12-12 21:27:38] 桶 bucket_id=L1_age=mid_age|L2_medical_specialty=PrimaryCare level=2：
#     n_train=94, n_val=139,
#     BAC=0.438, F1=0.576, AUC=0.622,
#     Regret=0.583, BND_ratio=0.180, POS_coverage=0.820,
#     Score(f1_regret_bnd )=-0.096
# [INFO][BT][2025-12-12 21:27:38] 桶 bucket_id=L1_age=mid_age|L2_medical_specialty=PrimaryCare：
#     parent_id=L1_age=mid_age，parent_Score=-0.112, bucket_Score=-0.096,
#     Gain=+0.016, is_weak=False
# 【INFO】【2025-12-12 21:27:38】【阈值】桶 L1_age=mid_age|L2_medical_specialty=Surgery_Trauma（n_val=122）使用本地阈值 α=0.4000, β=0.2000
# [INFO][BT][2025-12-12 21:27:38] 桶 bucket_id=L1_age=mid_age|L2_medical_specialty=Surgery_Trauma level=2：
#     n_train=135, n_val=122,
#     BAC=0.423, F1=0.667, AUC=0.706,
#     Regret=0.484, BND_ratio=0.393, POS_coverage=0.533,
#     Score(f1_regret_bnd )=-0.014
# [INFO][BT][2025-12-12 21:27:38] 桶 bucket_id=L1_age=mid_age|L2_medical_specialty=Surgery_Trauma：
#     parent_id=L1_age=mid_age，parent_Score=-0.112, bucket_Score=-0.014,
#     Gain=+0.098, is_weak=False
# 【INFO】【2025-12-12 21:27:39】【阈值】桶 L1_age=oldest|L2_medical_specialty=Cardio 标记为弱桶，阈值将回退使用 L1_age=oldest 的阈值
# [INFO][BT][2025-12-12 21:27:39] 桶 bucket_id=L1_age=oldest|L2_medical_specialty=Cardio level=2：
#     n_train=114, n_val=53,
#     BAC=0.500, F1=0.605, AUC=0.567,
#     Regret=0.566, BND_ratio=0.000, POS_coverage=1.000,
#     Score(f1_regret_bnd )=0.039
# [INFO][BT][2025-12-12 21:27:39] 桶 bucket_id=L1_age=oldest|L2_medical_specialty=Cardio：
#     parent_id=L1_age=oldest，parent_Score=0.117, bucket_Score=0.039,
#     Gain=-0.077, is_weak=True
# 【INFO】【2025-12-12 21:27:39】【阈值】桶 L1_age=oldest|L2_medical_specialty=InternalMed 标记为弱桶，阈值将回退使用 L1_age=oldest 的阈值
# [INFO][BT][2025-12-12 21:27:39] 桶 bucket_id=L1_age=oldest|L2_medical_specialty=InternalMed level=2：
#     n_train=92, n_val=201,
#     BAC=0.367, F1=0.595, AUC=0.655,
#     Regret=0.555, BND_ratio=0.393, POS_coverage=0.607,
#     Score(f1_regret_bnd )=-0.156
# [INFO][BT][2025-12-12 21:27:39] 桶 bucket_id=L1_age=oldest|L2_medical_specialty=InternalMed：
#     parent_id=L1_age=oldest，parent_Score=0.117, bucket_Score=-0.156,
#     Gain=-0.273, is_weak=True
# 【INFO】【2025-12-12 21:27:39】【阈值】桶 L1_age=oldest|L2_medical_specialty=Others（n_val=756）使用本地阈值 α=0.2000, β=0.0000
# [INFO][BT][2025-12-12 21:27:39] 桶 bucket_id=L1_age=oldest|L2_medical_specialty=Others level=2：
#     n_train=1719, n_val=756,
#     BAC=0.497, F1=0.657, AUC=0.635,
#     Regret=0.511, BND_ratio=0.016, POS_coverage=0.984,
#     Score(f1_regret_bnd )=0.139
# [INFO][BT][2025-12-12 21:27:39] 桶 bucket_id=L1_age=oldest|L2_medical_specialty=Others：
#     parent_id=L1_age=oldest，parent_Score=0.117, bucket_Score=0.139,
#     Gain=+0.022, is_weak=False
# 【INFO】【2025-12-12 21:27:39】【阈值】桶 L1_age=oldest|L2_medical_specialty=PrimaryCare（n_val=112）使用本地阈值 α=0.1000, β=0.0000
# [INFO][BT][2025-12-12 21:27:39] 桶 bucket_id=L1_age=oldest|L2_medical_specialty=PrimaryCare level=2：
#     n_train=227, n_val=112,
#     BAC=0.500, F1=0.667, AUC=0.562,
#     Regret=0.500, BND_ratio=0.000, POS_coverage=1.000,
#     Score(f1_regret_bnd )=0.167
# [INFO][BT][2025-12-12 21:27:39] 桶 bucket_id=L1_age=oldest|L2_medical_specialty=PrimaryCare：
#     parent_id=L1_age=oldest，parent_Score=0.117, bucket_Score=0.167,
#     Gain=+0.050, is_weak=False
# 【INFO】【2025-12-12 21:27:40】【阈值】桶 L1_age=oldest|L2_medical_specialty=Surgery_Trauma（n_val=172）使用本地阈值 α=0.2000, β=0.0000
# [INFO][BT][2025-12-12 21:27:40] 桶 bucket_id=L1_age=oldest|L2_medical_specialty=Surgery_Trauma level=2：
#     n_train=130, n_val=172,
#     BAC=0.500, F1=0.672, AUC=0.528,
#     Regret=0.494, BND_ratio=0.012, POS_coverage=0.988,
#     Score(f1_regret_bnd )=0.172
# [INFO][BT][2025-12-12 21:27:40] 桶 bucket_id=L1_age=oldest|L2_medical_specialty=Surgery_Trauma：
#     parent_id=L1_age=oldest，parent_Score=0.117, bucket_Score=0.172,
#     Gain=+0.055, is_weak=False
# 【INFO】【2025-12-12 21:27:40】【阈值】桶 L1_age=young_old|L2_medical_specialty=Cardio（n_val=110）使用本地阈值 α=0.1000, β=0.0000
# [INFO][BT][2025-12-12 21:27:40] 桶 bucket_id=L1_age=young_old|L2_medical_specialty=Cardio level=2：
#     n_train=132, n_val=110,
#     BAC=0.500, F1=0.659, AUC=0.619,
#     Regret=0.509, BND_ratio=0.000, POS_coverage=1.000,
#     Score(f1_regret_bnd )=0.149
# [INFO][BT][2025-12-12 21:27:40] 桶 bucket_id=L1_age=young_old|L2_medical_specialty=Cardio：
#     parent_id=L1_age=young_old，parent_Score=0.116, bucket_Score=0.149,
#     Gain=+0.033, is_weak=False
# 【INFO】【2025-12-12 21:27:40】【阈值】桶 L1_age=young_old|L2_medical_specialty=InternalMed（n_val=157）使用本地阈值 α=0.2000, β=0.0000
# [INFO][BT][2025-12-12 21:27:40] 桶 bucket_id=L1_age=young_old|L2_medical_specialty=InternalMed level=2：
#     n_train=190, n_val=157,
#     BAC=0.500, F1=0.692, AUC=0.593,
#     Regret=0.471, BND_ratio=0.013, POS_coverage=0.987,
#     Score(f1_regret_bnd )=0.214
# [INFO][BT][2025-12-12 21:27:40] 桶 bucket_id=L1_age=young_old|L2_medical_specialty=InternalMed：
#     parent_id=L1_age=young_old，parent_Score=0.116, bucket_Score=0.214,
#     Gain=+0.098, is_weak=False
# 【INFO】【2025-12-12 21:27:40】【阈值】桶 L1_age=young_old|L2_medical_specialty=Others（n_val=1847）使用本地阈值 α=0.2000, β=0.1000
# [INFO][BT][2025-12-12 21:27:40] 桶 bucket_id=L1_age=young_old|L2_medical_specialty=Others level=2：
#     n_train=4378, n_val=1847,
#     BAC=0.497, F1=0.660, AUC=0.657,
#     Regret=0.506, BND_ratio=0.021, POS_coverage=0.977,
#     Score(f1_regret_bnd )=0.143
# [INFO][BT][2025-12-12 21:27:40] 桶 bucket_id=L1_age=young_old|L2_medical_specialty=Others：
#     parent_id=L1_age=young_old，parent_Score=0.116, bucket_Score=0.143,
#     Gain=+0.027, is_weak=False
# 【INFO】【2025-12-12 21:27:40】【阈值】桶 L1_age=young_old|L2_medical_specialty=PrimaryCare（n_val=194）使用本地阈值 α=0.1000, β=0.0000
# [INFO][BT][2025-12-12 21:27:40] 桶 bucket_id=L1_age=young_old|L2_medical_specialty=PrimaryCare level=2：
#     n_train=171, n_val=194,
#     BAC=0.500, F1=0.689, AUC=0.509,
#     Regret=0.474, BND_ratio=0.000, POS_coverage=1.000,
#     Score(f1_regret_bnd )=0.215
# [INFO][BT][2025-12-12 21:27:40] 桶 bucket_id=L1_age=young_old|L2_medical_specialty=PrimaryCare：
#     parent_id=L1_age=young_old，parent_Score=0.116, bucket_Score=0.215,
#     Gain=+0.099, is_weak=False
# 【INFO】【2025-12-12 21:27:41】【阈值】桶 L1_age=young_old|L2_medical_specialty=Surgery_Trauma 标记为弱桶，阈值将回退使用 L1_age=young_old 的阈值
# [INFO][BT][2025-12-12 21:27:41] 桶 bucket_id=L1_age=young_old|L2_medical_specialty=Surgery_Trauma level=2：
#     n_train=167, n_val=126,
#     BAC=0.425, F1=0.636, AUC=0.670,
#     Regret=0.504, BND_ratio=0.349, POS_coverage=0.571,
#     Score(f1_regret_bnd )=-0.043
# [INFO][BT][2025-12-12 21:27:41] 桶 bucket_id=L1_age=young_old|L2_medical_specialty=Surgery_Trauma：
#     parent_id=L1_age=young_old，parent_Score=0.116, bucket_Score=-0.043,
#     Gain=-0.159, is_weak=True
# 【INFO】【2025-12-12 21:27:41】【阈值】桶 L1_age=mid_age|L2_medical_specialty=Cardio|L3_time_in_hospital=short_stay 标记为弱桶，阈值将回退使用 L1_age=mid_age|L2_medical_specialty=Cardio 的阈值
# [INFO][BT][2025-12-12 21:27:41] 桶 bucket_id=L1_age=mid_age|L2_medical_specialty=Cardio|L3_time_in_hospital=short_stay level=3：
#     n_train=150, n_val=66,
#     BAC=0.379, F1=0.620, AUC=0.675,
#     Regret=0.538, BND_ratio=0.364, POS_coverage=0.636,
#     Score(f1_regret_bnd )=-0.100
# [INFO][BT][2025-12-12 21:27:41] 桶 bucket_id=L1_age=mid_age|L2_medical_specialty=Cardio|L3_time_in_hospital=short_stay：
#     parent_id=L1_age=mid_age|L2_medical_specialty=Cardio，parent_Score=-0.092, bucket_Score=-0.100,
#     Gain=-0.008, is_weak=True
# 【INFO】【2025-12-12 21:27:41】【阈值】桶 L1_age=mid_age|L2_medical_specialty=Cardio|L3_time_in_hospital=others 标记为弱桶，阈值将回退使用 L1_age=mid_age|L2_medical_specialty=Cardio 的阈值
# [INFO][BT][2025-12-12 21:27:41] 桶 bucket_id=L1_age=mid_age|L2_medical_specialty=Cardio|L3_time_in_hospital=others level=3：
#     n_train=83, n_val=24,
#     BAC=nan, F1=nan, AUC=nan,
#     Regret=nan, BND_ratio=nan, POS_coverage=nan,
#     Score(f1_regret_bnd )=nan
# [INFO][BT][2025-12-12 21:27:41] 桶 bucket_id=L1_age=mid_age|L2_medical_specialty=Cardio|L3_time_in_hospital=others：
#     parent_id=L1_age=mid_age|L2_medical_specialty=Cardio，parent_Score=-0.092, bucket_Score=nan,
#     Gain=+nan, is_weak=True
# 【INFO】【2025-12-12 21:27:41】【阈值】桶 L1_age=mid_age|L2_medical_specialty=InternalMed|L3_time_in_hospital=long_stay 标记为弱桶，阈值将回退使用 L1_age=mid_age|L2_medical_specialty=InternalMed 的阈值
# [INFO][BT][2025-12-12 21:27:41] 桶 bucket_id=L1_age=mid_age|L2_medical_specialty=InternalMed|L3_time_in_hospital=long_stay level=3：
#     n_train=77, n_val=30,
#     BAC=nan, F1=nan, AUC=nan,
#     Regret=nan, BND_ratio=nan, POS_coverage=nan,
#     Score(f1_regret_bnd )=nan
# [INFO][BT][2025-12-12 21:27:41] 桶 bucket_id=L1_age=mid_age|L2_medical_specialty=InternalMed|L3_time_in_hospital=long_stay：
#     parent_id=L1_age=mid_age|L2_medical_specialty=InternalMed，parent_Score=-0.191, bucket_Score=nan,
#     Gain=+nan, is_weak=True
# 【INFO】【2025-12-12 21:27:41】【阈值】桶 L1_age=mid_age|L2_medical_specialty=InternalMed|L3_time_in_hospital=mid_stay（n_val=71）使用本地阈值 α=0.6000, β=0.2000
# [INFO][BT][2025-12-12 21:27:41] 桶 bucket_id=L1_age=mid_age|L2_medical_specialty=InternalMed|L3_time_in_hospital=mid_stay level=3：
#     n_train=187, n_val=71,
#     BAC=0.315, F1=0.681, AUC=0.808,
#     Regret=0.465, BND_ratio=0.704, POS_coverage=0.239,
#     Score(f1_regret_bnd )=-0.136
# [INFO][BT][2025-12-12 21:27:41] 桶 bucket_id=L1_age=mid_age|L2_medical_specialty=InternalMed|L3_time_in_hospital=mid_stay：
#     parent_id=L1_age=mid_age|L2_medical_specialty=InternalMed，parent_Score=-0.191, bucket_Score=-0.136,
#     Gain=+0.054, is_weak=False
# 【INFO】【2025-12-12 21:27:41】【阈值】桶 L1_age=mid_age|L2_medical_specialty=InternalMed|L3_time_in_hospital=short_stay（n_val=130）使用本地阈值 α=0.3000, β=0.0000
# [INFO][BT][2025-12-12 21:27:41] 桶 bucket_id=L1_age=mid_age|L2_medical_specialty=InternalMed|L3_time_in_hospital=short_stay level=3：
#     n_train=281, n_val=130,
#     BAC=0.395, F1=0.638, AUC=0.692,
#     Regret=0.523, BND_ratio=0.354, POS_coverage=0.646,
#     Score(f1_regret_bnd )=-0.062
# [INFO][BT][2025-12-12 21:27:41] 桶 bucket_id=L1_age=mid_age|L2_medical_specialty=InternalMed|L3_time_in_hospital=short_stay：
#     parent_id=L1_age=mid_age|L2_medical_specialty=InternalMed，parent_Score=-0.191, bucket_Score=-0.062,
#     Gain=+0.129, is_weak=False
# 【INFO】【2025-12-12 21:27:41】【阈值】桶 L1_age=mid_age|L2_medical_specialty=PrimaryCare|L3_time_in_hospital=mid_stay 标记为弱桶，阈值将回退使用 L1_age=mid_age|L2_medical_specialty=PrimaryCare 的阈值
# [INFO][BT][2025-12-12 21:27:41] 桶 bucket_id=L1_age=mid_age|L2_medical_specialty=PrimaryCare|L3_time_in_hospital=mid_stay level=3：
#     n_train=117, n_val=42,
#     BAC=nan, F1=nan, AUC=nan,
#     Regret=nan, BND_ratio=nan, POS_coverage=nan,
#     Score(f1_regret_bnd )=nan
# [INFO][BT][2025-12-12 21:27:41] 桶 bucket_id=L1_age=mid_age|L2_medical_specialty=PrimaryCare|L3_time_in_hospital=mid_stay：
#     parent_id=L1_age=mid_age|L2_medical_specialty=PrimaryCare，parent_Score=-0.096, bucket_Score=nan,
#     Gain=+nan, is_weak=True
# 【INFO】【2025-12-12 21:27:41】【阈值】桶 L1_age=mid_age|L2_medical_specialty=PrimaryCare|L3_time_in_hospital=short_stay 标记为弱桶，阈值将回退使用 L1_age=mid_age|L2_medical_specialty=PrimaryCare 的阈值
# [INFO][BT][2025-12-12 21:27:41] 桶 bucket_id=L1_age=mid_age|L2_medical_specialty=PrimaryCare|L3_time_in_hospital=short_stay level=3：
#     n_train=178, n_val=84,
#     BAC=0.354, F1=0.514, AUC=0.617,
#     Regret=0.601, BND_ratio=0.417, POS_coverage=0.524,
#     Score(f1_regret_bnd )=-0.296
# [INFO][BT][2025-12-12 21:27:41] 桶 bucket_id=L1_age=mid_age|L2_medical_specialty=PrimaryCare|L3_time_in_hospital=short_stay：
#     parent_id=L1_age=mid_age|L2_medical_specialty=PrimaryCare，parent_Score=-0.096, bucket_Score=-0.296,
#     Gain=-0.200, is_weak=True
# 【INFO】【2025-12-12 21:27:41】【阈值】桶 L1_age=mid_age|L2_medical_specialty=PrimaryCare|L3_time_in_hospital=others 标记为弱桶，阈值将回退使用 L1_age=mid_age|L2_medical_specialty=PrimaryCare 的阈值
# [INFO][BT][2025-12-12 21:27:41] 桶 bucket_id=L1_age=mid_age|L2_medical_specialty=PrimaryCare|L3_time_in_hospital=others level=3：
#     n_train=36, n_val=13,
#     BAC=nan, F1=nan, AUC=nan,
#     Regret=nan, BND_ratio=nan, POS_coverage=nan,
#     Score(f1_regret_bnd )=nan
# [INFO][BT][2025-12-12 21:27:41] 桶 bucket_id=L1_age=mid_age|L2_medical_specialty=PrimaryCare|L3_time_in_hospital=others：
#     parent_id=L1_age=mid_age|L2_medical_specialty=PrimaryCare，parent_Score=-0.096, bucket_Score=nan,
#     Gain=+nan, is_weak=True
# 【INFO】【2025-12-12 21:27:42】【阈值】桶 L1_age=mid_age|L2_medical_specialty=Surgery_Trauma|L3_time_in_hospital=mid_stay 标记为弱桶，阈值将回退使用 L1_age=mid_age|L2_medical_specialty=Surgery_Trauma 的阈值
# [INFO][BT][2025-12-12 21:27:42] 桶 bucket_id=L1_age=mid_age|L2_medical_specialty=Surgery_Trauma|L3_time_in_hospital=mid_stay level=3：
#     n_train=164, n_val=77,
#     BAC=0.396, F1=0.641, AUC=0.678,
#     Regret=0.494, BND_ratio=0.403, POS_coverage=0.545,
#     Score(f1_regret_bnd )=-0.054
# [INFO][BT][2025-12-12 21:27:42] 桶 bucket_id=L1_age=mid_age|L2_medical_specialty=Surgery_Trauma|L3_time_in_hospital=mid_stay：
#     parent_id=L1_age=mid_age|L2_medical_specialty=Surgery_Trauma，parent_Score=-0.014, bucket_Score=-0.054,
#     Gain=-0.040, is_weak=True
# 【INFO】【2025-12-12 21:27:42】【阈值】桶 L1_age=mid_age|L2_medical_specialty=Surgery_Trauma|L3_time_in_hospital=short_stay 标记为弱桶，阈值将回退使用 L1_age=mid_age|L2_medical_specialty=Surgery_Trauma 的阈值
# [INFO][BT][2025-12-12 21:27:42] 桶 bucket_id=L1_age=mid_age|L2_medical_specialty=Surgery_Trauma|L3_time_in_hospital=short_stay level=3：
#     n_train=270, n_val=105,
#     BAC=0.312, F1=0.645, AUC=0.695,
#     Regret=0.514, BND_ratio=0.571, POS_coverage=0.429,
#     Score(f1_regret_bnd )=-0.155
# [INFO][BT][2025-12-12 21:27:42] 桶 bucket_id=L1_age=mid_age|L2_medical_specialty=Surgery_Trauma|L3_time_in_hospital=short_stay：
#     parent_id=L1_age=mid_age|L2_medical_specialty=Surgery_Trauma，parent_Score=-0.014, bucket_Score=-0.155,
#     Gain=-0.141, is_weak=True
# 【INFO】【2025-12-12 21:27:42】【阈值】桶 L1_age=mid_age|L2_medical_specialty=Surgery_Trauma|L3_time_in_hospital=others 标记为弱桶，阈值将回退使用 L1_age=mid_age|L2_medical_specialty=Surgery_Trauma 的阈值
# [INFO][BT][2025-12-12 21:27:42] 桶 bucket_id=L1_age=mid_age|L2_medical_specialty=Surgery_Trauma|L3_time_in_hospital=others level=3：
#     n_train=49, n_val=24,
#     BAC=nan, F1=nan, AUC=nan,
#     Regret=nan, BND_ratio=nan, POS_coverage=nan,
#     Score(f1_regret_bnd )=nan
# [INFO][BT][2025-12-12 21:27:42] 桶 bucket_id=L1_age=mid_age|L2_medical_specialty=Surgery_Trauma|L3_time_in_hospital=others：
#     parent_id=L1_age=mid_age|L2_medical_specialty=Surgery_Trauma，parent_Score=-0.014, bucket_Score=nan,
#     Gain=+nan, is_weak=True
# 【INFO】【2025-12-12 21:27:42】【阈值】桶 L1_age=oldest|L2_medical_specialty=InternalMed|L3_time_in_hospital=long_stay 标记为弱桶，阈值将回退使用 L1_age=oldest|L2_medical_specialty=InternalMed 的阈值
# [INFO][BT][2025-12-12 21:27:42] 桶 bucket_id=L1_age=oldest|L2_medical_specialty=InternalMed|L3_time_in_hospital=long_stay level=3：
#     n_train=104, n_val=49,
#     BAC=nan, F1=nan, AUC=nan,
#     Regret=nan, BND_ratio=nan, POS_coverage=nan,
#     Score(f1_regret_bnd )=nan
# [INFO][BT][2025-12-12 21:27:42] 桶 bucket_id=L1_age=oldest|L2_medical_specialty=InternalMed|L3_time_in_hospital=long_stay：
#     parent_id=L1_age=oldest|L2_medical_specialty=InternalMed，parent_Score=-0.156, bucket_Score=nan,
#     Gain=+nan, is_weak=True
# 【INFO】【2025-12-12 21:27:42】【阈值】桶 L1_age=oldest|L2_medical_specialty=InternalMed|L3_time_in_hospital=mid_stay（n_val=87）使用本地阈值 α=0.3000, β=0.0000
# [INFO][BT][2025-12-12 21:27:42] 桶 bucket_id=L1_age=oldest|L2_medical_specialty=InternalMed|L3_time_in_hospital=mid_stay level=3：
#     n_train=202, n_val=87,
#     BAC=0.463, F1=0.649, AUC=0.668,
#     Regret=0.517, BND_ratio=0.149, POS_coverage=0.851,
#     Score(f1_regret_bnd )=0.057
# [INFO][BT][2025-12-12 21:27:42] 桶 bucket_id=L1_age=oldest|L2_medical_specialty=InternalMed|L3_time_in_hospital=mid_stay：
#     parent_id=L1_age=oldest|L2_medical_specialty=InternalMed，parent_Score=-0.156, bucket_Score=0.057,
#     Gain=+0.213, is_weak=False
# 【INFO】【2025-12-12 21:27:42】【阈值】桶 L1_age=oldest|L2_medical_specialty=InternalMed|L3_time_in_hospital=short_stay（n_val=65）使用本地阈值 α=0.4000, β=0.0000
# [INFO][BT][2025-12-12 21:27:42] 桶 bucket_id=L1_age=oldest|L2_medical_specialty=InternalMed|L3_time_in_hospital=short_stay level=3：
#     n_train=161, n_val=65,
#     BAC=0.385, F1=0.625, AUC=0.754,
#     Regret=0.531, BND_ratio=0.415, POS_coverage=0.585,
#     Score(f1_regret_bnd )=-0.113
# [INFO][BT][2025-12-12 21:27:42] 桶 bucket_id=L1_age=oldest|L2_medical_specialty=InternalMed|L3_time_in_hospital=short_stay：
#     parent_id=L1_age=oldest|L2_medical_specialty=InternalMed，parent_Score=-0.156, bucket_Score=-0.113,
#     Gain=+0.043, is_weak=False
# 【INFO】【2025-12-12 21:27:42】【阈值】桶 L1_age=oldest|L2_medical_specialty=PrimaryCare|L3_time_in_hospital=mid_stay 标记为弱桶，阈值将回退使用 L1_age=oldest|L2_medical_specialty=PrimaryCare 的阈值
# [INFO][BT][2025-12-12 21:27:42] 桶 bucket_id=L1_age=oldest|L2_medical_specialty=PrimaryCare|L3_time_in_hospital=mid_stay level=3：
#     n_train=95, n_val=47,
#     BAC=nan, F1=nan, AUC=nan,
#     Regret=nan, BND_ratio=nan, POS_coverage=nan,
#     Score(f1_regret_bnd )=nan
# [INFO][BT][2025-12-12 21:27:42] 桶 bucket_id=L1_age=oldest|L2_medical_specialty=PrimaryCare|L3_time_in_hospital=mid_stay：
#     parent_id=L1_age=oldest|L2_medical_specialty=PrimaryCare，parent_Score=0.167, bucket_Score=nan,
#     Gain=+nan, is_weak=True
# 【INFO】【2025-12-12 21:27:43】【阈值】桶 L1_age=oldest|L2_medical_specialty=PrimaryCare|L3_time_in_hospital=short_stay（n_val=53）使用本地阈值 α=0.1000, β=0.0000
# [INFO][BT][2025-12-12 21:27:43] 桶 bucket_id=L1_age=oldest|L2_medical_specialty=PrimaryCare|L3_time_in_hospital=short_stay level=3：
#     n_train=91, n_val=53,
#     BAC=0.500, F1=0.691, AUC=0.534,
#     Regret=0.472, BND_ratio=0.000, POS_coverage=1.000,
#     Score(f1_regret_bnd )=0.220
# [INFO][BT][2025-12-12 21:27:43] 桶 bucket_id=L1_age=oldest|L2_medical_specialty=PrimaryCare|L3_time_in_hospital=short_stay：
#     parent_id=L1_age=oldest|L2_medical_specialty=PrimaryCare，parent_Score=0.167, bucket_Score=0.220,
#     Gain=+0.053, is_weak=False
# 【INFO】【2025-12-12 21:27:43】【阈值】桶 L1_age=oldest|L2_medical_specialty=PrimaryCare|L3_time_in_hospital=others 标记为弱桶，阈值将回退使用 L1_age=oldest|L2_medical_specialty=PrimaryCare 的阈值
# [INFO][BT][2025-12-12 21:27:43] 桶 bucket_id=L1_age=oldest|L2_medical_specialty=PrimaryCare|L3_time_in_hospital=others level=3：
#     n_train=41, n_val=12,
#     BAC=nan, F1=nan, AUC=nan,
#     Regret=nan, BND_ratio=nan, POS_coverage=nan,
#     Score(f1_regret_bnd )=nan
# [INFO][BT][2025-12-12 21:27:43] 桶 bucket_id=L1_age=oldest|L2_medical_specialty=PrimaryCare|L3_time_in_hospital=others：
#     parent_id=L1_age=oldest|L2_medical_specialty=PrimaryCare，parent_Score=0.167, bucket_Score=nan,
#     Gain=+nan, is_weak=True
# 【INFO】【2025-12-12 21:27:43】【阈值】桶 L1_age=oldest|L2_medical_specialty=Surgery_Trauma|L3_time_in_hospital=mid_stay（n_val=75）使用本地阈值 α=0.1000, β=0.0000
# [INFO][BT][2025-12-12 21:27:43] 桶 bucket_id=L1_age=oldest|L2_medical_specialty=Surgery_Trauma|L3_time_in_hospital=mid_stay level=3：
#     n_train=172, n_val=75,
#     BAC=0.500, F1=0.673, AUC=0.577,
#     Regret=0.493, BND_ratio=0.000, POS_coverage=1.000,
#     Score(f1_regret_bnd )=0.179
# [INFO][BT][2025-12-12 21:27:43] 桶 bucket_id=L1_age=oldest|L2_medical_specialty=Surgery_Trauma|L3_time_in_hospital=mid_stay：
#     parent_id=L1_age=oldest|L2_medical_specialty=Surgery_Trauma，parent_Score=0.172, bucket_Score=0.179,
#     Gain=+0.007, is_weak=False
# 【INFO】【2025-12-12 21:27:43】【阈值】桶 L1_age=oldest|L2_medical_specialty=Surgery_Trauma|L3_time_in_hospital=short_stay 标记为弱桶，阈值将回退使用 L1_age=oldest|L2_medical_specialty=Surgery_Trauma 的阈值
# [INFO][BT][2025-12-12 21:27:43] 桶 bucket_id=L1_age=oldest|L2_medical_specialty=Surgery_Trauma|L3_time_in_hospital=short_stay level=3：
#     n_train=145, n_val=69,
#     BAC=0.500, F1=0.667, AUC=0.492,
#     Regret=0.500, BND_ratio=0.014, POS_coverage=0.986,
#     Score(f1_regret_bnd )=0.159
# [INFO][BT][2025-12-12 21:27:43] 桶 bucket_id=L1_age=oldest|L2_medical_specialty=Surgery_Trauma|L3_time_in_hospital=short_stay：
#     parent_id=L1_age=oldest|L2_medical_specialty=Surgery_Trauma，parent_Score=0.172, bucket_Score=0.159,
#     Gain=-0.012, is_weak=True
# 【INFO】【2025-12-12 21:27:43】【阈值】桶 L1_age=oldest|L2_medical_specialty=Surgery_Trauma|L3_time_in_hospital=others 标记为弱桶，阈值将回退使用 L1_age=oldest|L2_medical_specialty=Surgery_Trauma 的阈值
# [INFO][BT][2025-12-12 21:27:43] 桶 bucket_id=L1_age=oldest|L2_medical_specialty=Surgery_Trauma|L3_time_in_hospital=others level=3：
#     n_train=67, n_val=28,
#     BAC=nan, F1=nan, AUC=nan,
#     Regret=nan, BND_ratio=nan, POS_coverage=nan,
#     Score(f1_regret_bnd )=nan
# [INFO][BT][2025-12-12 21:27:43] 桶 bucket_id=L1_age=oldest|L2_medical_specialty=Surgery_Trauma|L3_time_in_hospital=others：
#     parent_id=L1_age=oldest|L2_medical_specialty=Surgery_Trauma，parent_Score=0.172, bucket_Score=nan,
#     Gain=+nan, is_weak=True
# 【INFO】【2025-12-12 21:27:43】【阈值】桶 L1_age=young_old|L2_medical_specialty=Cardio|L3_time_in_hospital=mid_stay（n_val=60）使用本地阈值 α=0.1000, β=0.0000
# [INFO][BT][2025-12-12 21:27:43] 桶 bucket_id=L1_age=young_old|L2_medical_specialty=Cardio|L3_time_in_hospital=mid_stay level=3：
#     n_train=134, n_val=60,
#     BAC=0.500, F1=0.737, AUC=0.618,
#     Regret=0.417, BND_ratio=0.000, POS_coverage=1.000,
#     Score(f1_regret_bnd )=0.320
# [INFO][BT][2025-12-12 21:27:43] 桶 bucket_id=L1_age=young_old|L2_medical_specialty=Cardio|L3_time_in_hospital=mid_stay：
#     parent_id=L1_age=young_old|L2_medical_specialty=Cardio，parent_Score=0.149, bucket_Score=0.320,
#     Gain=+0.171, is_weak=False
# 【INFO】【2025-12-12 21:27:43】【阈值】桶 L1_age=young_old|L2_medical_specialty=Cardio|L3_time_in_hospital=short_stay 标记为弱桶，阈值将回退使用 L1_age=young_old|L2_medical_specialty=Cardio 的阈值
# [INFO][BT][2025-12-12 21:27:43] 桶 bucket_id=L1_age=young_old|L2_medical_specialty=Cardio|L3_time_in_hospital=short_stay level=3：
#     n_train=258, n_val=130,
#     BAC=0.500, F1=0.632, AUC=0.545,
#     Regret=0.538, BND_ratio=0.000, POS_coverage=1.000,
#     Score(f1_regret_bnd )=0.093
# [INFO][BT][2025-12-12 21:27:43] 桶 bucket_id=L1_age=young_old|L2_medical_specialty=Cardio|L3_time_in_hospital=short_stay：
#     parent_id=L1_age=young_old|L2_medical_specialty=Cardio，parent_Score=0.149, bucket_Score=0.093,
#     Gain=-0.056, is_weak=True
# 【INFO】【2025-12-12 21:27:43】【阈值】桶 L1_age=young_old|L2_medical_specialty=Cardio|L3_time_in_hospital=others 标记为弱桶，阈值将回退使用 L1_age=young_old|L2_medical_specialty=Cardio 的阈值
# [INFO][BT][2025-12-12 21:27:43] 桶 bucket_id=L1_age=young_old|L2_medical_specialty=Cardio|L3_time_in_hospital=others level=3：
#     n_train=55, n_val=24,
#     BAC=nan, F1=nan, AUC=nan,
#     Regret=nan, BND_ratio=nan, POS_coverage=nan,
#     Score(f1_regret_bnd )=nan
# [INFO][BT][2025-12-12 21:27:43] 桶 bucket_id=L1_age=young_old|L2_medical_specialty=Cardio|L3_time_in_hospital=others：
#     parent_id=L1_age=young_old|L2_medical_specialty=Cardio，parent_Score=0.149, bucket_Score=nan,
#     Gain=+nan, is_weak=True
# 【INFO】【2025-12-12 21:27:44】【阈值】桶 L1_age=young_old|L2_medical_specialty=InternalMed|L3_time_in_hospital=long_stay（n_val=82）使用本地阈值 α=0.2000, β=0.0000
# [INFO][BT][2025-12-12 21:27:44] 桶 bucket_id=L1_age=young_old|L2_medical_specialty=InternalMed|L3_time_in_hospital=long_stay level=3：
#     n_train=184, n_val=82,
#     BAC=0.500, F1=0.724, AUC=0.612,
#     Regret=0.433, BND_ratio=0.012, POS_coverage=0.988,
#     Score(f1_regret_bnd )=0.285
# [INFO][BT][2025-12-12 21:27:44] 桶 bucket_id=L1_age=young_old|L2_medical_specialty=InternalMed|L3_time_in_hospital=long_stay：
#     parent_id=L1_age=young_old|L2_medical_specialty=InternalMed，parent_Score=0.214, bucket_Score=0.285,
#     Gain=+0.071, is_weak=False
# 【INFO】【2025-12-12 21:27:44】【阈值】桶 L1_age=young_old|L2_medical_specialty=InternalMed|L3_time_in_hospital=mid_stay 标记为弱桶，阈值将回退使用 L1_age=young_old|L2_medical_specialty=InternalMed 的阈值
# [INFO][BT][2025-12-12 21:27:44] 桶 bucket_id=L1_age=young_old|L2_medical_specialty=InternalMed|L3_time_in_hospital=mid_stay level=3：
#     n_train=379, n_val=187,
#     BAC=0.500, F1=0.688, AUC=0.633,
#     Regret=0.476, BND_ratio=0.000, POS_coverage=1.000,
#     Score(f1_regret_bnd )=0.212
# [INFO][BT][2025-12-12 21:27:44] 桶 bucket_id=L1_age=young_old|L2_medical_specialty=InternalMed|L3_time_in_hospital=mid_stay：
#     parent_id=L1_age=young_old|L2_medical_specialty=InternalMed，parent_Score=0.214, bucket_Score=0.212,
#     Gain=-0.002, is_weak=True
# 【INFO】【2025-12-12 21:27:44】【阈值】桶 L1_age=young_old|L2_medical_specialty=InternalMed|L3_time_in_hospital=short_stay 标记为弱桶，阈值将回退使用 L1_age=young_old|L2_medical_specialty=InternalMed 的阈值
# [INFO][BT][2025-12-12 21:27:44] 桶 bucket_id=L1_age=young_old|L2_medical_specialty=InternalMed|L3_time_in_hospital=short_stay level=3：
#     n_train=397, n_val=190,
#     BAC=0.348, F1=0.576, AUC=0.675,
#     Regret=0.547, BND_ratio=0.474, POS_coverage=0.500,
#     Score(f1_regret_bnd )=-0.208
# [INFO][BT][2025-12-12 21:27:44] 桶 bucket_id=L1_age=young_old|L2_medical_specialty=InternalMed|L3_time_in_hospital=short_stay：
#     parent_id=L1_age=young_old|L2_medical_specialty=InternalMed，parent_Score=0.214, bucket_Score=-0.208,
#     Gain=-0.422, is_weak=True
# 【INFO】【2025-12-12 21:27:44】【阈值】桶 L1_age=young_old|L2_medical_specialty=PrimaryCare|L3_time_in_hospital=long_stay 标记为弱桶，阈值将回退使用 L1_age=young_old|L2_medical_specialty=PrimaryCare 的阈值
# ...
#     assigned_samples=129,
#     used_local_decision=0,
#     fallback_to_parent=129,
#     parent_id=L1_age=young_old|L2_medical_specialty=InternalMed,
#     is_weak=True
# [INFO][BT][2025-12-12 21:28:39] 预测统计：bucket_id=L1_age=young_old|L2_medical_specialty=Others：
#     assigned_samples=1565,
#     used_local_decision=1565,
#     fallback_to_parent=0,
#     parent_id=L1_age=young_old,
#     is_weak=False
# [INFO][BT][2025-12-12 21:28:39] 预测统计：bucket_id=L1_age=young_old|L2_medical_specialty=PrimaryCare|L3_time_in_hospital=long_stay：
#     assigned_samples=30,
#     used_local_decision=0,
#     fallback_to_parent=30,
#     parent_id=L1_age=young_old|L2_medical_specialty=PrimaryCare,
#     is_weak=True
# [INFO][BT][2025-12-12 21:28:39] 预测统计：bucket_id=L1_age=young_old|L2_medical_specialty=PrimaryCare：
#     assigned_samples=0,
#     used_local_decision=99,
#     fallback_to_parent=0,
#     parent_id=L1_age=young_old,
#     is_weak=False
# [INFO][BT][2025-12-12 21:28:39] 预测统计：bucket_id=L1_age=young_old|L2_medical_specialty=PrimaryCare|L3_time_in_hospital=mid_stay：
#     assigned_samples=69,
#     used_local_decision=0,
#     fallback_to_parent=69,
#     parent_id=L1_age=young_old|L2_medical_specialty=PrimaryCare,
#     is_weak=True
# [INFO][BT][2025-12-12 21:28:39] 预测统计：bucket_id=L1_age=young_old|L2_medical_specialty=PrimaryCare|L3_time_in_hospital=short_stay：
#     assigned_samples=78,
#     used_local_decision=78,
#     fallback_to_parent=0,
#     parent_id=L1_age=young_old|L2_medical_specialty=PrimaryCare,
#     is_weak=False
# [INFO][BT][2025-12-12 21:28:39] 预测统计：bucket_id=L1_age=young_old|L2_medical_specialty=Surgery_Trauma|L3_time_in_hospital=long_stay：
#     assigned_samples=55,
#     used_local_decision=0,
#     fallback_to_parent=55,
#     parent_id=L1_age=young_old|L2_medical_specialty=Surgery_Trauma,
#     is_weak=True
# [INFO][BT][2025-12-12 21:28:39] 预测统计：bucket_id=L1_age=young_old|L2_medical_specialty=Surgery_Trauma|L3_time_in_hospital=mid_stay：
#     assigned_samples=116,
#     used_local_decision=116,
#     fallback_to_parent=0,
#     parent_id=L1_age=young_old|L2_medical_specialty=Surgery_Trauma,
#     is_weak=False
# [INFO][BT][2025-12-12 21:28:39] 预测统计：bucket_id=L1_age=young_old|L2_medical_specialty=Surgery_Trauma|L3_time_in_hospital=short_stay：
#     assigned_samples=113,
#     used_local_decision=113,
#     fallback_to_parent=0,
#     parent_id=L1_age=young_old|L2_medical_specialty=Surgery_Trauma,
#     is_weak=False
# [INFO][BT][2025-12-12 21:28:39] 回退汇总：
#     总样本数=5000,
#     使用叶子桶决策的样本比例=59.920%,
#     使用中间桶决策的样本比例=18.840%,
#     回退到全局桶决策的样本比例=21.240%
# 【INFO】【2025-12-12 21:28:39】【BTTWD】三支指标(含后悔)：Precision=0.488, Recall=0.967, F1=0.649, BAC=0.534, AUC=0.662, MCC=0.133, Kappa=0.064, BND_ratio=0.056, POS_Coverage=0.934, Regret=0.521
# 【INFO】【2025-12-12 21:28:39】【桶树】已为样本生成桶ID，共 45 个组合
# 【INFO】【2025-12-12 21:28:39】【K折实验】所有结果已写入 results 目录
# 【INFO】【2025-12-12 21:28:39】[BASELINE] 数据拆分完成（train/val/test）
# 【INFO】【2025-12-12 21:28:39】[BASELINE] 全局 XGB 模型开始训练
# C:\Users\xzq20.HUANLI\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:158: UserWarning: [21:28:40] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 【INFO】【2025-12-12 21:28:40】[BASELINE] 全局 XGB 模型训练完成
# 【INFO】【2025-12-12 21:28:40】[BASELINE] 阈值搜索开始
# 【INFO】【2025-12-12 21:28:40】[BASELINE] 最佳阈值找到: alpha=0.3000, beta=0.0000, regret=0.5172
# 【INFO】【2025-12-12 21:28:40】【桶树】已为样本生成桶ID，共 45 个组合
# 【INFO】【2025-12-12 21:28:40】[BASELINE] 测试集桶映射完成，共 45 个桶
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=young_old|L2_medical_specialty=Others|L3_time_in_hospital=mid_stay: BAC=0.5153, Regret=0.5069, Precision=0.5065, Recall=0.9481
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=young_old|L2_medical_specialty=Others|L3_time_in_hospital=long_stay: BAC=0.5370, Regret=0.4752, Precision=0.5540, Recall=0.9147
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=mid_age|L2_medical_specialty=InternalMed|L3_time_in_hospital=short_stay: BAC=0.6635, Regret=0.5303, Precision=0.5370, Recall=0.7436
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=mid_age|L2_medical_specialty=Others|L3_time_in_hospital=short_stay: BAC=0.5726, Regret=0.5859, Precision=0.4245, Recall=0.8491
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=young_old|L2_medical_specialty=InternalMed|L3_time_in_hospital=mid_stay: BAC=0.5312, Regret=0.4770, Precision=0.5435, Recall=0.9375
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=mid_age|L2_medical_specialty=Others|L3_time_in_hospital=long_stay: BAC=0.5120, Regret=0.4961, Precision=0.5619, Recall=0.8310
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=oldest|L2_medical_specialty=Others|L3_time_in_hospital=mid_stay: BAC=0.5099, Regret=0.4979, Precision=0.5177, Recall=0.9435
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=mid_age|L2_medical_specialty=Others|L3_time_in_hospital=mid_stay: BAC=0.5359, Regret=0.5103, Precision=0.5137, Recall=0.9097
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=young_old|L2_medical_specialty=Cardio|L3_time_in_hospital=short_stay: BAC=0.4906, Regret=0.6158, Precision=0.4051, Recall=0.8205
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=oldest|L2_medical_specialty=InternalMed|L3_time_in_hospital=long_stay: BAC=0.5212, Regret=0.5952, Precision=0.4167, Recall=0.8824
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=oldest|L2_medical_specialty=Surgery_Trauma|L3_time_in_hospital=short_stay: BAC=0.5589, Regret=0.4333, Precision=0.5818, Recall=0.9697
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=mid_age|L2_medical_specialty=Surgery_Trauma|L3_time_in_hospital=short_stay: BAC=0.6110, Regret=0.5879, Precision=0.4127, Recall=0.8387
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=young_old|L2_medical_specialty=Others|L3_time_in_hospital=short_stay: BAC=0.5616, Regret=0.5337, Precision=0.4826, Recall=0.9151
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=mid_age|L2_medical_specialty=Cardio|L3_time_in_hospital=short_stay: BAC=0.5957, Regret=0.5865, Precision=0.4375, Recall=0.7368
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=young_old|L2_medical_specialty=Surgery_Trauma|L3_time_in_hospital=short_stay: BAC=0.5355, Regret=0.6074, Precision=0.4111, Recall=0.7872
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=young_old|L2_medical_specialty=PrimaryCare|L3_time_in_hospital=mid_stay: BAC=0.5202, Regret=0.4412, Precision=0.5692, Recall=0.9737
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=mid_age|L2_medical_specialty=PrimaryCare|L3_time_in_hospital=long_stay: BAC=0.5000, Regret=0.3333, Precision=0.6667, Recall=1.0000
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=mid_age|L2_medical_specialty=Cardio|L3_time_in_hospital=mid_stay: BAC=0.5833, Regret=0.4400, Precision=0.5652, Recall=1.0000
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=young_old|L2_medical_specialty=InternalMed|L3_time_in_hospital=long_stay: BAC=0.5067, Regret=0.4851, Precision=0.5410, Recall=0.9167
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=mid_age|L2_medical_specialty=PrimaryCare|L3_time_in_hospital=mid_stay: BAC=0.5682, Regret=0.5256, Precision=0.4722, Recall=1.0000
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=oldest|L2_medical_specialty=InternalMed|L3_time_in_hospital=short_stay: BAC=0.6000, Regret=0.6000, Precision=0.3878, Recall=0.9500
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=mid_age|L2_medical_specialty=InternalMed|L3_time_in_hospital=mid_stay: BAC=0.5328, Regret=0.5342, Precision=0.4844, Recall=0.9118
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=oldest|L2_medical_specialty=Others|L3_time_in_hospital=short_stay: BAC=0.5413, Regret=0.4868, Precision=0.5202, Recall=0.9773
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=mid_age|L2_medical_specialty=PrimaryCare|L3_time_in_hospital=short_stay: BAC=0.5051, Regret=0.5652, Precision=0.4815, Recall=0.7879
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=young_old|L2_medical_specialty=Cardio|L3_time_in_hospital=long_stay: BAC=0.5556, Regret=0.4250, Precision=0.5789, Recall=1.0000
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=oldest|L2_medical_specialty=Cardio|L3_time_in_hospital=long_stay: BAC=0.5000, Regret=0.2727, Precision=0.7273, Recall=1.0000
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=oldest|L2_medical_specialty=Cardio|L3_time_in_hospital=short_stay: BAC=0.5714, Regret=0.4333, Precision=0.5714, Recall=1.0000
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=young_old|L2_medical_specialty=Surgery_Trauma|L3_time_in_hospital=mid_stay: BAC=0.5360, Regret=0.4318, Precision=0.5825, Recall=0.9677
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=oldest|L2_medical_specialty=Surgery_Trauma|L3_time_in_hospital=long_stay: BAC=0.5417, Regret=0.6970, Precision=0.2903, Recall=1.0000
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=young_old|L2_medical_specialty=PrimaryCare|L3_time_in_hospital=short_stay: BAC=0.5493, Regret=0.4167, Precision=0.6562, Recall=0.8571
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=oldest|L2_medical_specialty=Others|L3_time_in_hospital=long_stay: BAC=0.5383, Regret=0.5318, Precision=0.4752, Recall=0.9600
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=young_old|L2_medical_specialty=Surgery_Trauma|L3_time_in_hospital=long_stay: BAC=0.5417, Regret=0.5900, Precision=0.4250, Recall=0.8500
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=oldest|L2_medical_specialty=InternalMed|L3_time_in_hospital=mid_stay: BAC=0.5452, Regret=0.5562, Precision=0.4783, Recall=0.8250
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=mid_age|L2_medical_specialty=Surgery_Trauma|L3_time_in_hospital=mid_stay: BAC=0.6138, Regret=0.4706, Precision=0.5610, Recall=0.9200
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=young_old|L2_medical_specialty=InternalMed|L3_time_in_hospital=short_stay: BAC=0.6006, Regret=0.5305, Precision=0.4812, Recall=0.9275
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=oldest|L2_medical_specialty=PrimaryCare|L3_time_in_hospital=mid_stay: BAC=0.4969, Regret=0.5417, Precision=0.4706, Recall=0.9412
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=young_old|L2_medical_specialty=PrimaryCare|L3_time_in_hospital=long_stay: BAC=0.5018, Regret=0.5000, Precision=0.5161, Recall=0.9412
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=oldest|L2_medical_specialty=PrimaryCare|L3_time_in_hospital=short_stay: BAC=0.5615, Regret=0.4348, Precision=0.6000, Recall=0.9231
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=young_old|L2_medical_specialty=Cardio|L3_time_in_hospital=mid_stay: BAC=0.5060, Regret=0.4808, Precision=0.5417, Recall=0.9286
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=mid_age|L2_medical_specialty=Surgery_Trauma|L3_time_in_hospital=long_stay: BAC=0.5909, Regret=0.4762, Precision=0.5263, Recall=1.0000
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=oldest|L2_medical_specialty=Surgery_Trauma|L3_time_in_hospital=mid_stay: BAC=0.5536, Regret=0.5196, Precision=0.4792, Recall=1.0000
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=mid_age|L2_medical_specialty=Cardio|L3_time_in_hospital=long_stay: BAC=0.5000, Regret=0.5714, Precision=0.4286, Recall=1.0000
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=oldest|L2_medical_specialty=Cardio|L3_time_in_hospital=mid_stay: BAC=0.5000, Regret=0.2500, Precision=0.7500, Recall=1.0000
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=mid_age|L2_medical_specialty=InternalMed|L3_time_in_hospital=long_stay: BAC=0.4758, Regret=0.6154, Precision=0.4091, Recall=0.8182
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=oldest|L2_medical_specialty=PrimaryCare|L3_time_in_hospital=long_stay: BAC=0.5833, Regret=0.5500, Precision=0.4444, Recall=1.0000
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=young_old|L2_medical_specialty=Others: BAC=0.5417, Regret=0.5143, Precision=0.5033, Recall=0.9280
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=young_old: BAC=0.5425, Regret=0.5120, Precision=0.5085, Recall=0.9196
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=mid_age|L2_medical_specialty=InternalMed: BAC=0.5993, Regret=0.5429, Precision=0.4929, Recall=0.8214
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=mid_age: BAC=0.5699, Regret=0.5432, Precision=0.4828, Recall=0.8650
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=mid_age|L2_medical_specialty=Others: BAC=0.5549, Regret=0.5459, Precision=0.4794, Recall=0.8690
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=young_old|L2_medical_specialty=InternalMed: BAC=0.5608, Regret=0.5013, Precision=0.5181, Recall=0.9297
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=oldest|L2_medical_specialty=Others: BAC=0.5286, Regret=0.4992, Precision=0.5113, Recall=0.9608
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=oldest: BAC=0.5396, Regret=0.5123, Precision=0.4995, Recall=0.9504
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=young_old|L2_medical_specialty=Cardio: BAC=0.5097, Regret=0.5509, Precision=0.4726, Recall=0.8846
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=oldest|L2_medical_specialty=InternalMed: BAC=0.5535, Regret=0.5785, Precision=0.4351, Recall=0.8701
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=oldest|L2_medical_specialty=Surgery_Trauma: BAC=0.5493, Regret=0.5243, Precision=0.4776, Recall=0.9846
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=mid_age|L2_medical_specialty=Surgery_Trauma: BAC=0.6171, Regret=0.5368, Precision=0.4797, Recall=0.8939
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=mid_age|L2_medical_specialty=Cardio: BAC=0.6020, Regret=0.5417, Precision=0.4839, Recall=0.8571
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=young_old|L2_medical_specialty=Surgery_Trauma: BAC=0.5504, Regret=0.5356, Precision=0.4893, Recall=0.8837
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=young_old|L2_medical_specialty=PrimaryCare: BAC=0.5234, Regret=0.4413, Precision=0.5938, Recall=0.9135
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=mid_age|L2_medical_specialty=PrimaryCare: BAC=0.5277, Regret=0.5342, Precision=0.4949, Recall=0.8750
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=oldest|L2_medical_specialty=Cardio: BAC=0.5417, Regret=0.3382, Precision=0.6667, Recall=1.0000
# 【INFO】【2025-12-12 21:28:41】[BASELINE] 桶 L1_age=oldest|L2_medical_specialty=PrimaryCare: BAC=0.5277, Regret=0.5072, Precision=0.5079, Recall=0.9412
# 【INFO】【2025-12-12 21:28:41】[BASELINE] baseline_bucket_metrics.csv 写出完成
# 【INFO】【2025-12-12 21:28:41】[BASELINE] baseline 指标成功合并到 bucket_metrics_gain.csv
#           model  Precision_mean  Precision_std  Recall_mean  Recall_std  \
# 0         BTTWD        0.487137       0.001709     0.955504    0.007202
# 1        LogReg        0.470421       0.000270     0.999915    0.000170
# 2  RandomForest        0.474191       0.000304     0.988684    0.001839
# 3           KNN        0.492499       0.001811     0.843117    0.005035
# 4       XGBoost        0.475988       0.000858     0.987409    0.000876
#
#     F1_mean    F1_std  BAC_mean   BAC_std  AUC_mean  ...  MCC_mean   MCC_std  \
# 0  0.645287  0.002922  0.531429  0.003141  0.649473  ...  0.117409  0.013790
# 1  0.639828  0.000223  0.500524  0.000428  0.646378  ...  0.018265  0.010084
# 2  0.640964  0.000556  0.507931  0.000485  0.639255  ...  0.057103  0.003986
# 3  0.621782  0.002280  0.536083  0.002764  0.584971  ...  0.090894  0.006801
# 4  0.642334  0.000894  0.511408  0.001664  0.655854  ...  0.073222  0.008968
#
#    Kappa_mean  Kappa_std  BND_ratio_mean  BND_ratio_std  POS_Coverage_mean  \
# 0    0.059628   0.005949         0.10504       0.032246            0.88756
# 1    0.000985   0.000806         0.00000       0.000000                NaN
# 2    0.014949   0.000916         0.00000       0.000000                NaN
# 3    0.069386   0.005331         0.00000       0.000000                NaN
# 4    0.021514   0.003141         0.00000       0.000000                NaN
#
#    POS_Coverage_std  Regret_mean  Regret_std
# 0          0.031898      0.52256    0.001286
# 1               NaN      0.52936    0.000388
# 2               NaN      0.53140    0.001876
# 3               NaN      0.62976    0.006158
# 4               NaN      0.52884    0.002271
#
# [5 rows x 21 columns]
# 【INFO】【2025-12-12 21:28:42】【步骤6摘要】BTTWD 与基线的 k 折结果已生成并保存。

# %%
# 步骤7：桶级别分析
bucket_metrics_path = os.path.join(root_path, cfg['OUTPUT']['results_dir'], 'bucket_metrics.csv')
if os.path.exists(bucket_metrics_path):
    bucket_metrics_df = pd.read_csv(bucket_metrics_path)
    display(bucket_metrics_df.head())
    bucket_metrics_df.plot(x='bucket_id', y='pos_rate_all', kind='bar', figsize=(12,4), title='桶正类比例')
    plt.ylabel('正类比例')
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.savefig(fig_bucket, bbox_inches='tight')
    plt.close()
log_info('【步骤7摘要】桶级指标已整理，可用于局部化分析。')
# Out:
#                                       bucket_id layer  parent_bucket_id  \
# 0                                          ROOT    L1               NaN
# 1                              L1_age=young_old    L1              ROOT
# 2  L1_age=young_old|L2_medical_specialty=Others    L2  L1_age=young_old
# 3                                L1_age=mid_age    L1              ROOT
# 4                                 L1_age=oldest    L1              ROOT
#
#    n_train  n_val  pos_rate_train  pos_rate_val  alpha  beta  regret_val  ...  \
# 0     2799   1198        0.478742      0.484975    0.3   0.1    0.512521  ...
# 1     1428    612        0.460784      0.475490    0.2   0.0    0.520425  ...
# 2     4378   1847        0.481498      0.489442    0.2   0.1    0.506497  ...
# 3      787    396        0.443456      0.441919    0.3   0.1    0.527778  ...
# 4      579    300        0.483592      0.473333    0.2   0.0    0.520000  ...
#
#    is_weak                       threshold_source_bucket  \
# 0    False                                          ROOT
# 1    False                              L1_age=young_old
# 2    False  L1_age=young_old|L2_medical_specialty=Others
# 3     True                                          ROOT
# 4    False                                 L1_age=oldest
#
#    parent_with_threshold  n_test  pos_rate_test  BND_ratio_test  \
# 0                    NaN     NaN            NaN             NaN
# 1                    NaN     NaN            NaN             NaN
# 2                    NaN     NaN            NaN             NaN
# 3                    NaN     NaN            NaN             NaN
# 4                    NaN     NaN            NaN             NaN
#
#    POS_Coverage_test  regret_test  fold  pos_rate
# 0                NaN          NaN     1  0.470200
# 1                NaN          NaN     1  0.482394
# 2                NaN          NaN     1  0.483855
# 3                NaN          NaN     1  0.439239
# 4                NaN          NaN     1  0.481570
#
# [5 rows x 35 columns]
# C:\Users\xzq20.HUANLI\AppData\Local\Temp\ipykernel_24584\946468196.py:9: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 【INFO】【2025-12-12 21:28:45】【步骤7摘要】桶级指标已整理，可用于局部化分析。

# %%
# 步骤8：结果汇总
log_info('【步骤8】检查结果文件与图表。')
print(os.listdir(os.path.join(root_path, cfg['OUTPUT']['results_dir'])))
print(os.listdir(os.path.join(root_path, cfg['OUTPUT']['figs_dir'])))
log_info('【全部步骤完成】Telco Churn 数据集上的 BT-TWD 实验结束。')
# Out:
# 【INFO】【2025-12-12 21:28:45】【步骤8】检查结果文件与图表。
# ['baseline_bucket_metrics.csv', 'bucket_fallback_stats.csv', 'bucket_metrics.csv', 'bucket_metrics_gain.csv', 'bucket_thresholds.csv', 'bucket_thresholds_per_fold.csv', 'bucket_tree_structure.csv', 'metrics_kfold_per_fold.csv', 'metrics_kfold_summary.csv', 'metrics_overview.csv']
# ['bank_class_distribution.png', 'bucket_metrics_bar.png', 'class_distribution.png', 'metrics_compare.png']
# 【INFO】【2025-12-12 21:28:45】【全部步骤完成】Telco Churn 数据集上的 BT-TWD 实验结束。
