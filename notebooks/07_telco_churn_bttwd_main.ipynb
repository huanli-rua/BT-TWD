# %% [markdown]
# Telco Churn 数据集 BT-TWD 可行性实验
#
# 本 notebook 按步骤运行：加载配置 → 读取数据 → 预处理 → 桶树划分 → 基线与 BTTWD k 折实验 → 桶级分析。

# %%
# 步骤0：环境与路径设置
import os, sys
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['Microsoft YaHei']
plt.rcParams['axes.unicode_minus'] = False

# 将项目根目录加入路径，便于导入 bttwdlib
root_path = os.path.abspath(os.path.join(os.getcwd(), '..'))
if root_path not in sys.path:
    sys.path.append(root_path)

from bttwdlib import (
    load_yaml_cfg,
    show_cfg,
    load_dataset,
    prepare_features_and_labels,
    BucketTree,
    run_kfold_experiments,
    log_info,
    set_global_seed,
)

cfg_path = Path(root_path) / "configs" / "telco_churn.yaml"
cfg = load_yaml_cfg(cfg_path)
set_global_seed(cfg.get('SEED', {}).get('global_seed', 42))
log_info('【步骤0摘要】环境准备完毕，路径与随机种子已设置。')
# Out:
# 【INFO】【2025-12-11 19:36:45】【配置加载】已读取 e:\yan\组\三支决策\机器学习\BT_TWD\configs\telco_churn.yaml
# 【INFO】【2025-12-11 19:36:49】【步骤0摘要】环境准备完毕，路径与随机种子已设置。

# %%
# 步骤1：加载配置
show_cfg(cfg)
log_info('【步骤1摘要】配置文件加载完成，关键参数检查通过。')
# Out:
# 【INFO】【2025-12-11 19:36:49】【配置-数据】数据集=telco_churn, k折=5, 目标列=Churn, 正类="Yes"
# 【INFO】【2025-12-11 19:36:49】【配置-BTTWD】阈值模式=None, 全局模型=xgb, 桶内模型=none, 后验估计器(兼容字段)=logreg
# 【INFO】【2025-12-11 19:36:49】【配置-基线】LogReg启用=True, RandomForest启用=True, KNN启用=True, XGBoost启用=True
# 【INFO】【2025-12-11 19:36:49】【步骤1摘要】配置文件加载完成，关键参数检查通过。

# %%
# 步骤2：加载原始数据
df_raw, target_col_model = load_dataset(cfg)  # 这里返回的是用于建模的标签列，例如 "label"

display(df_raw.head())
print("用于建模的标签列:", target_col_model)

# 1）画 0/1 标签（流失/未流失）的比例
class_counts = df_raw[target_col_model].value_counts(normalize=True)
ax = class_counts.plot(kind='bar', title='流失 vs 未流失比例')
plt.ylabel('比例')

fig_path = os.path.join(root_path, cfg['OUTPUT']['figs_dir'], 'class_distribution.png')
os.makedirs(os.path.dirname(fig_path), exist_ok=True)
plt.savefig(fig_path, bbox_inches='tight')
plt.close()

# 2）如果想看原始标签列的分布，可以另外单独分析：
raw_target_col = cfg['DATA']['target_col']  # 这里是原始标签列
print("原始目标列:", raw_target_col)
print(df_raw[raw_target_col].describe())

log_info('【步骤2摘要】Telco Churn 原始数据加载与基本统计完成。')
# Out:
# 【INFO】【2025-12-11 19:36:49】【数据加载】文本表格 ..\data\Telco-Customer-Churn\Telco-Customer-Churn.csv 已读取，样本数=7043，列数=21
# 【INFO】【2025-12-11 19:36:49】【数据集信息】名称=telco_churn，样本数=7043，目标列=Churn，正类比例=26.54%
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges  Churn
# 0           Electronic check          29.85         29.85      0
# 1               Mailed check          56.95       1889.50      0
# 2               Mailed check          53.85        108.15      1
# 3  Bank transfer (automatic)          42.30       1840.75      0
# 4           Electronic check          70.70        151.65      1
#
# [5 rows x 21 columns]
# 用于建模的标签列: Churn
# 原始目标列: Churn
# count    7043.000000
# mean        0.265370
# std         0.441561
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: Churn, dtype: float64
# 【INFO】【2025-12-11 19:36:49】【步骤2摘要】Telco Churn 原始数据加载与基本统计完成。

# %%
# 步骤3：预处理与特征工程
X, y, meta = prepare_features_and_labels(df_raw, cfg)
log_info(f'【预处理】编码特征维度={X.shape[1]}，样本数={X.shape[0]}')
log_info(f"【步骤3摘要】特征预处理完成：连续={len(meta['continuous_cols'])}，类别={len(meta['categorical_cols'])}，编码维度={X.shape[1]}。")
# Out:
# 【INFO】【2025-12-11 19:36:49】【预处理】缺失值填充策略=most_frequent
# 【INFO】【2025-12-11 19:36:49】【预处理】连续特征=3个，类别特征=16个
# 【INFO】【2025-12-11 19:36:49】【预处理】编码后维度=30
# 【INFO】【2025-12-11 19:36:49】【预处理】编码特征维度=30，样本数=7043
# 【INFO】【2025-12-11 19:36:49】【步骤3摘要】特征预处理完成：连续=3，类别=16，编码维度=30。

# %%
# 步骤4：构建桶树并检查划分
feature_cols_for_bucket = [c for c in df_raw.columns if c != target_col_model]

bucket_tree = BucketTree(
    cfg['BTTWD']['bucket_levels'],
    feature_names=feature_cols_for_bucket
)

bucket_ids_full = bucket_tree.assign_buckets(df_raw[feature_cols_for_bucket])

bucket_df = bucket_ids_full.value_counts().reset_index()
bucket_df.columns = ['bucket_id', 'count']

bucket_df['pos_rate'] = (
    df_raw.groupby(bucket_ids_full)[target_col_model]
    .apply(lambda s: (s == 1).mean())
    .values
)
display(bucket_df.head())
bucket_df.set_index('bucket_id')['count'].plot(kind='bar', figsize=(12,4), title='桶样本数分布')
fig_bucket = os.path.join(root_path, cfg['OUTPUT']['figs_dir'], 'bucket_metrics_bar.png')
plt.savefig(fig_bucket, bbox_inches='tight')
plt.close()
log_info(f'【步骤4摘要】桶树划分完成，共有 {bucket_ids_full.nunique()} 个叶子桶。')
# Out:
# 【INFO】【2025-12-11 19:36:50】【桶树】已为样本生成桶ID，共 35 个组合
#                                            bucket_id  count  pos_rate
# 0  L1_Contract=month_to_month|L2_tenure=new|L3_In...    916  1.000000
# 1  L1_Contract=month_to_month|L2_tenure=mid_term|...    695  0.000000
# 2  L1_Contract=month_to_month|L2_tenure=new|L3_In...    690  0.250000
# 3  L1_Contract=month_to_month|L2_tenure=short_ter...    425  0.036364
# 4  L1_Contract=two_year|L2_tenure=long_term|L3_In...    402  0.160839
# 【INFO】【2025-12-11 19:36:50】【步骤4摘要】桶树划分完成，共有 35 个叶子桶。

# %%
# 步骤5：运行基线模型 k 折实验
# 基线部分在 run_kfold_experiments 内统一调度
log_info('【步骤5】基线模型将在整体交叉验证中一并运行。')
log_info('【步骤5摘要】基线模型性能将作为后续对比基准。')
# Out:
# 【INFO】【2025-12-11 19:36:50】【步骤5】基线模型将在整体交叉验证中一并运行。
# 【INFO】【2025-12-11 19:36:50】【步骤5摘要】基线模型性能将作为后续对比基准。

# %%
import numpy as np
import pandas as pd

print("y 全局标签分布：", np.unique(y, return_counts=True))

print("原始标签列分布：")
print(df_raw[cfg['DATA']['target_col']].value_counts())
# Out:
# y 全局标签分布： (array([0, 1]), array([5174, 1869], dtype=int64))
# 原始标签列分布：
# Churn
# 0    5174
# 1    1869
# Name: count, dtype: int64

# %%
# 步骤6：运行 BTTWD k 折实验（含基线）
results = run_kfold_experiments(X, y, df_raw.drop(columns=[cfg['DATA']['target_col']]), cfg)
summary_df = pd.read_csv(os.path.join(root_path, cfg['OUTPUT']['results_dir'], 'metrics_kfold_summary.csv'))
display(summary_df)
summary_df.plot(x='model', kind='bar', figsize=(8,4), title='模型指标对比')
fig_compare = os.path.join(root_path, cfg['OUTPUT']['figs_dir'], 'metrics_compare.png')
plt.savefig(fig_compare, bbox_inches='tight')
plt.close()
log_info('【步骤6摘要】BTTWD 与基线的 k 折结果已生成并保存。')
# Out:
# 【INFO】【2025-12-11 19:36:51】【基线-LogReg】使用决策阈值=0.200（fixed 模式）
# e:\yan\组\三支决策\机器学习\BT_TWD\bttwdlib\baselines.py:103: RuntimeWarning: Mean of empty slice
#   summary[f"{col}_mean"] = float(np.nanmean(arr))
# d:\Anaconda3\Lib\site-packages\numpy\lib\nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# 【INFO】【2025-12-11 19:36:51】【基线-LogReg】整体指标：AUC_mean=0.845, AUC_std=0.013, BAC_mean=0.756, BAC_std=0.013, BND_ratio_mean=0.000, BND_ratio_std=0.000, F1_mean=0.610, F1_std=0.014, Kappa_mean=0.405, Kappa_std=0.022, MCC_mean=0.453, MCC_std=0.022, POS_Coverage_mean=nan, POS_Coverage_std=nan, Precision_mean=0.471, Precision_std=0.013, Recall_mean=0.863, Recall_std=0.015, Regret_mean=0.439, Regret_std=0.027
# 【INFO】【2025-12-11 19:36:51】【基线-RF】使用决策阈值=0.200（fixed 模式）
# e:\yan\组\三支决策\机器学习\BT_TWD\bttwdlib\baselines.py:103: RuntimeWarning: Mean of empty slice
#   summary[f"{col}_mean"] = float(np.nanmean(arr))
# d:\Anaconda3\Lib\site-packages\numpy\lib\nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# 【INFO】【2025-12-11 19:36:54】【基线-RF】整体指标：AUC_mean=0.825, AUC_std=0.013, BAC_mean=0.743, BAC_std=0.008, BND_ratio_mean=0.000, BND_ratio_std=0.000, F1_mean=0.596, F1_std=0.009, Kappa_mean=0.385, Kappa_std=0.015, MCC_mean=0.429, MCC_std=0.015, POS_Coverage_mean=nan, POS_Coverage_std=nan, Precision_mean=0.462, Precision_std=0.009, Recall_mean=0.839, Recall_std=0.012, Regret_mean=0.473, Regret_std=0.018
# 【INFO】【2025-12-11 19:36:54】【基线-KNN】使用决策阈值=0.200（fixed 模式）
# e:\yan\组\三支决策\机器学习\BT_TWD\bttwdlib\baselines.py:103: RuntimeWarning: Mean of empty slice
#   summary[f"{col}_mean"] = float(np.nanmean(arr))
# d:\Anaconda3\Lib\site-packages\numpy\lib\nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# C:\Users\xzq20.HUANLI\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:158: UserWarning: [19:36:56] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 【INFO】【2025-12-11 19:36:56】【基线-KNN】整体指标：AUC_mean=0.790, AUC_std=0.018, BAC_mean=0.726, BAC_std=0.011, BND_ratio_mean=0.000, BND_ratio_std=0.000, F1_mean=0.580, F1_std=0.012, Kappa_mean=0.367, Kappa_std=0.018, MCC_mean=0.401, MCC_std=0.019, POS_Coverage_mean=nan, POS_Coverage_std=nan, Precision_mean=0.457, Precision_std=0.010, Recall_mean=0.792, Recall_std=0.021, Regret_mean=0.526, Regret_std=0.027
# 【INFO】【2025-12-11 19:36:56】【基线-XGB】使用决策阈值=0.200（fixed 模式）
# C:\Users\xzq20.HUANLI\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:158: UserWarning: [19:36:57] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\xzq20.HUANLI\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:158: UserWarning: [19:37:00] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\xzq20.HUANLI\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:158: UserWarning: [19:37:00] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\xzq20.HUANLI\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:158: UserWarning: [19:37:12] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# e:\yan\组\三支决策\机器学习\BT_TWD\bttwdlib\baselines.py:103: RuntimeWarning: Mean of empty slice
#   summary[f"{col}_mean"] = float(np.nanmean(arr))
# d:\Anaconda3\Lib\site-packages\numpy\lib\nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# C:\Users\xzq20.HUANLI\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:158: UserWarning: [19:37:13] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 【INFO】【2025-12-11 19:37:13】【基线-XGB】整体指标：AUC_mean=0.835, AUC_std=0.009, BAC_mean=0.753, BAC_std=0.008, BND_ratio_mean=0.000, BND_ratio_std=0.000, F1_mean=0.609, F1_std=0.009, Kappa_mean=0.412, Kappa_std=0.015, MCC_mean=0.449, MCC_std=0.015, POS_Coverage_mean=nan, POS_Coverage_std=nan, Precision_mean=0.482, Precision_std=0.010, Recall_mean=0.829, Recall_std=0.010, Regret_mean=0.464, Regret_std=0.017
# 【INFO】【2025-12-11 19:37:13】【K折实验】正在执行第 1/5 折...
# 【INFO】【2025-12-11 19:37:13】[BT] 使用桶评分配置：mode=f1_regret_bnd, f1_weight=1.0, regret_weight=1.0, bnd_weight=0.5
# 【INFO】【2025-12-11 19:37:16】【BTTWD】全局模型训练完成，用于兜底预测
# [INFO][BT][2025-12-11 19:37:17] 创建桶 bucket_id=ROOT，level=0，parent_id=ROOT，split_name=ROOT，split_type=ROOT，split_rule="all"，n_samples=5634
# [INFO][BT][2025-12-11 19:37:17] 创建桶 bucket_id=L1_Contract=month_to_month，level=1，parent_id=ROOT，split_name=L1_Contract，split_type=categorical_group，split_rule="month_to_month"，n_samples=3108
# [INFO][BT][2025-12-11 19:37:17] 创建桶 bucket_id=L1_Contract=one_year，level=1，parent_id=ROOT，split_name=L1_Contract，split_type=categorical_group，split_rule="one_year"，n_samples=1182
# [INFO][BT][2025-12-11 19:37:17] 创建桶 bucket_id=L1_Contract=two_year，level=1，parent_id=ROOT，split_name=L1_Contract，split_type=categorical_group，split_rule="two_year"，n_samples=1344
# [INFO][BT][2025-12-11 19:37:17] 创建桶 bucket_id=L1_Contract=month_to_month|L2_tenure=long_term，level=2，parent_id=L1_Contract=month_to_month，split_name=L2_tenure，split_type=numeric_bin，split_rule="long_term"，n_samples=91
# [INFO][BT][2025-12-11 19:37:17] 创建桶 bucket_id=L1_Contract=month_to_month|L2_tenure=mid_term，level=2，parent_id=L1_Contract=month_to_month，split_name=L2_tenure，split_type=numeric_bin，split_rule="mid_term"，n_samples=826
# [INFO][BT][2025-12-11 19:37:17] 创建桶 bucket_id=L1_Contract=month_to_month|L2_tenure=new，level=2，parent_id=L1_Contract=month_to_month，split_name=L2_tenure，split_type=numeric_bin，split_rule="new"，n_samples=1613
# [INFO][BT][2025-12-11 19:37:17] 创建桶 bucket_id=L1_Contract=month_to_month|L2_tenure=short_term，level=2，parent_id=L1_Contract=month_to_month，split_name=L2_tenure，split_type=numeric_bin，split_rule="short_term"，n_samples=578
# [INFO][BT][2025-12-11 19:37:17] 创建桶 bucket_id=L1_Contract=one_year|L2_tenure=long_term，level=2，parent_id=L1_Contract=one_year，split_name=L2_tenure，split_type=numeric_bin，split_rule="long_term"，n_samples=255
# [INFO][BT][2025-12-11 19:37:17] 创建桶 bucket_id=L1_Contract=one_year|L2_tenure=mid_term，level=2，parent_id=L1_Contract=one_year，split_name=L2_tenure，split_type=numeric_bin，split_rule="mid_term"，n_samples=669
# [INFO][BT][2025-12-11 19:37:17] 创建桶 bucket_id=L1_Contract=one_year|L2_tenure=new，level=2，parent_id=L1_Contract=one_year，split_name=L2_tenure，split_type=numeric_bin，split_rule="new"，n_samples=99
# [INFO][BT][2025-12-11 19:37:17] 创建桶 bucket_id=L1_Contract=one_year|L2_tenure=short_term，level=2，parent_id=L1_Contract=one_year，split_name=L2_tenure，split_type=numeric_bin，split_rule="short_term"，n_samples=159
# [INFO][BT][2025-12-11 19:37:17] 创建桶 bucket_id=L1_Contract=two_year|L2_tenure=long_term，level=2，parent_id=L1_Contract=two_year，split_name=L2_tenure，split_type=numeric_bin，split_rule="long_term"，n_samples=778
# [INFO][BT][2025-12-11 19:37:17] 创建桶 bucket_id=L1_Contract=two_year|L2_tenure=mid_term，level=2，parent_id=L1_Contract=two_year，split_name=L2_tenure，split_type=numeric_bin，split_rule="mid_term"，n_samples=447
# [INFO][BT][2025-12-11 19:37:17] 创建桶 bucket_id=L1_Contract=two_year|L2_tenure=short_term，level=2，parent_id=L1_Contract=two_year，split_name=L2_tenure，split_type=numeric_bin，split_rule="short_term"，n_samples=67
# [INFO][BT][2025-12-11 19:37:17] 创建桶 bucket_id=L1_Contract=two_year|L2_tenure=others，level=2，parent_id=L1_Contract=two_year，split_name=L2_tenure，split_type=numeric_bin，split_rule="others"，n_samples=52
# [INFO][BT][2025-12-11 19:37:17] 创建桶 bucket_id=L1_Contract=month_to_month|L2_tenure=long_term|L3_InternetService=fiber，level=3，parent_id=L1_Contract=month_to_month|L2_tenure=long_term，split_name=L3_InternetService，split_type=categorical_group，split_rule="fiber"，n_samples=77
# [INFO][BT][2025-12-11 19:37:17] 创建桶 bucket_id=L1_Contract=month_to_month|L2_tenure=long_term|L3_InternetService=others，level=3，parent_id=L1_Contract=month_to_month|L2_tenure=long_term，split_name=L3_InternetService，split_type=categorical_group，split_rule="others"，n_samples=14
# [INFO][BT][2025-12-11 19:37:17] 创建桶 bucket_id=L1_Contract=month_to_month|L2_tenure=mid_term|L3_InternetService=dsl，level=3，parent_id=L1_Contract=month_to_month|L2_tenure=mid_term，split_name=L3_InternetService，split_type=categorical_group，split_rule="dsl"，n_samples=223
# [INFO][BT][2025-12-11 19:37:17] 创建桶 bucket_id=L1_Contract=month_to_month|L2_tenure=mid_term|L3_InternetService=fiber，level=3，parent_id=L1_Contract=month_to_month|L2_tenure=mid_term，split_name=L3_InternetService，split_type=categorical_group，split_rule="fiber"，n_samples=562
# [INFO][BT][2025-12-11 19:37:17] 创建桶 bucket_id=L1_Contract=month_to_month|L2_tenure=mid_term|L3_InternetService=others，level=3，parent_id=L1_Contract=month_to_month|L2_tenure=mid_term，split_name=L3_InternetService，split_type=categorical_group，split_rule="others"，n_samples=41
# [INFO][BT][2025-12-11 19:37:17] 创建桶 bucket_id=L1_Contract=month_to_month|L2_tenure=new|L3_InternetService=OTHER，level=3，parent_id=L1_Contract=month_to_month|L2_tenure=new，split_name=L3_InternetService，split_type=categorical_group，split_rule="OTHER"，n_samples=315
# [INFO][BT][2025-12-11 19:37:17] 创建桶 bucket_id=L1_Contract=month_to_month|L2_tenure=new|L3_InternetService=dsl，level=3，parent_id=L1_Contract=month_to_month|L2_tenure=new，split_name=L3_InternetService，split_type=categorical_group，split_rule="dsl"，n_samples=568
# [INFO][BT][2025-12-11 19:37:17] 创建桶 bucket_id=L1_Contract=month_to_month|L2_tenure=new|L3_InternetService=fiber，level=3，parent_id=L1_Contract=month_to_month|L2_tenure=new，split_name=L3_InternetService，split_type=categorical_group，split_rule="fiber"，n_samples=730
# [INFO][BT][2025-12-11 19:37:17] 创建桶 bucket_id=L1_Contract=month_to_month|L2_tenure=short_term|L3_InternetService=OTHER，level=3，parent_id=L1_Contract=month_to_month|L2_tenure=short_term，split_name=L3_InternetService，split_type=categorical_group，split_rule="OTHER"，n_samples=67
# [INFO][BT][2025-12-11 19:37:17] 创建桶 bucket_id=L1_Contract=month_to_month|L2_tenure=short_term|L3_InternetService=dsl，level=3，parent_id=L1_Contract=month_to_month|L2_tenure=short_term，split_name=L3_InternetService，split_type=categorical_group，split_rule="dsl"，n_samples=172
# [INFO][BT][2025-12-11 19:37:17] 创建桶 bucket_id=L1_Contract=month_to_month|L2_tenure=short_term|L3_InternetService=fiber，level=3，parent_id=L1_Contract=month_to_month|L2_tenure=short_term，split_name=L3_InternetService，split_type=categorical_group，split_rule="fiber"，n_samples=339
# [INFO][BT][2025-12-11 19:37:17] 创建桶 bucket_id=L1_Contract=one_year|L2_tenure=long_term|L3_InternetService=dsl，level=3，parent_id=L1_Contract=one_year|L2_tenure=long_term，split_name=L3_InternetService，split_type=categorical_group，split_rule="dsl"，n_samples=74
# [INFO][BT][2025-12-11 19:37:17] 创建桶 bucket_id=L1_Contract=one_year|L2_tenure=long_term|L3_InternetService=fiber，level=3，parent_id=L1_Contract=one_year|L2_tenure=long_term，split_name=L3_InternetService，split_type=categorical_group，split_rule="fiber"，n_samples=157
# [INFO][BT][2025-12-11 19:37:17] 创建桶 bucket_id=L1_Contract=one_year|L2_tenure=long_term|L3_InternetService=others，level=3，parent_id=L1_Contract=one_year|L2_tenure=long_term，split_name=L3_InternetService，split_type=categorical_group，split_rule="others"，n_samples=24
# [INFO][BT][2025-12-11 19:37:17] 创建桶 bucket_id=L1_Contract=one_year|L2_tenure=mid_term|L3_InternetService=OTHER，level=3，parent_id=L1_Contract=one_year|L2_tenure=mid_term，split_name=L3_InternetService，split_type=categorical_group，split_rule="OTHER"，n_samples=134
# [INFO][BT][2025-12-11 19:37:17] 创建桶 bucket_id=L1_Contract=one_year|L2_tenure=mid_term|L3_InternetService=dsl，level=3，parent_id=L1_Contract=one_year|L2_tenure=mid_term，split_name=L3_InternetService，split_type=categorical_group，split_rule="dsl"，n_samples=285
# [INFO][BT][2025-12-11 19:37:17] 创建桶 bucket_id=L1_Contract=one_year|L2_tenure=mid_term|L3_InternetService=fiber，level=3，parent_id=L1_Contract=one_year|L2_tenure=mid_term，split_name=L3_InternetService，split_type=categorical_group，split_rule="fiber"，n_samples=250
# [INFO][BT][2025-12-11 19:37:17] 创建桶 bucket_id=L1_Contract=one_year|L2_tenure=new|L3_InternetService=OTHER，level=3，parent_id=L1_Contract=one_year|L2_tenure=new，split_name=L3_InternetService，split_type=categorical_group，split_rule="OTHER"，n_samples=62
# [INFO][BT][2025-12-11 19:37:17] 创建桶 bucket_id=L1_Contract=one_year|L2_tenure=new|L3_InternetService=others，level=3，parent_id=L1_Contract=one_year|L2_tenure=new，split_name=L3_InternetService，split_type=categorical_group，split_rule="others"，n_samples=37
# [INFO][BT][2025-12-11 19:37:17] 创建桶 bucket_id=L1_Contract=one_year|L2_tenure=short_term|L3_InternetService=OTHER，level=3，parent_id=L1_Contract=one_year|L2_tenure=short_term，split_name=L3_InternetService，split_type=categorical_group，split_rule="OTHER"，n_samples=75
# [INFO][BT][2025-12-11 19:37:17] 创建桶 bucket_id=L1_Contract=one_year|L2_tenure=short_term|L3_InternetService=dsl，level=3，parent_id=L1_Contract=one_year|L2_tenure=short_term，split_name=L3_InternetService，split_type=categorical_group，split_rule="dsl"，n_samples=65
# [INFO][BT][2025-12-11 19:37:17] 创建桶 bucket_id=L1_Contract=one_year|L2_tenure=short_term|L3_InternetService=others，level=3，parent_id=L1_Contract=one_year|L2_tenure=short_term，split_name=L3_InternetService，split_type=categorical_group，split_rule="others"，n_samples=19
# [INFO][BT][2025-12-11 19:37:17] 创建桶 bucket_id=L1_Contract=two_year|L2_tenure=long_term|L3_InternetService=OTHER，level=3，parent_id=L1_Contract=two_year|L2_tenure=long_term，split_name=L3_InternetService，split_type=categorical_group，split_rule="OTHER"，n_samples=190
# [INFO][BT][2025-12-11 19:37:17] 创建桶 bucket_id=L1_Contract=two_year|L2_tenure=long_term|L3_InternetService=dsl，level=3，parent_id=L1_Contract=two_year|L2_tenure=long_term，split_name=L3_InternetService，split_type=categorical_group，split_rule="dsl"，n_samples=318
# [INFO][BT][2025-12-11 19:37:17] 创建桶 bucket_id=L1_Contract=two_year|L2_tenure=long_term|L3_InternetService=fiber，level=3，parent_id=L1_Contract=two_year|L2_tenure=long_term，split_name=L3_InternetService，split_type=categorical_group，split_rule="fiber"，n_samples=270
# [INFO][BT][2025-12-11 19:37:17] 创建桶 bucket_id=L1_Contract=two_year|L2_tenure=mid_term|L3_InternetService=OTHER，level=3，parent_id=L1_Contract=two_year|L2_tenure=mid_term，split_name=L3_InternetService，split_type=categorical_group，split_rule="OTHER"，n_samples=221
# [INFO][BT][2025-12-11 19:37:17] 创建桶 bucket_id=L1_Contract=two_year|L2_tenure=mid_term|L3_InternetService=dsl，level=3，parent_id=L1_Contract=two_year|L2_tenure=mid_term，split_name=L3_InternetService，split_type=categorical_group，split_rule="dsl"，n_samples=153
# [INFO][BT][2025-12-11 19:37:17] 创建桶 bucket_id=L1_Contract=two_year|L2_tenure=mid_term|L3_InternetService=fiber，level=3，parent_id=L1_Contract=two_year|L2_tenure=mid_term，split_name=L3_InternetService，split_type=categorical_group，split_rule="fiber"，n_samples=73
# [INFO][BT][2025-12-11 19:37:17] 桶 bucket_id=L1_Contract=two_year|L2_tenure=short_term 样本不足（n=67 < min_bucket_size=60），不再细分
# [INFO][BT][2025-12-11 19:37:18] 桶树构建完成：总桶数=44，最大层数=3，叶子桶数=30
# 【INFO】【2025-12-11 19:37:18】【BTTWD】bucket_estimator=none：不训练桶内局部模型，仅使用全局模型概率做桶内阈值搜索
# e:\yan\组\三支决策\机器学习\BT_TWD\bttwdlib\bucket_gain.py:27: RuntimeWarning: compute_bucket_score: metric 'F1' is missing or NaN, defaulting to 0.0.
#   warnings.warn(
# e:\yan\组\三支决策\机器学习\BT_TWD\bttwdlib\bucket_gain.py:27: RuntimeWarning: compute_bucket_score: metric 'BND_ratio' is missing or NaN, defaulting to 0.0.
#   warnings.warn(
# 【INFO】【2025-12-11 19:37:18】【阈值】桶 ROOT（n_val=337）使用本地阈值 α=0.4000, β=0.2000
# [INFO][BT][2025-12-11 19:37:18] 桶 bucket_id=ROOT level=0：
#     n_train=788, n_val=337,
#     BAC=0.659, F1=0.568, AUC=0.822,
#     Regret=0.441, BND_ratio=0.151, POS_coverage=0.303,
#     Score(f1_regret_bnd )=0.052
# 【INFO】【2025-12-11 19:37:18】【阈值】桶 L1_Contract=month_to_month 标记为弱桶，阈值将回退使用 ROOT 的阈值
# [INFO][BT][2025-12-11 19:37:18] 桶 bucket_id=L1_Contract=month_to_month level=1：
#     n_train=434, n_val=198,
#     BAC=0.448, F1=0.619, AUC=0.728,
#     Regret=0.561, BND_ratio=0.263, POS_coverage=0.737,
#     Score(f1_regret_bnd )=-0.073
# [INFO][BT][2025-12-11 19:37:18] 桶 bucket_id=L1_Contract=month_to_month：
#     parent_id=ROOT，parent_Score=0.052, bucket_Score=-0.073,
#     Gain=-0.125, is_weak=True
# 【INFO】【2025-12-11 19:37:19】【阈值】桶 L1_Contract=one_year 标记为弱桶，阈值将回退使用 ROOT 的阈值
# [INFO][BT][2025-12-11 19:37:19] 桶 bucket_id=L1_Contract=one_year level=1：
#     n_train=165, n_val=126,
#     BAC=0.345, F1=0.000, AUC=0.653,
#     Regret=0.520, BND_ratio=0.341, POS_coverage=0.000,
#     Score(f1_regret_bnd )=-0.690
# [INFO][BT][2025-12-11 19:37:19] 桶 bucket_id=L1_Contract=one_year：
#     parent_id=ROOT，parent_Score=0.052, bucket_Score=-0.690,
#     Gain=-0.742, is_weak=True
# 【INFO】【2025-12-11 19:37:19】【阈值】桶 L1_Contract=two_year 标记为弱桶，阈值将回退使用 ROOT 的阈值
# [INFO][BT][2025-12-11 19:37:19] 桶 bucket_id=L1_Contract=two_year level=1：
#     n_train=252, n_val=111,
#     BAC=nan, F1=nan, AUC=nan,
#     Regret=nan, BND_ratio=nan, POS_coverage=nan,
#     Score(f1_regret_bnd )=nan
# [INFO][BT][2025-12-11 19:37:19] 桶 bucket_id=L1_Contract=two_year：
#     parent_id=ROOT，parent_Score=0.052, bucket_Score=nan,
#     Gain=+nan, is_weak=True
# 【INFO】【2025-12-11 19:37:19】【阈值】桶 L1_Contract=month_to_month|L2_tenure=long_term 标记为弱桶，阈值将回退使用 L1_Contract=month_to_month 的阈值
# [INFO][BT][2025-12-11 19:37:19] 桶 bucket_id=L1_Contract=month_to_month|L2_tenure=long_term level=2：
#     n_train=74, n_val=17,
#     BAC=nan, F1=nan, AUC=nan,
#     Regret=nan, BND_ratio=nan, POS_coverage=nan,
#     Score(f1_regret_bnd )=nan
# [INFO][BT][2025-12-11 19:37:19] 桶 bucket_id=L1_Contract=month_to_month|L2_tenure=long_term：
#     parent_id=L1_Contract=month_to_month，parent_Score=-0.073, bucket_Score=nan,
#     Gain=+nan, is_weak=True
# 【INFO】【2025-12-11 19:37:19】【阈值】桶 L1_Contract=month_to_month|L2_tenure=mid_term 标记为弱桶，阈值将回退使用 L1_Contract=month_to_month 的阈值
# [INFO][BT][2025-12-11 19:37:19] 桶 bucket_id=L1_Contract=month_to_month|L2_tenure=mid_term level=2：
#     n_train=141, n_val=56,
#     BAC=0.167, F1=0.500, AUC=0.682,
#     Regret=0.607, BND_ratio=0.929, POS_coverage=0.071,
#     Score(f1_regret_bnd )=-0.571
# [INFO][BT][2025-12-11 19:37:19] 桶 bucket_id=L1_Contract=month_to_month|L2_tenure=mid_term：
#     parent_id=L1_Contract=month_to_month，parent_Score=-0.073, bucket_Score=-0.571,
#     Gain=-0.498, is_weak=True
# 【INFO】【2025-12-11 19:37:19】【阈值】桶 L1_Contract=month_to_month|L2_tenure=new（n_val=96）使用本地阈值 α=0.2000, β=0.0000
# [INFO][BT][2025-12-11 19:37:19] 桶 bucket_id=L1_Contract=month_to_month|L2_tenure=new level=2：
#     n_train=224, n_val=96,
#     BAC=0.468, F1=0.704, AUC=0.741,
#     Regret=0.479, BND_ratio=0.188, POS_coverage=0.812,
#     Score(f1_regret_bnd )=0.131
# [INFO][BT][2025-12-11 19:37:19] 桶 bucket_id=L1_Contract=month_to_month|L2_tenure=new：
#     parent_id=L1_Contract=month_to_month，parent_Score=-0.073, bucket_Score=0.131,
#     Gain=+0.204, is_weak=False
# 【INFO】【2025-12-11 19:37:20】【阈值】桶 L1_Contract=month_to_month|L2_tenure=short_term 标记为弱桶，阈值将回退使用 L1_Contract=month_to_month 的阈值
# [INFO][BT][2025-12-11 19:37:20] 桶 bucket_id=L1_Contract=month_to_month|L2_tenure=short_term level=2：
#     n_train=117, n_val=97,
#     BAC=0.346, F1=0.480, AUC=0.631,
#     Regret=0.649, BND_ratio=0.495, POS_coverage=0.505,
#     Score(f1_regret_bnd )=-0.417
# [INFO][BT][2025-12-11 19:37:20] 桶 bucket_id=L1_Contract=month_to_month|L2_tenure=short_term：
#     parent_id=L1_Contract=month_to_month，parent_Score=-0.073, bucket_Score=-0.417,
#     Gain=-0.344, is_weak=True
# 【INFO】【2025-12-11 19:37:20】【阈值】桶 L1_Contract=one_year|L2_tenure=long_term（n_val=78）使用本地阈值 α=0.5000, β=0.4000
# [INFO][BT][2025-12-11 19:37:20] 桶 bucket_id=L1_Contract=one_year|L2_tenure=long_term level=2：
#     n_train=89, n_val=78,
#     BAC=0.557, F1=0.222, AUC=0.726,
#     Regret=0.359, BND_ratio=0.026, POS_coverage=0.026,
#     Score(f1_regret_bnd )=-0.150
# [INFO][BT][2025-12-11 19:37:20] 桶 bucket_id=L1_Contract=one_year|L2_tenure=long_term：
#     parent_id=L1_Contract=one_year，parent_Score=-0.690, bucket_Score=-0.150,
#     Gain=+0.541, is_weak=False
# 【INFO】【2025-12-11 19:37:20】【阈值】桶 L1_Contract=one_year|L2_tenure=mid_term（n_val=64）使用本地阈值 α=0.7000, β=0.6000
# [INFO][BT][2025-12-11 19:37:20] 桶 bucket_id=L1_Contract=one_year|L2_tenure=mid_term level=2：
#     n_train=94, n_val=64,
#     BAC=0.500, F1=0.000, AUC=0.671,
#     Regret=0.391, BND_ratio=0.000, POS_coverage=0.000,
#     Score(f1_regret_bnd )=-0.391
# [INFO][BT][2025-12-11 19:37:20] 桶 bucket_id=L1_Contract=one_year|L2_tenure=mid_term：
#     parent_id=L1_Contract=one_year，parent_Score=-0.690, bucket_Score=-0.391,
#     Gain=+0.300, is_weak=False
# 【INFO】【2025-12-11 19:37:20】【阈值】桶 L1_Contract=one_year|L2_tenure=new（n_val=31）使用本地阈值 α=0.3000, β=0.1000
# [INFO][BT][2025-12-11 19:37:20] 桶 bucket_id=L1_Contract=one_year|L2_tenure=new level=2：
#     n_train=68, n_val=31,
#     BAC=0.514, F1=0.333, AUC=0.778,
#     Regret=0.371, BND_ratio=0.226, POS_coverage=0.065,
#     Score(f1_regret_bnd )=-0.151
# [INFO][BT][2025-12-11 19:37:20] 桶 bucket_id=L1_Contract=one_year|L2_tenure=new：
#     parent_id=L1_Contract=one_year，parent_Score=-0.690, bucket_Score=-0.151,
#     Gain=+0.540, is_weak=False
# 【INFO】【2025-12-11 19:37:21】【阈值】桶 L1_Contract=one_year|L2_tenure=short_term（n_val=41）使用本地阈值 α=0.2000, β=0.1000
# [INFO][BT][2025-12-11 19:37:21] 桶 bucket_id=L1_Contract=one_year|L2_tenure=short_term level=2：
#     n_train=118, n_val=41,
#     BAC=0.403, F1=0.000, AUC=0.678,
#     Regret=0.524, BND_ratio=0.220, POS_coverage=0.000,
#     Score(f1_regret_bnd )=-0.634
# [INFO][BT][2025-12-11 19:37:21] 桶 bucket_id=L1_Contract=one_year|L2_tenure=short_term：
#     parent_id=L1_Contract=one_year，parent_Score=-0.690, bucket_Score=-0.634,
#     Gain=+0.056, is_weak=False
# 【INFO】【2025-12-11 19:37:21】【阈值】桶 L1_Contract=two_year|L2_tenure=long_term（n_val=236）使用本地阈值 α=0.7000, β=0.2000
# [INFO][BT][2025-12-11 19:37:21] 桶 bucket_id=L1_Contract=two_year|L2_tenure=long_term level=2：
#     n_train=107, n_val=236,
#     BAC=0.491, F1=0.000, AUC=0.808,
#     Regret=0.212, BND_ratio=0.025, POS_coverage=0.000,
#     Score(f1_regret_bnd )=-0.225
# [INFO][BT][2025-12-11 19:37:21] 桶 bucket_id=L1_Contract=two_year|L2_tenure=long_term：
#     parent_id=L1_Contract=two_year，parent_Score=-0.440, bucket_Score=-0.225,
#     Gain=+0.215, is_weak=False
# 【INFO】【2025-12-11 19:37:21】【阈值】桶 L1_Contract=two_year|L2_tenure=mid_term（n_val=84）使用本地阈值 α=0.5000, β=0.4000
# [INFO][BT][2025-12-11 19:37:21] 桶 bucket_id=L1_Contract=two_year|L2_tenure=mid_term level=2：
#     n_train=98, n_val=84,
#     BAC=0.500, F1=0.000, AUC=0.651,
#     Regret=0.060, BND_ratio=0.000, POS_coverage=0.000,
#     Score(f1_regret_bnd )=-0.060
# [INFO][BT][2025-12-11 19:37:21] 桶 bucket_id=L1_Contract=two_year|L2_tenure=mid_term：
#     parent_id=L1_Contract=two_year，parent_Score=-0.440, bucket_Score=-0.060,
#     Gain=+0.380, is_weak=False
# 【INFO】【2025-12-11 19:37:21】【阈值】桶 L1_Contract=two_year|L2_tenure=short_term 标记为弱桶，阈值将回退使用 L1_Contract=two_year 的阈值
# [INFO][BT][2025-12-11 19:37:21] 桶 bucket_id=L1_Contract=two_year|L2_tenure=short_term level=2：
#     n_train=46, n_val=21,
#     BAC=nan, F1=nan, AUC=nan,
#     Regret=nan, BND_ratio=nan, POS_coverage=nan,
#     Score(f1_regret_bnd )=nan
# [INFO][BT][2025-12-11 19:37:21] 桶 bucket_id=L1_Contract=two_year|L2_tenure=short_term：
#     parent_id=L1_Contract=two_year，parent_Score=-0.440, bucket_Score=nan,
#     Gain=+nan, is_weak=True
# 【INFO】【2025-12-11 19:37:21】【阈值】桶 L1_Contract=two_year|L2_tenure=others 标记为弱桶，阈值将回退使用 L1_Contract=two_year 的阈值
# [INFO][BT][2025-12-11 19:37:21] 桶 bucket_id=L1_Contract=two_year|L2_tenure=others level=2：
#     n_train=38, n_val=14,
#     BAC=nan, F1=nan, AUC=nan,
#     Regret=nan, BND_ratio=nan, POS_coverage=nan,
#     Score(f1_regret_bnd )=nan
# [INFO][BT][2025-12-11 19:37:21] 桶 bucket_id=L1_Contract=two_year|L2_tenure=others：
#     parent_id=L1_Contract=two_year，parent_Score=-0.440, bucket_Score=nan,
#     Gain=+nan, is_weak=True
# 【INFO】【2025-12-11 19:37:21】【阈值】桶 L1_Contract=month_to_month|L2_tenure=long_term|L3_InternetService=fiber 标记为弱桶，阈值将回退使用 L1_Contract=month_to_month|L2_tenure=long_term 的阈值
# [INFO][BT][2025-12-11 19:37:21] 桶 bucket_id=L1_Contract=month_to_month|L2_tenure=long_term|L3_InternetService=fiber level=3：
#     n_train=64, n_val=13,
#     BAC=nan, F1=nan, AUC=nan,
#     Regret=nan, BND_ratio=nan, POS_coverage=nan,
#     Score(f1_regret_bnd )=nan
# [INFO][BT][2025-12-11 19:37:21] 桶 bucket_id=L1_Contract=month_to_month|L2_tenure=long_term|L3_InternetService=fiber：
#     parent_id=L1_Contract=month_to_month|L2_tenure=long_term，parent_Score=-0.440, bucket_Score=nan,
#     Gain=+nan, is_weak=True
# 【INFO】【2025-12-11 19:37:21】【阈值】桶 L1_Contract=month_to_month|L2_tenure=long_term|L3_InternetService=others 标记为弱桶，阈值将回退使用 L1_Contract=month_to_month|L2_tenure=long_term 的阈值
# [INFO][BT][2025-12-11 19:37:21] 桶 bucket_id=L1_Contract=month_to_month|L2_tenure=long_term|L3_InternetService=others level=3：
#     n_train=10, n_val=4,
#     BAC=nan, F1=nan, AUC=nan,
#     Regret=nan, BND_ratio=nan, POS_coverage=nan,
#     Score(f1_regret_bnd )=nan
# [INFO][BT][2025-12-11 19:37:21] 桶 bucket_id=L1_Contract=month_to_month|L2_tenure=long_term|L3_InternetService=others：
#     parent_id=L1_Contract=month_to_month|L2_tenure=long_term，parent_Score=-0.440, bucket_Score=nan,
#     Gain=+nan, is_weak=True
# 【INFO】【2025-12-11 19:37:21】【阈值】桶 L1_Contract=month_to_month|L2_tenure=mid_term|L3_InternetService=dsl（n_val=75）使用本地阈值 α=0.4000, β=0.2000
# [INFO][BT][2025-12-11 19:37:21] 桶 bucket_id=L1_Contract=month_to_month|L2_tenure=mid_term|L3_InternetService=dsl level=3：
#     n_train=148, n_val=75,
#     BAC=0.477, F1=0.267, AUC=0.594,
#     Regret=0.520, BND_ratio=0.213, POS_coverage=0.067,
#     Score(f1_regret_bnd )=-0.360
# [INFO][BT][2025-12-11 19:37:21] 桶 bucket_id=L1_Contract=month_to_month|L2_tenure=mid_term|L3_InternetService=dsl：
#     parent_id=L1_Contract=month_to_month|L2_tenure=mid_term，parent_Score=-0.571, bucket_Score=-0.360,
#     Gain=+0.211, is_weak=False
# 【INFO】【2025-12-11 19:37:22】【阈值】桶 L1_Contract=month_to_month|L2_tenure=mid_term|L3_InternetService=fiber（n_val=160）使用本地阈值 α=0.2000, β=0.0000
# [INFO][BT][2025-12-11 19:37:22] 桶 bucket_id=L1_Contract=month_to_month|L2_tenure=mid_term|L3_InternetService=fiber level=3：
#     n_train=402, n_val=160,
#     BAC=0.474, F1=0.579, AUC=0.661,
#     Regret=0.588, BND_ratio=0.175, POS_coverage=0.825,
#     Score(f1_regret_bnd )=-0.096
# [INFO][BT][2025-12-11 19:37:22] 桶 bucket_id=L1_Contract=month_to_month|L2_tenure=mid_term|L3_InternetService=fiber：
#     parent_id=L1_Contract=month_to_month|L2_tenure=mid_term，parent_Score=-0.571, bucket_Score=-0.096,
#     Gain=+0.475, is_weak=False
# 【INFO】【2025-12-11 19:37:22】【阈值】桶 L1_Contract=month_to_month|L2_tenure=mid_term|L3_InternetService=others 标记为弱桶，阈值将回退使用 L1_Contract=month_to_month|L2_tenure=mid_term 的阈值
# [INFO][BT][2025-12-11 19:37:22] 桶 bucket_id=L1_Contract=month_to_month|L2_tenure=mid_term|L3_InternetService=others level=3：
#     n_train=32, n_val=9,
#     BAC=nan, F1=nan, AUC=nan,
#     Regret=nan, BND_ratio=nan, POS_coverage=nan,
#     Score(f1_regret_bnd )=nan
# [INFO][BT][2025-12-11 19:37:22] 桶 bucket_id=L1_Contract=month_to_month|L2_tenure=mid_term|L3_InternetService=others：
#     parent_id=L1_Contract=month_to_month|L2_tenure=mid_term，parent_Score=-0.571, bucket_Score=nan,
#     Gain=+nan, is_weak=True
# 【INFO】【2025-12-11 19:37:22】【阈值】桶 L1_Contract=month_to_month|L2_tenure=new|L3_InternetService=OTHER 标记为弱桶，阈值将回退使用 L1_Contract=month_to_month|L2_tenure=new 的阈值
# [INFO][BT][2025-12-11 19:37:22] 桶 bucket_id=L1_Contract=month_to_month|L2_tenure=new|L3_InternetService=OTHER level=3：
#     n_train=218, n_val=97,
#     BAC=0.292, F1=0.444, AUC=0.598,
#     Regret=0.660, BND_ratio=0.598, POS_coverage=0.402,
#     Score(f1_regret_bnd )=-0.514
# [INFO][BT][2025-12-11 19:37:22] 桶 bucket_id=L1_Contract=month_to_month|L2_tenure=new|L3_InternetService=OTHER：
#     parent_id=L1_Contract=month_to_month|L2_tenure=new，parent_Score=0.131, bucket_Score=-0.514,
#     Gain=-0.645, is_weak=True
# 【INFO】【2025-12-11 19:37:23】【阈值】桶 L1_Contract=month_to_month|L2_tenure=new|L3_InternetService=dsl 标记为弱桶，阈值将回退使用 L1_Contract=month_to_month|L2_tenure=new 的阈值
# [INFO][BT][2025-12-11 19:37:23] 桶 bucket_id=L1_Contract=month_to_month|L2_tenure=new|L3_InternetService=dsl level=3：
#     n_train=402, n_val=166,
#     BAC=0.479, F1=0.654, AUC=0.602,
#     Regret=0.521, BND_ratio=0.163, POS_coverage=0.837,
#     Score(f1_regret_bnd )=0.052
# [INFO][BT][2025-12-11 19:37:23] 桶 bucket_id=L1_Contract=month_to_month|L2_tenure=new|L3_InternetService=dsl：
#     parent_id=L1_Contract=month_to_month|L2_tenure=new，parent_Score=0.131, bucket_Score=0.052,
#     Gain=-0.079, is_weak=True
# 【INFO】【2025-12-11 19:37:23】【阈值】桶 L1_Contract=month_to_month|L2_tenure=new|L3_InternetService=fiber（n_val=222）使用本地阈值 α=0.3000, β=0.0000
# [INFO][BT][2025-12-11 19:37:23] 桶 bucket_id=L1_Contract=month_to_month|L2_tenure=new|L3_InternetService=fiber level=3：
#     n_train=508, n_val=222,
#     BAC=0.497, F1=0.826, AUC=0.654,
#     Regret=0.302, BND_ratio=0.018, POS_coverage=0.982,
#     Score(f1_regret_bnd )=0.515
# [INFO][BT][2025-12-11 19:37:23] 桶 bucket_id=L1_Contract=month_to_month|L2_tenure=new|L3_InternetService=fiber：
#     parent_id=L1_Contract=month_to_month|L2_tenure=new，parent_Score=0.131, bucket_Score=0.515,
#     Gain=+0.384, is_weak=False
# 【INFO】【2025-12-11 19:37:23】【阈值】桶 L1_Contract=month_to_month|L2_tenure=short_term|L3_InternetService=OTHER 标记为弱桶，阈值将回退使用 L1_Contract=month_to_month|L2_tenure=short_term 的阈值
# [INFO][BT][2025-12-11 19:37:23] 桶 bucket_id=L1_Contract=month_to_month|L2_tenure=short_term|L3_InternetService=OTHER level=3：
#     n_train=48, n_val=19,
#     BAC=nan, F1=nan, AUC=nan,
#     Regret=nan, BND_ratio=nan, POS_coverage=nan,
#     Score(f1_regret_bnd )=nan
# [INFO][BT][2025-12-11 19:37:23] 桶 bucket_id=L1_Contract=month_to_month|L2_tenure=short_term|L3_InternetService=OTHER：
#     parent_id=L1_Contract=month_to_month|L2_tenure=short_term，parent_Score=-0.417, bucket_Score=nan,
#     Gain=+nan, is_weak=True
# 【INFO】【2025-12-11 19:37:23】【阈值】桶 L1_Contract=month_to_month|L2_tenure=short_term|L3_InternetService=dsl 标记为弱桶，阈值将回退使用 L1_Contract=month_to_month|L2_tenure=short_term 的阈值
# [INFO][BT][2025-12-11 19:37:23] 桶 bucket_id=L1_Contract=month_to_month|L2_tenure=short_term|L3_InternetService=dsl level=3：
#     n_train=115, n_val=57,
#     BAC=0.042, F1=0.133, AUC=0.465,
#     Regret=0.702, BND_ratio=0.947, POS_coverage=0.053,
#     Score(f1_regret_bnd )=-1.042
# [INFO][BT][2025-12-11 19:37:23] 桶 bucket_id=L1_Contract=month_to_month|L2_tenure=short_term|L3_InternetService=dsl：
#     parent_id=L1_Contract=month_to_month|L2_tenure=short_term，parent_Score=-0.417, bucket_Score=-1.042,
#     Gain=-0.625, is_weak=True
# 【INFO】【2025-12-11 19:37:24】【阈值】桶 L1_Contract=month_to_month|L2_tenure=short_term|L3_InternetService=fiber（n_val=106）使用本地阈值 α=0.1000, β=0.0000
# [INFO][BT][2025-12-11 19:37:24] 桶 bucket_id=L1_Contract=month_to_month|L2_tenure=short_term|L3_InternetService=fiber level=3：
#     n_train=233, n_val=106,
#     BAC=0.500, F1=0.691, AUC=0.608,
#     Regret=0.472, BND_ratio=0.000, POS_coverage=1.000,
#     Score(f1_regret_bnd )=0.220
# [INFO][BT][2025-12-11 19:37:24] 桶 bucket_id=L1_Contract=month_to_month|L2_tenure=short_term|L3_InternetService=fiber：
#     parent_id=L1_Contract=month_to_month|L2_tenure=short_term，parent_Score=-0.417, bucket_Score=0.220,
#     Gain=+0.637, is_weak=False
# 【INFO】【2025-12-11 19:37:24】【阈值】桶 L1_Contract=one_year|L2_tenure=long_term|L3_InternetService=dsl 标记为弱桶，阈值将回退使用 L1_Contract=one_year|L2_tenure=long_term 的阈值
# [INFO][BT][2025-12-11 19:37:24] 桶 bucket_id=L1_Contract=one_year|L2_tenure=long_term|L3_InternetService=dsl level=3：
#     n_train=56, n_val=18,
#     BAC=nan, F1=nan, AUC=nan,
#     Regret=nan, BND_ratio=nan, POS_coverage=nan,
#     Score(f1_regret_bnd )=nan
# [INFO][BT][2025-12-11 19:37:24] 桶 bucket_id=L1_Contract=one_year|L2_tenure=long_term|L3_InternetService=dsl：
#     parent_id=L1_Contract=one_year|L2_tenure=long_term，parent_Score=-0.150, bucket_Score=nan,
#     Gain=+nan, is_weak=True
# 【INFO】【2025-12-11 19:37:24】【阈值】桶 L1_Contract=one_year|L2_tenure=long_term|L3_InternetService=fiber 标记为弱桶，阈值将回退使用 L1_Contract=one_year|L2_tenure=long_term 的阈值
# [INFO][BT][2025-12-11 19:37:24] 桶 bucket_id=L1_Contract=one_year|L2_tenure=long_term|L3_InternetService=fiber level=3：
#     n_train=110, n_val=47,
#     BAC=0.559, F1=0.250, AUC=0.659,
#     Regret=0.489, BND_ratio=0.043, POS_coverage=0.043,
#     Score(f1_regret_bnd )=-0.261
# [INFO][BT][2025-12-11 19:37:24] 桶 bucket_id=L1_Contract=one_year|L2_tenure=long_term|L3_InternetService=fiber：
#     parent_id=L1_Contract=one_year|L2_tenure=long_term，parent_Score=-0.150, bucket_Score=-0.261,
#     Gain=-0.111, is_weak=True
# 【INFO】【2025-12-11 19:37:24】【阈值】桶 L1_Contract=one_year|L2_tenure=long_term|L3_InternetService=others 标记为弱桶，阈值将回退使用 L1_Contract=one_year|L2_tenure=long_term 的阈值
# [INFO][BT][2025-12-11 19:37:24] 桶 bucket_id=L1_Contract=one_year|L2_tenure=long_term|L3_InternetService=others level=3：
#     n_train=11, n_val=13,
#     BAC=nan, F1=nan, AUC=nan,
#     Regret=nan, BND_ratio=nan, POS_coverage=nan,
#     Score(f1_regret_bnd )=nan
# [INFO][BT][2025-12-11 19:37:24] 桶 bucket_id=L1_Contract=one_year|L2_tenure=long_term|L3_InternetService=others：
#     parent_id=L1_Contract=one_year|L2_tenure=long_term，parent_Score=-0.150, bucket_Score=nan,
#     Gain=+nan, is_weak=True
# 【INFO】【2025-12-11 19:37:24】【阈值】桶 L1_Contract=one_year|L2_tenure=mid_term|L3_InternetService=OTHER 标记为弱桶，阈值将回退使用 L1_Contract=one_year|L2_tenure=mid_term 的阈值
# [INFO][BT][2025-12-11 19:37:24] 桶 bucket_id=L1_Contract=one_year|L2_tenure=mid_term|L3_InternetService=OTHER level=3：
#     n_train=102, n_val=32,
#     BAC=nan, F1=nan, AUC=nan,
#     Regret=nan, BND_ratio=nan, POS_coverage=nan,
#     Score(f1_regret_bnd )=nan
# [INFO][BT][2025-12-11 19:37:24] 桶 bucket_id=L1_Contract=one_year|L2_tenure=mid_term|L3_InternetService=OTHER：
#     parent_id=L1_Contract=one_year|L2_tenure=mid_term，parent_Score=-0.391, bucket_Score=nan,
#     Gain=+nan, is_weak=True
# 【INFO】【2025-12-11 19:37:24】【阈值】桶 L1_Contract=one_year|L2_tenure=mid_term|L3_InternetService=dsl（n_val=85）使用本地阈值 α=0.6000, β=0.5000
# [INFO][BT][2025-12-11 19:37:24] 桶 bucket_id=L1_Contract=one_year|L2_tenure=mid_term|L3_InternetService=dsl level=3：
#     n_train=200, n_val=85,
#     BAC=0.500, F1=0.000, AUC=0.424,
#     Regret=0.353, BND_ratio=0.000, POS_coverage=0.000,
#     Score(f1_regret_bnd )=-0.353
# [INFO][BT][2025-12-11 19:37:24] 桶 bucket_id=L1_Contract=one_year|L2_tenure=mid_term|L3_InternetService=dsl：
#     parent_id=L1_Contract=one_year|L2_tenure=mid_term，parent_Score=-0.391, bucket_Score=-0.353,
#     Gain=+0.038, is_weak=False
# 【INFO】【2025-12-11 19:37:25】【阈值】桶 L1_Contract=one_year|L2_tenure=mid_term|L3_InternetService=fiber（n_val=78）使用本地阈值 α=0.1000, β=0.0000
# [INFO][BT][2025-12-11 19:37:25] 桶 bucket_id=L1_Contract=one_year|L2_tenure=mid_term|L3_InternetService=fiber level=3：
#     n_train=172, n_val=78,
#     BAC=0.386, F1=0.459, AUC=0.535,
#     Regret=0.679, BND_ratio=0.333, POS_coverage=0.667,
#     Score(f1_regret_bnd )=-0.387
# [INFO][BT][2025-12-11 19:37:25] 桶 bucket_id=L1_Contract=one_year|L2_tenure=mid_term|L3_InternetService=fiber：
#     parent_id=L1_Contract=one_year|L2_tenure=mid_term，parent_Score=-0.391, bucket_Score=-0.387,
#     Gain=+0.004, is_weak=False
# 【INFO】【2025-12-11 19:37:25】【阈值】桶 L1_Contract=one_year|L2_tenure=new|L3_InternetService=OTHER 标记为弱桶，阈值将回退使用 L1_Contract=one_year|L2_tenure=new 的阈值
# [INFO][BT][2025-12-11 19:37:25] 桶 bucket_id=L1_Contract=one_year|L2_tenure=new|L3_InternetService=OTHER level=3：
#     n_train=42, n_val=20,
#     BAC=nan, F1=nan, AUC=nan,
#     Regret=nan, BND_ratio=nan, POS_coverage=nan,
#     Score(f1_regret_bnd )=nan
# [INFO][BT][2025-12-11 19:37:25] 桶 bucket_id=L1_Contract=one_year|L2_tenure=new|L3_InternetService=OTHER：
#     parent_id=L1_Contract=one_year|L2_tenure=new，parent_Score=-0.151, bucket_Score=nan,
#     Gain=+nan, is_weak=True
# 【INFO】【2025-12-11 19:37:25】【阈值】桶 L1_Contract=one_year|L2_tenure=new|L3_InternetService=others 标记为弱桶，阈值将回退使用 L1_Contract=one_year|L2_tenure=new 的阈值
# [INFO][BT][2025-12-11 19:37:25] 桶 bucket_id=L1_Contract=one_year|L2_tenure=new|L3_InternetService=others level=3：
#     n_train=26, n_val=11,
#     BAC=nan, F1=nan, AUC=nan,
#     Regret=nan, BND_ratio=nan, POS_coverage=nan,
#     Score(f1_regret_bnd )=nan
# [INFO][BT][2025-12-11 19:37:25] 桶 bucket_id=L1_Contract=one_year|L2_tenure=new|L3_InternetService=others：
#     parent_id=L1_Contract=one_year|L2_tenure=new，parent_Score=-0.151, bucket_Score=nan,
#     Gain=+nan, is_weak=True
# 【INFO】【2025-12-11 19:37:25】【阈值】桶 L1_Contract=one_year|L2_tenure=short_term|L3_InternetService=OTHER 标记为弱桶，阈值将回退使用 L1_Contract=one_year|L2_tenure=short_term 的阈值
# [INFO][BT][2025-12-11 19:37:25] 桶 bucket_id=L1_Contract=one_year|L2_tenure=short_term|L3_InternetService=OTHER level=3：
#     n_train=55, n_val=20,
#     BAC=nan, F1=nan, AUC=nan,
#     Regret=nan, BND_ratio=nan, POS_coverage=nan,
#     Score(f1_regret_bnd )=nan
# [INFO][BT][2025-12-11 19:37:25] 桶 bucket_id=L1_Contract=one_year|L2_tenure=short_term|L3_InternetService=OTHER：
#     parent_id=L1_Contract=one_year|L2_tenure=short_term，parent_Score=-0.634, bucket_Score=nan,
#     Gain=+nan, is_weak=True
# 【INFO】【2025-12-11 19:37:25】【阈值】桶 L1_Contract=one_year|L2_tenure=short_term|L3_InternetService=dsl 标记为弱桶，阈值将回退使用 L1_Contract=one_year|L2_tenure=short_term 的阈值
# [INFO][BT][2025-12-11 19:37:25] 桶 bucket_id=L1_Contract=one_year|L2_tenure=short_term|L3_InternetService=dsl level=3：
#     n_train=47, n_val=18,
#     BAC=nan, F1=nan, AUC=nan,
#     Regret=nan, BND_ratio=nan, POS_coverage=nan,
#     Score(f1_regret_bnd )=nan
# [INFO][BT][2025-12-11 19:37:25] 桶 bucket_id=L1_Contract=one_year|L2_tenure=short_term|L3_InternetService=dsl：
#     parent_id=L1_Contract=one_year|L2_tenure=short_term，parent_Score=-0.634, bucket_Score=nan,
#     Gain=+nan, is_weak=True
# 【INFO】【2025-12-11 19:37:25】【阈值】桶 L1_Contract=one_year|L2_tenure=short_term|L3_InternetService=others 标记为弱桶，阈值将回退使用 L1_Contract=one_year|L2_tenure=short_term 的阈值
# [INFO][BT][2025-12-11 19:37:25] 桶 bucket_id=L1_Contract=one_year|L2_tenure=short_term|L3_InternetService=others level=3：
#     n_train=16, n_val=3,
#     BAC=nan, F1=nan, AUC=nan,
#     Regret=nan, BND_ratio=nan, POS_coverage=nan,
#     Score(f1_regret_bnd )=nan
# [INFO][BT][2025-12-11 19:37:25] 桶 bucket_id=L1_Contract=one_year|L2_tenure=short_term|L3_InternetService=others：
#     parent_id=L1_Contract=one_year|L2_tenure=short_term，parent_Score=-0.634, bucket_Score=nan,
#     Gain=+nan, is_weak=True
# 【INFO】【2025-12-11 19:37:25】【阈值】桶 L1_Contract=two_year|L2_tenure=long_term|L3_InternetService=OTHER 标记为弱桶，阈值将回退使用 L1_Contract=two_year|L2_tenure=long_term 的阈值
# [INFO][BT][2025-12-11 19:37:25] 桶 bucket_id=L1_Contract=two_year|L2_tenure=long_term|L3_InternetService=OTHER level=3：
#     n_train=119, n_val=71,
#     BAC=nan, F1=nan, AUC=nan,
#     Regret=nan, BND_ratio=nan, POS_coverage=nan,
#     Score(f1_regret_bnd )=nan
# [INFO][BT][2025-12-11 19:37:25] 桶 bucket_id=L1_Contract=two_year|L2_tenure=long_term|L3_InternetService=OTHER：
#     parent_id=L1_Contract=two_year|L2_tenure=long_term，parent_Score=-0.225, bucket_Score=nan,
#     Gain=+nan, is_weak=True
# 【INFO】【2025-12-11 19:37:25】【阈值】桶 L1_Contract=two_year|L2_tenure=long_term|L3_InternetService=dsl（n_val=82）使用本地阈值 α=0.5000, β=0.4000
# [INFO][BT][2025-12-11 19:37:25] 桶 bucket_id=L1_Contract=two_year|L2_tenure=long_term|L3_InternetService=dsl level=3：
#     n_train=236, n_val=82,
#     BAC=0.500, F1=0.000, AUC=0.525,
#     Regret=0.122, BND_ratio=0.000, POS_coverage=0.000,
#     Score(f1_regret_bnd )=-0.122
# [INFO][BT][2025-12-11 19:37:25] 桶 bucket_id=L1_Contract=two_year|L2_tenure=long_term|L3_InternetService=dsl：
#     parent_id=L1_Contract=two_year|L2_tenure=long_term，parent_Score=-0.225, bucket_Score=-0.122,
#     Gain=+0.103, is_weak=False
# 【INFO】【2025-12-11 19:37:25】【阈值】桶 L1_Contract=two_year|L2_tenure=long_term|L3_InternetService=fiber 标记为弱桶，阈值将回退使用 L1_Contract=two_year|L2_tenure=long_term 的阈值
# [INFO][BT][2025-12-11 19:37:25] 桶 bucket_id=L1_Contract=two_year|L2_tenure=long_term|L3_InternetService=fiber level=3：
#     n_train=187, n_val=83,
#     BAC=0.480, F1=0.000, AUC=0.694,
#     Regret=0.476, BND_ratio=0.060, POS_coverage=0.000,
#     Score(f1_regret_bnd )=-0.506
# [INFO][BT][2025-12-11 19:37:25] 桶 bucket_id=L1_Contract=two_year|L2_tenure=long_term|L3_InternetService=fiber：
#     parent_id=L1_Contract=two_year|L2_tenure=long_term，parent_Score=-0.225, bucket_Score=-0.506,
#     Gain=-0.281, is_weak=True
# 【INFO】【2025-12-11 19:37:26】【阈值】桶 L1_Contract=two_year|L2_tenure=mid_term|L3_InternetService=OTHER 标记为弱桶，阈值将回退使用 L1_Contract=two_year|L2_tenure=mid_term 的阈值
# [INFO][BT][2025-12-11 19:37:26] 桶 bucket_id=L1_Contract=two_year|L2_tenure=mid_term|L3_InternetService=OTHER level=3：
#     n_train=143, n_val=78,
#     BAC=0.500, F1=0.000, AUC=0.935,
#     Regret=0.064, BND_ratio=0.000, POS_coverage=0.000,
#     Score(f1_regret_bnd )=-0.064
# [INFO][BT][2025-12-11 19:37:26] 桶 bucket_id=L1_Contract=two_year|L2_tenure=mid_term|L3_InternetService=OTHER：
#     parent_id=L1_Contract=two_year|L2_tenure=mid_term，parent_Score=-0.060, bucket_Score=-0.064,
#     Gain=-0.005, is_weak=True
# 【INFO】【2025-12-11 19:37:26】【阈值】桶 L1_Contract=two_year|L2_tenure=mid_term|L3_InternetService=dsl 标记为弱桶，阈值将回退使用 L1_Contract=two_year|L2_tenure=mid_term 的阈值
# [INFO][BT][2025-12-11 19:37:26] 桶 bucket_id=L1_Contract=two_year|L2_tenure=mid_term|L3_InternetService=dsl level=3：
#     n_train=108, n_val=45,
#     BAC=nan, F1=nan, AUC=nan,
#     Regret=nan, BND_ratio=nan, POS_coverage=nan,
#     Score(f1_regret_bnd )=nan
# [INFO][BT][2025-12-11 19:37:26] 桶 bucket_id=L1_Contract=two_year|L2_tenure=mid_term|L3_InternetService=dsl：
#     parent_id=L1_Contract=two_year|L2_tenure=mid_term，parent_Score=-0.060, bucket_Score=nan,
#     Gain=+nan, is_weak=True
# 【INFO】【2025-12-11 19:37:26】【阈值】桶 L1_Contract=two_year|L2_tenure=mid_term|L3_InternetService=fiber 标记为弱桶，阈值将回退使用 L1_Contract=two_year|L2_tenure=mid_term 的阈值
# [INFO][BT][2025-12-11 19:37:26] 桶 bucket_id=L1_Contract=two_year|L2_tenure=mid_term|L3_InternetService=fiber level=3：
#     n_train=49, n_val=24,
#     BAC=nan, F1=nan, AUC=nan,
#     Regret=nan, BND_ratio=nan, POS_coverage=nan,
#     Score(f1_regret_bnd )=nan
# [INFO][BT][2025-12-11 19:37:26] 桶 bucket_id=L1_Contract=two_year|L2_tenure=mid_term|L3_InternetService=fiber：
#     parent_id=L1_Contract=two_year|L2_tenure=mid_term，parent_Score=-0.060, bucket_Score=nan,
#     Gain=+nan, is_weak=True
# [INFO][BT][2025-12-11 19:37:26] 桶 bucket_id=L1_Contract=month_to_month 样本不足或为弱桶，未单独搜索阈值，继承桶 ROOT 的阈值(alpha=0.4000,beta=0.2000)
# [INFO][BT][2025-12-11 19:37:26] 桶 bucket_id=L1_Contract=one_year 样本不足或为弱桶，未单独搜索阈值，继承桶 ROOT 的阈值(alpha=0.4000,beta=0.2000)
# [INFO][BT][2025-12-11 19:37:26] 桶 bucket_id=L1_Contract=two_year 样本不足或为弱桶，未单独搜索阈值，继承桶 ROOT 的阈值(alpha=0.4000,beta=0.2000)
# [INFO][BT][2025-12-11 19:37:26] 桶 bucket_id=L1_Contract=month_to_month|L2_tenure=long_term 样本不足或为弱桶，未单独搜索阈值，继承桶 ROOT 的阈值(alpha=0.4000,beta=0.2000)
# [INFO][BT][2025-12-11 19:37:26] 桶 bucket_id=L1_Contract=month_to_month|L2_tenure=mid_term 样本不足或为弱桶，未单独搜索阈值，继承桶 ROOT 的阈值(alpha=0.4000,beta=0.2000)
# [INFO][BT][2025-12-11 19:37:26] 桶 bucket_id=L1_Contract=month_to_month|L2_tenure=short_term 样本不足或为弱桶，未单独搜索阈值，继承桶 ROOT 的阈值(alpha=0.4000,beta=0.2000)
# [INFO][BT][2025-12-11 19:37:26] 桶 bucket_id=L1_Contract=two_year|L2_tenure=short_term 样本不足或为弱桶，未单独搜索阈值，继承桶 ROOT 的阈值(alpha=0.4000,beta=0.2000)
# [INFO][BT][2025-12-11 19:37:26] 桶 bucket_id=L1_Contract=two_year|L2_tenure=others 样本不足或为弱桶，未单独搜索阈值，继承桶 ROOT 的阈值(alpha=0.4000,beta=0.2000)
# [INFO][BT][2025-12-11 19:37:26] 桶 bucket_id=L1_Contract=month_to_month|L2_tenure=long_term|L3_InternetService=fiber 样本不足或为弱桶，未单独搜索阈值，继承桶 ROOT 的阈值(alpha=0.4000,beta=0.2000)
# [INFO][BT][2025-12-11 19:37:26] 桶 bucket_id=L1_Contract=month_to_month|L2_tenure=long_term|L3_InternetService=others 样本不足或为弱桶，未单独搜索阈值，继承桶 ROOT 的阈值(alpha=0.4000,beta=0.2000)
# [INFO][BT][2025-12-11 19:37:26] 桶 bucket_id=L1_Contract=month_to_month|L2_tenure=mid_term|L3_InternetService=others 样本不足或为弱桶，未单独搜索阈值，继承桶 ROOT 的阈值(alpha=0.4000,beta=0.2000)
# [INFO][BT][2025-12-11 19:37:26] 桶 bucket_id=L1_Contract=month_to_month|L2_tenure=new|L3_InternetService=OTHER 样本不足或为弱桶，未单独搜索阈值，继承桶 L1_Contract=month_to_month|L2_tenure=new 的阈值(alpha=0.2000,beta=0.0000)
# [INFO][BT][2025-12-11 19:37:26] 桶 bucket_id=L1_Contract=month_to_month|L2_tenure=new|L3_InternetService=dsl 样本不足或为弱桶，未单独搜索阈值，继承桶 L1_Contract=month_to_month|L2_tenure=new 的阈值(alpha=0.2000,beta=0.0000)
# [INFO][BT][2025-12-11 19:37:26] 桶 bucket_id=L1_Contract=month_to_month|L2_tenure=short_term|L3_InternetService=OTHER 样本不足或为弱桶，未单独搜索阈值，继承桶 ROOT 的阈值(alpha=0.4000,beta=0.2000)
# [INFO][BT][2025-12-11 19:37:26] 桶 bucket_id=L1_Contract=month_to_month|L2_tenure=short_term|L3_InternetService=dsl 样本不足或为弱桶，未单独搜索阈值，继承桶 ROOT 的阈值(alpha=0.4000,beta=0.2000)
# [INFO][BT][2025-12-11 19:37:26] 桶 bucket_id=L1_Contract=one_year|L2_tenure=long_term|L3_InternetService=dsl 样本不足或为弱桶，未单独搜索阈值，继承桶 L1_Contract=one_year|L2_tenure=long_term 的阈值(alpha=0.5000,beta=0.4000)
# [INFO][BT][2025-12-11 19:37:26] 桶 bucket_id=L1_Contract=one_year|L2_tenure=long_term|L3_InternetService=fiber 样本不足或为弱桶，未单独搜索阈值，继承桶 L1_Contract=one_year|L2_tenure=long_term 的阈值(alpha=0.5000,beta=0.4000)
# [INFO][BT][2025-12-11 19:37:26] 桶 bucket_id=L1_Contract=one_year|L2_tenure=long_term|L3_InternetService=others 样本不足或为弱桶，未单独搜索阈值，继承桶 L1_Contract=one_year|L2_tenure=long_term 的阈值(alpha=0.5000,beta=0.4000)
# [INFO][BT][2025-12-11 19:37:26] 桶 bucket_id=L1_Contract=one_year|L2_tenure=mid_term|L3_InternetService=OTHER 样本不足或为弱桶，未单独搜索阈值，继承桶 L1_Contract=one_year|L2_tenure=mid_term 的阈值(alpha=0.7000,beta=0.6000)
# [INFO][BT][2025-12-11 19:37:26] 桶 bucket_id=L1_Contract=one_year|L2_tenure=new|L3_InternetService=OTHER 样本不足或为弱桶，未单独搜索阈值，继承桶 L1_Contract=one_year|L2_tenure=new 的阈值(alpha=0.3000,beta=0.1000)
# [INFO][BT][2025-12-11 19:37:26] 桶 bucket_id=L1_Contract=one_year|L2_tenure=new|L3_InternetService=others 样本不足或为弱桶，未单独搜索阈值，继承桶 L1_Contract=one_year|L2_tenure=new 的阈值(alpha=0.3000,beta=0.1000)
# [INFO][BT][2025-12-11 19:37:26] 桶 bucket_id=L1_Contract=one_year|L2_tenure=short_term|L3_InternetService=OTHER 样本不足或为弱桶，未单独搜索阈值，继承桶 L1_Contract=one_year|L2_tenure=short_term 的阈值(alpha=0.2000,beta=0.1000)
# [INFO][BT][2025-12-11 19:37:26] 桶 bucket_id=L1_Contract=one_year|L2_tenure=short_term|L3_InternetService=dsl 样本不足或为弱桶，未单独搜索阈值，继承桶 L1_Contract=one_year|L2_tenure=short_term 的阈值(alpha=0.2000,beta=0.1000)
# [INFO][BT][2025-12-11 19:37:26] 桶 bucket_id=L1_Contract=one_year|L2_tenure=short_term|L3_InternetService=others 样本不足或为弱桶，未单独搜索阈值，继承桶 L1_Contract=one_year|L2_tenure=short_term 的阈值(alpha=0.2000,beta=0.1000)
# [INFO][BT][2025-12-11 19:37:26] 桶 bucket_id=L1_Contract=two_year|L2_tenure=long_term|L3_InternetService=OTHER 样本不足或为弱桶，未单独搜索阈值，继承桶 L1_Contract=two_year|L2_tenure=long_term 的阈值(alpha=0.7000,beta=0.2000)
# [INFO][BT][2025-12-11 19:37:26] 桶 bucket_id=L1_Contract=two_year|L2_tenure=long_term|L3_InternetService=fiber 样本不足或为弱桶，未单独搜索阈值，继承桶 L1_Contract=two_year|L2_tenure=long_term 的阈值(alpha=0.7000,beta=0.2000)
# [INFO][BT][2025-12-11 19:37:26] 桶 bucket_id=L1_Contract=two_year|L2_tenure=mid_term|L3_InternetService=OTHER 样本不足或为弱桶，未单独搜索阈值，继承桶 L1_Contract=two_year|L2_tenure=mid_term 的阈值(alpha=0.5000,beta=0.4000)
# ...
#     used_local_decision=0,
#     fallback_to_parent=23,
#     parent_id=L1_Contract=two_year,
#     is_weak=True
# [INFO][BT][2025-12-11 19:38:12] 回退汇总：
#     总样本数=1408,
#     使用叶子桶决策的样本比例=21.520%,
#     使用中间桶决策的样本比例=60.938%,
#     回退到全局桶决策的样本比例=17.543%
# 【INFO】【2025-12-11 19:38:12】【BTTWD】三支指标(含后悔)：Precision=0.469, Recall=0.829, F1=0.599, BAC=0.745, AUC=0.821, MCC=0.433, Kappa=0.393, BND_ratio=0.178, POS_Coverage=0.387, Regret=0.456
# 【INFO】【2025-12-11 19:38:12】【桶树】已为样本生成桶ID，共 32 个组合
# 【INFO】【2025-12-11 19:38:12】【K折实验】所有结果已写入 results 目录
# 【INFO】【2025-12-11 19:38:12】[BASELINE] 数据拆分完成（train/val/test）
# 【INFO】【2025-12-11 19:38:12】[BASELINE] 全局 XGB 模型开始训练
# C:\Users\xzq20.HUANLI\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:158: UserWarning: [19:38:12] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 【INFO】【2025-12-11 19:38:12】[BASELINE] 全局 XGB 模型训练完成
# 【INFO】【2025-12-11 19:38:12】[BASELINE] 阈值搜索开始
# 【INFO】【2025-12-11 19:38:13】[BASELINE] 最佳阈值找到: alpha=0.2000, beta=0.1000, regret=0.4382
# 【INFO】【2025-12-11 19:38:13】【桶树】已为样本生成桶ID，共 33 个组合
# 【INFO】【2025-12-11 19:38:13】[BASELINE] 测试集桶映射完成，共 33 个桶
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:2394: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:2394: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=two_year|L2_tenure=long_term|L3_InternetService=fiber: BAC=0.4919, Regret=0.3712, Precision=0.0000, Recall=0.0000
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=month_to_month|L2_tenure=new|L3_InternetService=fiber: BAC=0.5039, Regret=0.3441, Precision=0.6630, Recall=0.9919
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=one_year|L2_tenure=mid_term|L3_InternetService=dsl: BAC=0.5000, Regret=0.4067, Precision=0.0000, Recall=0.0000
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=month_to_month|L2_tenure=short_term|L3_InternetService=fiber: BAC=0.5100, Regret=0.5160, Precision=0.4945, Recall=0.9783
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=two_year|L2_tenure=long_term|L3_InternetService=dsl: BAC=0.5000, Regret=0.0704, Precision=0.0000, Recall=0.0000
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=month_to_month|L2_tenure=short_term|L3_InternetService=OTHER: BAC=0.9231, Regret=0.0769, Precision=0.0000, Recall=0.0000
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=two_year|L2_tenure=long_term|L3_InternetService=OTHER: BAC=1.0000, Regret=0.0000, Precision=0.0000, Recall=0.0000
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=month_to_month|L2_tenure=short_term|L3_InternetService=dsl: BAC=0.6500, Regret=0.6500, Precision=0.2857, Recall=0.8000
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=month_to_month|L2_tenure=long_term|L3_InternetService=fiber: BAC=0.7692, Regret=0.3750, Precision=0.3333, Recall=1.0000
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=month_to_month|L2_tenure=mid_term|L3_InternetService=dsl: BAC=0.4300, Regret=0.7917, Precision=0.0769, Recall=0.1000
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=two_year|L2_tenure=new|L3_InternetService=OTHER: BAC=1.0000, Regret=0.0000, Precision=0.0000, Recall=0.0000
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=one_year|L2_tenure=long_term|L3_InternetService=fiber: BAC=0.6475, Regret=0.6515, Precision=0.6000, Recall=0.3750
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=one_year|L2_tenure=mid_term|L3_InternetService=OTHER: BAC=0.5000, Regret=0.1351, Precision=0.0000, Recall=0.0000
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=one_year|L2_tenure=short_term|L3_InternetService=OTHER: BAC=1.0000, Regret=0.0000, Precision=0.0000, Recall=0.0000
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=month_to_month|L2_tenure=mid_term|L3_InternetService=fiber: BAC=0.5400, Regret=0.5840, Precision=0.4220, Recall=0.9200
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=two_year|L2_tenure=mid_term|L3_InternetService=OTHER: BAC=1.0000, Regret=0.0000, Precision=0.0000, Recall=0.0000
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=month_to_month|L2_tenure=new|L3_InternetService=dsl: BAC=0.5556, Regret=0.6360, Precision=0.5146, Recall=0.8154
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=one_year|L2_tenure=long_term|L3_InternetService=OTHER: BAC=1.0000, Regret=0.0000, Precision=0.0000, Recall=0.0000
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=month_to_month|L2_tenure=new|L3_InternetService=OTHER: BAC=0.5406, Regret=0.8141, Precision=0.3158, Recall=0.5455
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=one_year|L2_tenure=mid_term|L3_InternetService=fiber: BAC=0.3486, Regret=0.8443, Precision=0.0800, Recall=0.1667
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=one_year|L2_tenure=new|L3_InternetService=dsl: BAC=0.6591, Regret=0.4231, Precision=0.3333, Recall=0.5000
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=one_year|L2_tenure=long_term|L3_InternetService=dsl: BAC=1.0000, Regret=0.0526, Precision=0.0000, Recall=0.0000
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=two_year|L2_tenure=mid_term|L3_InternetService=fiber: BAC=0.4500, Regret=0.7826, Precision=0.0000, Recall=0.0000
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=one_year|L2_tenure=short_term|L3_InternetService=fiber: BAC=0.3750, Regret=0.8333, Precision=0.2500, Recall=0.5000
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=one_year|L2_tenure=new|L3_InternetService=OTHER: BAC=0.5000, Regret=0.5250, Precision=0.0000, Recall=0.0000
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=two_year|L2_tenure=mid_term|L3_InternetService=dsl: BAC=0.5000, Regret=0.1486, Precision=0.0000, Recall=0.0000
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=month_to_month|L2_tenure=mid_term|L3_InternetService=OTHER: BAC=1.0000, Regret=0.0455, Precision=0.0000, Recall=0.0000
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=one_year|L2_tenure=short_term|L3_InternetService=dsl: BAC=0.6944, Regret=0.5909, Precision=0.5000, Recall=0.5000
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=month_to_month|L2_tenure=long_term|L3_InternetService=dsl: BAC=1.0000, Regret=0.0000, Precision=0.0000, Recall=0.0000
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=two_year|L2_tenure=short_term|L3_InternetService=OTHER: BAC=1.0000, Regret=0.0000, Precision=0.0000, Recall=0.0000
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=two_year|L2_tenure=short_term|L3_InternetService=dsl: BAC=1.0000, Regret=0.0000, Precision=0.0000, Recall=0.0000
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=one_year|L2_tenure=new|L3_InternetService=fiber: BAC=0.5000, Regret=0.6667, Precision=0.3333, Recall=1.0000
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=two_year|L2_tenure=new|L3_InternetService=dsl: BAC=1.0000, Regret=0.0000, Precision=0.0000, Recall=0.0000
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=two_year|L2_tenure=long_term: BAC=0.4974, Regret=0.1505, Precision=0.0000, Recall=0.0000
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=two_year: BAC=0.4954, Regret=0.1577, Precision=0.0000, Recall=0.0000
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=month_to_month|L2_tenure=new: BAC=0.5821, Regret=0.5350, Precision=0.5754, Recall=0.8905
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=month_to_month: BAC=0.6187, Regret=0.5472, Precision=0.5035, Recall=0.8815
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=one_year|L2_tenure=mid_term: BAC=0.4780, Regret=0.5029, Precision=0.0800, Recall=0.1053
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=one_year: BAC=0.5625, Regret=0.4633, Precision=0.2143, Recall=0.2500
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=month_to_month|L2_tenure=short_term: BAC=0.6415, Regret=0.5223, Precision=0.4417, Recall=0.9464
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=month_to_month|L2_tenure=long_term: BAC=0.8235, Regret=0.3000, Precision=0.3333, Recall=1.0000
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=month_to_month|L2_tenure=mid_term: BAC=0.6159, Regret=0.6173, Precision=0.3852, Recall=0.7833
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=two_year|L2_tenure=new: BAC=1.0000, Regret=0.0000, Precision=0.0000, Recall=0.0000
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=one_year|L2_tenure=long_term: BAC=0.6683, Regret=0.3750, Precision=0.6000, Recall=0.3750
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=one_year|L2_tenure=short_term: BAC=0.6759, Regret=0.3710, Precision=0.3333, Recall=0.5000
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=two_year|L2_tenure=mid_term: BAC=0.4905, Regret=0.2156, Precision=0.0000, Recall=0.0000
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=one_year|L2_tenure=new: BAC=0.6355, Regret=0.5000, Precision=0.3333, Recall=0.4000
# 【INFO】【2025-12-11 19:38:14】[BASELINE] 桶 L1_Contract=two_year|L2_tenure=short_term: BAC=1.0000, Regret=0.0000, Precision=0.0000, Recall=0.0000
# 【INFO】【2025-12-11 19:38:14】[BASELINE] baseline_bucket_metrics.csv 写出完成
# 【INFO】【2025-12-11 19:38:14】[BASELINE] baseline 指标成功合并到 bucket_metrics_gain.csv
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
#           model  Precision_mean  Precision_std  Recall_mean  Recall_std  \
# 0         BTTWD        0.468779       0.008144     0.846979    0.011842
# 1        LogReg        0.471242       0.012526     0.863016    0.015203
# 2  RandomForest        0.461734       0.008967     0.839479    0.012181
# 3           KNN        0.457309       0.010108     0.791847    0.021452
# 4       XGBoost        0.481943       0.009569     0.828787    0.010403
#
#     F1_mean    F1_std  BAC_mean   BAC_std  AUC_mean  ...  MCC_mean   MCC_std  \
# 0  0.603445  0.006118  0.750027  0.005369  0.830345  ...  0.442064  0.009531
# 1  0.609571  0.013644  0.756497  0.012515  0.845129  ...  0.453251  0.022273
# 2  0.595722  0.009000  0.742895  0.008224  0.824637  ...  0.429325  0.014665
# 3  0.579689  0.011935  0.726132  0.010911  0.789977  ...  0.400808  0.019274
# 4  0.609425  0.009224  0.753397  0.008080  0.834643  ...  0.449308  0.014635
#
#    Kappa_mean  Kappa_std  BND_ratio_mean  BND_ratio_std  POS_Coverage_mean  \
# 0    0.397625   0.011432        0.147382       0.026182           0.400539
# 1    0.405416   0.021902        0.000000       0.000000                NaN
# 2    0.385184   0.014774        0.000000       0.000000                NaN
# 3    0.366602   0.017845        0.000000       0.000000                NaN
# 4    0.412106   0.015150        0.000000       0.000000                NaN
#
#    POS_Coverage_std  Regret_mean  Regret_std
# 0          0.015658     0.437177    0.019105
# 1               NaN     0.438883    0.026687
# 2               NaN     0.472814    0.017776
# 3               NaN     0.525636    0.027284
# 4               NaN     0.463726    0.016890
#
# [5 rows x 21 columns]
# 【INFO】【2025-12-11 19:38:15】【步骤6摘要】BTTWD 与基线的 k 折结果已生成并保存。

# %%
# 步骤7：桶级别分析
bucket_metrics_path = os.path.join(root_path, cfg['OUTPUT']['results_dir'], 'bucket_metrics.csv')
if os.path.exists(bucket_metrics_path):
    bucket_metrics_df = pd.read_csv(bucket_metrics_path)
    display(bucket_metrics_df.head())
    bucket_metrics_df.plot(x='bucket_id', y='pos_rate_all', kind='bar', figsize=(12,4), title='桶正类比例')
    plt.ylabel('正类比例')
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.savefig(fig_bucket, bbox_inches='tight')
    plt.close()
log_info('【步骤7摘要】桶级指标已整理，可用于局部化分析。')
# Out:
#                                   bucket_id layer            parent_bucket_id  \
# 0                                      ROOT    L1                         NaN
# 1                L1_Contract=month_to_month    L1                        ROOT
# 2  L1_Contract=month_to_month|L2_tenure=new    L2  L1_Contract=month_to_month
# 3                      L1_Contract=two_year    L1                        ROOT
# 4                      L1_Contract=one_year    L1                        ROOT
#
#    n_train  n_val  pos_rate_train  pos_rate_val  alpha  beta  regret_val  ...  \
# 0      788    337        0.263959      0.240356    0.4   0.2    0.440653  ...
# 1      434    198        0.421659      0.388889    0.4   0.2    0.560606  ...
# 2      224     96        0.450893      0.489583    0.2   0.0    0.479167  ...
# 3      252    111        0.015873      0.000000    0.4   0.2         NaN  ...
# 4      165    126        0.096970      0.126984    0.4   0.2    0.519841  ...
#
#    is_weak                   threshold_source_bucket  parent_with_threshold  \
# 0    False                                      ROOT                    NaN
# 1     True                                      ROOT                    NaN
# 2    False  L1_Contract=month_to_month|L2_tenure=new                    NaN
# 3     True                                      ROOT                    NaN
# 4     True                                      ROOT                    NaN
#
#    n_test  pos_rate_test  BND_ratio_test  POS_Coverage_test  regret_test  \
# 0     NaN            NaN             NaN                NaN          NaN
# 1     NaN            NaN             NaN                NaN          NaN
# 2     NaN            NaN             NaN                NaN          NaN
# 3     NaN            NaN             NaN                NaN          NaN
# 4     NaN            NaN             NaN                NaN          NaN
#
#    fold  pos_rate
# 0     1  0.265353
# 1     1  0.425032
# 2     1  0.508369
# 3     1  0.029762
# 4     1  0.113367
#
# [5 rows x 35 columns]
# C:\Users\xzq20.HUANLI\AppData\Local\Temp\ipykernel_29492\946468196.py:9: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 【INFO】【2025-12-11 19:38:18】【步骤7摘要】桶级指标已整理，可用于局部化分析。

# %%
# 步骤8：结果汇总
log_info('【步骤8】检查结果文件与图表。')
print(os.listdir(os.path.join(root_path, cfg['OUTPUT']['results_dir'])))
print(os.listdir(os.path.join(root_path, cfg['OUTPUT']['figs_dir'])))
log_info('【全部步骤完成】Telco Churn 数据集上的 BT-TWD 实验结束。')
# Out:
# 【INFO】【2025-12-11 19:38:18】【步骤8】检查结果文件与图表。
# ['baseline_bucket_metrics.csv', 'bucket_fallback_stats.csv', 'bucket_metrics.csv', 'bucket_metrics_gain.csv', 'bucket_thresholds.csv', 'bucket_thresholds_per_fold.csv', 'bucket_tree_structure.csv', 'metrics_kfold_per_fold.csv', 'metrics_kfold_summary.csv', 'metrics_overview.csv']
# ['bank_class_distribution.png', 'bucket_metrics_bar.png', 'class_distribution.png', 'metrics_compare.png']
# 【INFO】【2025-12-11 19:38:18】【全部步骤完成】Telco Churn 数据集上的 BT-TWD 实验结束。
