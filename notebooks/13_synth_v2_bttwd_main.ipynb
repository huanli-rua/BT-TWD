# %% [markdown]
#  数据集 BT-TWD 可行性实验
#
# 本 notebook 按步骤运行：加载配置 → 读取数据 → 预处理 → 桶树划分 → 基线与 BTTWD k 折实验 → 桶级分析。

# %%
# 步骤0：环境与路径设置
import os, sys
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['Microsoft YaHei']
plt.rcParams['axes.unicode_minus'] = False

# 将项目根目录加入路径，便于导入 bttwdlib
root_path = os.path.abspath(os.path.join(os.getcwd(), '..'))
if root_path not in sys.path:
    sys.path.append(root_path)

from bttwdlib import (
    load_yaml_cfg,
    show_cfg,
    load_dataset,
    prepare_features_and_labels,
    BucketTree,
    run_kfold_experiments,
    log_info,
    set_global_seed,
)

cfg_path = os.path.join(root_path, 'configs', 'synth_strong_v2.yaml')
cfg = load_yaml_cfg(cfg_path)
set_global_seed(cfg.get('SEED', {}).get('global_seed', 42))
log_info('【步骤0摘要】环境准备完毕，路径与随机种子已设置。')
# Out:
# 【INFO】【2025-12-16 18:56:12】【配置加载】已读取 e:\yan\组\三支决策\机器学习\BT_TWD\configs\synth_strong_v2.yaml
# 【INFO】【2025-12-16 18:56:16】【步骤0摘要】环境准备完毕，路径与随机种子已设置。

# %%
# 步骤1：加载配置
show_cfg(cfg)
log_info('【步骤1摘要】配置文件加载完成，关键参数检查通过。')
# Out:
# 【INFO】【2025-12-16 18:56:17】【配置-数据】数据集=synth_strong_v2, k折=None, 目标列=target, 正类="1"
# 【INFO】【2025-12-16 18:56:17】【配置-BTTWD】阈值模式=bucket_wise, 全局模型=xgb, 桶内模型=lr, 后验估计器(兼容字段)=logreg
# 【INFO】【2025-12-16 18:56:17】【配置-基线】LogReg启用=True, RandomForest启用=True, KNN启用=True, XGBoost启用=True
# 【INFO】【2025-12-16 18:56:17】【步骤1摘要】配置文件加载完成，关键参数检查通过。

# %%
# 步骤2：加载原始数据
df_raw, target_col_model = load_dataset(cfg)  # 这里返回的是用于建模的标签列，例如 "label"

display(df_raw.head())
print("用于建模的标签列:", target_col_model)

# 1）画 0/1 标签（延误/不延误）的比例
class_counts = df_raw[target_col_model].value_counts(normalize=True)
ax = class_counts.plot(kind='bar', title='正 vs 负比例')
plt.ylabel('比例')

fig_path = os.path.join(root_path, cfg['OUTPUT']['figs_dir'], 'class_distribution.png')
os.makedirs(os.path.dirname(fig_path), exist_ok=True)
plt.savefig(fig_path, bbox_inches='tight')
plt.close()

# 2）如果想看原始 DepDelay 的分布，可以另外单独分析：
raw_target_col = cfg['DATA']['target_col']  # 这里是 "DepDelay"
print("原始目标列:", raw_target_col)
print(df_raw[raw_target_col].describe())

log_info('【步骤2摘要】Airlines 原始数据加载与基本统计完成。')
# Out:
# 【INFO】【2025-12-16 18:56:18】【合成数据v2加载】文件=..\data\synth\synth_strong_v2.csv，样本数=200000，全局正例率=26.06%
# 【INFO】【2025-12-16 18:56:18】组别 A: 样本数=49807，正例率=12.40%
# 【INFO】【2025-12-16 18:56:18】组别 B: 样本数=49948，正例率=20.91%
# 【INFO】【2025-12-16 18:56:18】组别 C: 样本数=50323，正例率=28.39%
# 【INFO】【2025-12-16 18:56:18】组别 D: 样本数=49922，正例率=42.48%
# 【INFO】【2025-12-16 18:56:18】【数据加载】检测到 synth_strong_v2 元数据 ..\data\synth\synth_strong_v2_meta.json，已注入 500 条桶级 cost 配置
# 【INFO】【2025-12-16 18:56:18】【数据集信息】名称=synth_strong_v2，样本数=200000，目标列=target，正类比例=26.06%
#    target group        x1        x2        x3        x4        x5        x6  \
# 0       0     A  1.064588 -1.305676  0.557827  0.009463  2.368387  0.719543
# 1       0     D  0.512215 -0.375004 -0.383665  0.704062 -0.619332  0.181440
# 2       0     C -0.370929  0.782064 -1.249109 -1.254847  0.056107 -1.111550
# 3       0     B  1.791067 -0.872657 -0.609798  0.565370  1.414436 -0.988554
# 4       1     B  0.917348  0.433200  0.110524  0.265732  0.602970 -1.176482
#
#          x7        x8        x9       x10        z1        z2        z3  \
# 0  0.007857  1.028664  0.582720  0.761297  1.054418 -0.801457  0.300131
# 1  0.511407 -0.562699  0.456859  0.038571  0.511402 -0.505405 -1.402719
# 2  1.299804 -0.322134 -1.384439 -0.148576 -0.670660  0.892483 -0.741191
# 3 -0.749953 -1.541402 -0.011446  0.252859 -0.328013 -0.757283 -0.919904
# 4  0.260115 -1.655680  1.147569  1.809379 -0.471701 -0.053854 -0.310862
#
#          z4        z5
# 0 -0.073666 -1.663032
# 1 -0.680446 -0.082700
# 2 -1.742448 -0.781772
# 3 -1.548651 -1.364378
# 4  0.740968  1.703402
# 用于建模的标签列: target
# 原始目标列: target
# count    200000.000000
# mean          0.260570
# std           0.438947
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           1.000000
# max           1.000000
# Name: target, dtype: float64
# 【INFO】【2025-12-16 18:56:19】【步骤2摘要】Airlines 原始数据加载与基本统计完成。

# %%
# 步骤3：预处理与特征工程
X, y, meta = prepare_features_and_labels(df_raw, cfg)
log_info(f'【预处理】编码特征维度={X.shape[1]}，样本数={X.shape[0]}')
log_info(f"【步骤3摘要】特征预处理完成：连续={len(meta['continuous_cols'])}，类别={len(meta['categorical_cols'])}，编码维度={X.shape[1]}。")
# Out:
# 【INFO】【2025-12-16 18:56:19】【预处理】连续特征=15个，类别特征=1个
# 【INFO】【2025-12-16 18:56:19】【预处理】编码后维度=18
# 【INFO】【2025-12-16 18:56:19】【预处理】编码特征维度=18，样本数=200000
# 【INFO】【2025-12-16 18:56:19】【步骤3摘要】特征预处理完成：连续=15，类别=1，编码维度=18。

# %%
# 步骤4：构建桶树并检查划分
bucket_tree = BucketTree(cfg['BTTWD']['bucket_levels'], feature_names=df_raw.drop(columns=[cfg['DATA']['target_col']]).columns.tolist())
bucket_ids_full = bucket_tree.assign_buckets(df_raw.drop(columns=[cfg['DATA']['target_col']]))
bucket_df = bucket_ids_full.value_counts().reset_index()
bucket_df.columns = ['bucket_id', 'count']
bucket_df['pos_rate'] = df_raw.groupby(bucket_ids_full)[cfg['DATA']['target_col']].apply(lambda s: (s == cfg['DATA']['positive_label']).mean()).values
display(bucket_df.head())
bucket_df.set_index('bucket_id')['count'].plot(kind='bar', figsize=(12,4), title='桶样本数分布')
fig_bucket = os.path.join(root_path, cfg['OUTPUT']['figs_dir'], 'bucket_metrics_bar.png')
plt.savefig(fig_bucket, bbox_inches='tight')
plt.close()
log_info(f'【步骤4摘要】桶树划分完成，共有 {bucket_ids_full.nunique()} 个叶子桶。')
# Out:
# 【INFO】【2025-12-16 18:56:19】【桶树】已为样本生成桶ID，共 500 个组合
#                                bucket_id  count  pos_rate
# 0  L1_group=C|L2_x1=b3|L3_x2=b2|L4_x3=b2    967  0.076923
# 1  L1_group=A|L2_x1=b3|L3_x2=b2|L4_x3=b2    949  0.050209
# 2  L1_group=A|L2_x1=b2|L3_x2=b2|L4_x3=b2    937  0.119266
# 3  L1_group=D|L2_x1=b4|L3_x2=b2|L4_x3=b2    935  0.079470
# 4  L1_group=C|L2_x1=b2|L3_x2=b2|L4_x3=b2    925  0.181818
# 【INFO】【2025-12-16 18:56:25】【步骤4摘要】桶树划分完成，共有 500 个叶子桶。

# %%
# 步骤5：运行基线模型 k 折实验
# 基线部分在 run_kfold_experiments 内统一调度
log_info('【步骤5】基线模型将在整体交叉验证中一并运行。')
log_info('【步骤5摘要】基线模型性能将作为后续对比基准。')
# Out:
# 【INFO】【2025-12-16 18:56:25】【步骤5】基线模型将在整体交叉验证中一并运行。
# 【INFO】【2025-12-16 18:56:25】【步骤5摘要】基线模型性能将作为后续对比基准。

# %%
import numpy as np
import pandas as pd

print("y 全局标签分布：", np.unique(y, return_counts=True))

print("原始 income 列分布：")
print(df_raw[cfg['DATA']['target_col']].value_counts())
# Out:
# y 全局标签分布： (array([0, 1]), array([147886,  52114], dtype=int64))
# 原始 income 列分布：
# target
# 0    147886
# 1     52114
# Name: count, dtype: int64

# %%
# 步骤6：运行 BTTWD k 折实验（含基线）
results = run_kfold_experiments(X, y, df_raw.drop(columns=[cfg['DATA']['target_col']]), cfg)
summary_df = pd.read_csv(os.path.join(root_path, cfg['OUTPUT']['results_dir'], 'metrics_kfold_summary.csv'))
display(summary_df)
summary_df.plot(x='model', kind='bar', figsize=(8,4), title='模型指标对比')
fig_compare = os.path.join(root_path, cfg['OUTPUT']['figs_dir'], 'metrics_compare.png')
plt.savefig(fig_compare, bbox_inches='tight')
plt.close()
log_info('【步骤6摘要】BTTWD 与基线的 k 折结果已生成并保存。')
# Out:
# 【INFO】【2025-12-16 19:04:06】【基线-LogReg】使用决策阈值=0.300（fixed 模式）
# e:\yan\组\三支决策\机器学习\BT_TWD\bttwdlib\baselines.py:109: RuntimeWarning: Mean of empty slice
#   summary[f"{col}_mean"] = float(np.nanmean(arr))
# d:\Anaconda3\Lib\site-packages\numpy\lib\nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# 【INFO】【2025-12-16 19:04:08】【基线-LogReg】整体指标：AUC_mean=0.811, AUC_std=0.002, BAC_mean=0.735, BAC_std=0.004, BND_ratio_mean=0.000, BND_ratio_std=0.000, F1_mean=0.596, F1_std=0.005, Kappa_mean=0.426, Kappa_std=0.007, MCC_mean=0.434, MCC_std=0.007, POS_Coverage_mean=nan, POS_Coverage_std=nan, Precision_mean=0.523, Precision_std=0.004, Recall_mean=0.693, Recall_std=0.004, Regret_mean=0.404, Regret_std=0.005
# 【INFO】【2025-12-16 19:04:08】【基线-RF】使用决策阈值=0.300（fixed 模式）
# e:\yan\组\三支决策\机器学习\BT_TWD\bttwdlib\baselines.py:109: RuntimeWarning: Mean of empty slice
#   summary[f"{col}_mean"] = float(np.nanmean(arr))
# d:\Anaconda3\Lib\site-packages\numpy\lib\nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# 【INFO】【2025-12-16 19:07:12】【基线-RF】整体指标：AUC_mean=0.871, AUC_std=0.002, BAC_mean=0.798, BAC_std=0.002, BND_ratio_mean=0.000, BND_ratio_std=0.000, F1_mean=0.678, F1_std=0.003, Kappa_mean=0.544, Kappa_std=0.003, MCC_mean=0.554, MCC_std=0.004, POS_Coverage_mean=nan, POS_Coverage_std=nan, Precision_mean=0.601, Precision_std=0.002, Recall_mean=0.778, Recall_std=0.004, Regret_mean=0.308, Regret_std=0.003
# 【INFO】【2025-12-16 19:07:12】【基线-KNN】使用决策阈值=0.300（fixed 模式）
# e:\yan\组\三支决策\机器学习\BT_TWD\bttwdlib\baselines.py:109: RuntimeWarning: Mean of empty slice
#   summary[f"{col}_mean"] = float(np.nanmean(arr))
# d:\Anaconda3\Lib\site-packages\numpy\lib\nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# C:\Users\xzq20.HUANLI\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:158: UserWarning: [19:07:35] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 【INFO】【2025-12-16 19:07:35】【基线-KNN】整体指标：AUC_mean=0.786, AUC_std=0.003, BAC_mean=0.720, BAC_std=0.004, BND_ratio_mean=0.000, BND_ratio_std=0.000, F1_mean=0.572, F1_std=0.004, Kappa_mean=0.372, Kappa_std=0.006, MCC_mean=0.393, MCC_std=0.007, POS_Coverage_mean=nan, POS_Coverage_std=nan, Precision_mean=0.468, Precision_std=0.003, Recall_mean=0.736, Recall_std=0.006, Regret_mean=0.425, Regret_std=0.006
# 【INFO】【2025-12-16 19:07:35】【基线-XGB】使用决策阈值=0.300（fixed 模式）
# C:\Users\xzq20.HUANLI\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:158: UserWarning: [19:07:36] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\xzq20.HUANLI\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:158: UserWarning: [19:07:37] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\xzq20.HUANLI\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:158: UserWarning: [19:07:39] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\xzq20.HUANLI\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:158: UserWarning: [19:07:40] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# e:\yan\组\三支决策\机器学习\BT_TWD\bttwdlib\baselines.py:109: RuntimeWarning: Mean of empty slice
#   summary[f"{col}_mean"] = float(np.nanmean(arr))
# d:\Anaconda3\Lib\site-packages\numpy\lib\nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# 【INFO】【2025-12-16 19:07:41】【基线-XGB】整体指标：AUC_mean=0.878, AUC_std=0.002, BAC_mean=0.802, BAC_std=0.003, BND_ratio_mean=0.000, BND_ratio_std=0.000, F1_mean=0.688, F1_std=0.004, Kappa_mean=0.562, Kappa_std=0.006, MCC_mean=0.568, MCC_std=0.005, POS_Coverage_mean=nan, POS_Coverage_std=nan, Precision_mean=0.624, Precision_std=0.004, Recall_mean=0.768, Recall_std=0.004, Regret_mean=0.302, Regret_std=0.004
# 【INFO】【2025-12-16 19:07:41】【K折实验】正在执行第 1/5 折...
# 【INFO】【2025-12-16 19:07:41】[BT] 使用桶评分配置：mode=f1_regret_bnd, f1_weight=1.0, regret_weight=1.0, bnd_weight=0.5
# C:\Users\xzq20.HUANLI\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:158: UserWarning: [19:07:41] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 【INFO】【2025-12-16 19:07:42】【BTTWD】全局模型训练完成，用于兜底预测
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=ROOT，level=0，parent_id=ROOT，split_name=ROOT，split_type=ROOT，split_rule="all"，n_samples=160000
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A，level=1，parent_id=ROOT，split_name=L1_group，split_type=categorical_group，split_rule="A"，n_samples=39874
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=B，level=1，parent_id=ROOT，split_name=L1_group，split_type=categorical_group，split_rule="B"，n_samples=39988
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=C，level=1，parent_id=ROOT，split_name=L1_group，split_type=categorical_group，split_rule="C"，n_samples=40123
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=D，level=1，parent_id=ROOT，split_name=L1_group，split_type=categorical_group，split_rule="D"，n_samples=40015
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b1，level=2，parent_id=L1_group=A，split_name=L2_x1，split_type=numeric_bin，split_rule="b1"，n_samples=4578
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b2，level=2，parent_id=L1_group=A，split_name=L2_x1，split_type=numeric_bin，split_rule="b2"，n_samples=9098
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b3，level=2，parent_id=L1_group=A，split_name=L2_x1，split_type=numeric_bin，split_rule="b3"，n_samples=9338
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b4，level=2，parent_id=L1_group=A，split_name=L2_x1，split_type=numeric_bin，split_rule="b4"，n_samples=9540
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b5，level=2，parent_id=L1_group=A，split_name=L2_x1，split_type=numeric_bin，split_rule="b5"，n_samples=7320
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=B|L2_x1=b1，level=2，parent_id=L1_group=B，split_name=L2_x1，split_type=numeric_bin，split_rule="b1"，n_samples=4750
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=B|L2_x1=b2，level=2，parent_id=L1_group=B，split_name=L2_x1，split_type=numeric_bin，split_rule="b2"，n_samples=9286
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=B|L2_x1=b3，level=2，parent_id=L1_group=B，split_name=L2_x1，split_type=numeric_bin，split_rule="b3"，n_samples=9277
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=B|L2_x1=b4，level=2，parent_id=L1_group=B，split_name=L2_x1，split_type=numeric_bin，split_rule="b4"，n_samples=9285
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=B|L2_x1=b5，level=2，parent_id=L1_group=B，split_name=L2_x1，split_type=numeric_bin，split_rule="b5"，n_samples=7390
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=C|L2_x1=b1，level=2，parent_id=L1_group=C，split_name=L2_x1，split_type=numeric_bin，split_rule="b1"，n_samples=4575
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=C|L2_x1=b2，level=2，parent_id=L1_group=C，split_name=L2_x1，split_type=numeric_bin，split_rule="b2"，n_samples=9347
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=C|L2_x1=b3，level=2，parent_id=L1_group=C，split_name=L2_x1，split_type=numeric_bin，split_rule="b3"，n_samples=9427
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=C|L2_x1=b4，level=2，parent_id=L1_group=C，split_name=L2_x1，split_type=numeric_bin，split_rule="b4"，n_samples=9340
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=C|L2_x1=b5，level=2，parent_id=L1_group=C，split_name=L2_x1，split_type=numeric_bin，split_rule="b5"，n_samples=7434
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=D|L2_x1=b1，level=2，parent_id=L1_group=D，split_name=L2_x1，split_type=numeric_bin，split_rule="b1"，n_samples=4511
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=D|L2_x1=b2，level=2，parent_id=L1_group=D，split_name=L2_x1，split_type=numeric_bin，split_rule="b2"，n_samples=9231
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=D|L2_x1=b3，level=2，parent_id=L1_group=D，split_name=L2_x1，split_type=numeric_bin，split_rule="b3"，n_samples=9396
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=D|L2_x1=b4，level=2，parent_id=L1_group=D，split_name=L2_x1，split_type=numeric_bin，split_rule="b4"，n_samples=9598
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=D|L2_x1=b5，level=2，parent_id=L1_group=D，split_name=L2_x1，split_type=numeric_bin，split_rule="b5"，n_samples=7279
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b1|L3_x2=b1，level=3，parent_id=L1_group=A|L2_x1=b1，split_name=L3_x2，split_type=numeric_bin，split_rule="b1"，n_samples=662
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b1|L3_x2=b2，level=3，parent_id=L1_group=A|L2_x1=b1，split_name=L3_x2，split_type=numeric_bin，split_rule="b2"，n_samples=1236
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b1|L3_x2=b3，level=3，parent_id=L1_group=A|L2_x1=b1，split_name=L3_x2，split_type=numeric_bin，split_rule="b3"，n_samples=1069
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b1|L3_x2=b4，level=3，parent_id=L1_group=A|L2_x1=b1，split_name=L3_x2，split_type=numeric_bin，split_rule="b4"，n_samples=868
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b1|L3_x2=b5，level=3，parent_id=L1_group=A|L2_x1=b1，split_name=L3_x2，split_type=numeric_bin，split_rule="b5"，n_samples=743
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b2|L3_x2=b1，level=3，parent_id=L1_group=A|L2_x1=b2，split_name=L3_x2，split_type=numeric_bin，split_rule="b1"，n_samples=1402
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b2|L3_x2=b2，level=3，parent_id=L1_group=A|L2_x1=b2，split_name=L3_x2，split_type=numeric_bin，split_rule="b2"，n_samples=2425
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b2|L3_x2=b3，level=3，parent_id=L1_group=A|L2_x1=b2，split_name=L3_x2，split_type=numeric_bin，split_rule="b3"，n_samples=2146
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b2|L3_x2=b4，level=3，parent_id=L1_group=A|L2_x1=b2，split_name=L3_x2，split_type=numeric_bin，split_rule="b4"，n_samples=1680
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b2|L3_x2=b5，level=3，parent_id=L1_group=A|L2_x1=b2，split_name=L3_x2，split_type=numeric_bin，split_rule="b5"，n_samples=1445
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b3|L3_x2=b1，level=3，parent_id=L1_group=A|L2_x1=b3，split_name=L3_x2，split_type=numeric_bin，split_rule="b1"，n_samples=1460
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b3|L3_x2=b2，level=3，parent_id=L1_group=A|L2_x1=b3，split_name=L3_x2，split_type=numeric_bin，split_rule="b2"，n_samples=2513
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b3|L3_x2=b3，level=3，parent_id=L1_group=A|L2_x1=b3，split_name=L3_x2，split_type=numeric_bin，split_rule="b3"，n_samples=2171
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b3|L3_x2=b4，level=3，parent_id=L1_group=A|L2_x1=b3，split_name=L3_x2，split_type=numeric_bin，split_rule="b4"，n_samples=1750
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b3|L3_x2=b5，level=3，parent_id=L1_group=A|L2_x1=b3，split_name=L3_x2，split_type=numeric_bin，split_rule="b5"，n_samples=1444
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b4|L3_x2=b1，level=3，parent_id=L1_group=A|L2_x1=b4，split_name=L3_x2，split_type=numeric_bin，split_rule="b1"，n_samples=1525
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b4|L3_x2=b2，level=3，parent_id=L1_group=A|L2_x1=b4，split_name=L3_x2，split_type=numeric_bin，split_rule="b2"，n_samples=2492
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b4|L3_x2=b3，level=3，parent_id=L1_group=A|L2_x1=b4，split_name=L3_x2，split_type=numeric_bin，split_rule="b3"，n_samples=2261
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b4|L3_x2=b4，level=3，parent_id=L1_group=A|L2_x1=b4，split_name=L3_x2，split_type=numeric_bin，split_rule="b4"，n_samples=1764
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b4|L3_x2=b5，level=3，parent_id=L1_group=A|L2_x1=b4，split_name=L3_x2，split_type=numeric_bin，split_rule="b5"，n_samples=1498
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b5|L3_x2=b1，level=3，parent_id=L1_group=A|L2_x1=b5，split_name=L3_x2，split_type=numeric_bin，split_rule="b1"，n_samples=1159
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b5|L3_x2=b2，level=3，parent_id=L1_group=A|L2_x1=b5，split_name=L3_x2，split_type=numeric_bin，split_rule="b2"，n_samples=1926
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b5|L3_x2=b3，level=3，parent_id=L1_group=A|L2_x1=b5，split_name=L3_x2，split_type=numeric_bin，split_rule="b3"，n_samples=1646
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b5|L3_x2=b4，level=3，parent_id=L1_group=A|L2_x1=b5，split_name=L3_x2，split_type=numeric_bin，split_rule="b4"，n_samples=1386
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b5|L3_x2=b5，level=3，parent_id=L1_group=A|L2_x1=b5，split_name=L3_x2，split_type=numeric_bin，split_rule="b5"，n_samples=1203
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=B|L2_x1=b1|L3_x2=b1，level=3，parent_id=L1_group=B|L2_x1=b1，split_name=L3_x2，split_type=numeric_bin，split_rule="b1"，n_samples=735
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=B|L2_x1=b1|L3_x2=b2，level=3，parent_id=L1_group=B|L2_x1=b1，split_name=L3_x2，split_type=numeric_bin，split_rule="b2"，n_samples=1246
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=B|L2_x1=b1|L3_x2=b3，level=3，parent_id=L1_group=B|L2_x1=b1，split_name=L3_x2，split_type=numeric_bin，split_rule="b3"，n_samples=1135
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=B|L2_x1=b1|L3_x2=b4，level=3，parent_id=L1_group=B|L2_x1=b1，split_name=L3_x2，split_type=numeric_bin，split_rule="b4"，n_samples=834
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=B|L2_x1=b1|L3_x2=b5，level=3，parent_id=L1_group=B|L2_x1=b1，split_name=L3_x2，split_type=numeric_bin，split_rule="b5"，n_samples=800
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=B|L2_x1=b2|L3_x2=b1，level=3，parent_id=L1_group=B|L2_x1=b2，split_name=L3_x2，split_type=numeric_bin，split_rule="b1"，n_samples=1530
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=B|L2_x1=b2|L3_x2=b2，level=3，parent_id=L1_group=B|L2_x1=b2，split_name=L3_x2，split_type=numeric_bin，split_rule="b2"，n_samples=2403
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=B|L2_x1=b2|L3_x2=b3，level=3，parent_id=L1_group=B|L2_x1=b2，split_name=L3_x2，split_type=numeric_bin，split_rule="b3"，n_samples=2179
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=B|L2_x1=b2|L3_x2=b4，level=3，parent_id=L1_group=B|L2_x1=b2，split_name=L3_x2，split_type=numeric_bin，split_rule="b4"，n_samples=1725
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=B|L2_x1=b2|L3_x2=b5，level=3，parent_id=L1_group=B|L2_x1=b2，split_name=L3_x2，split_type=numeric_bin，split_rule="b5"，n_samples=1449
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=B|L2_x1=b3|L3_x2=b1，level=3，parent_id=L1_group=B|L2_x1=b3，split_name=L3_x2，split_type=numeric_bin，split_rule="b1"，n_samples=1466
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=B|L2_x1=b3|L3_x2=b2，level=3，parent_id=L1_group=B|L2_x1=b3，split_name=L3_x2，split_type=numeric_bin，split_rule="b2"，n_samples=2436
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=B|L2_x1=b3|L3_x2=b3，level=3，parent_id=L1_group=B|L2_x1=b3，split_name=L3_x2，split_type=numeric_bin，split_rule="b3"，n_samples=2178
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=B|L2_x1=b3|L3_x2=b4，level=3，parent_id=L1_group=B|L2_x1=b3，split_name=L3_x2，split_type=numeric_bin，split_rule="b4"，n_samples=1748
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=B|L2_x1=b3|L3_x2=b5，level=3，parent_id=L1_group=B|L2_x1=b3，split_name=L3_x2，split_type=numeric_bin，split_rule="b5"，n_samples=1449
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=B|L2_x1=b4|L3_x2=b1，level=3，parent_id=L1_group=B|L2_x1=b4，split_name=L3_x2，split_type=numeric_bin，split_rule="b1"，n_samples=1489
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=B|L2_x1=b4|L3_x2=b2，level=3，parent_id=L1_group=B|L2_x1=b4，split_name=L3_x2，split_type=numeric_bin，split_rule="b2"，n_samples=2365
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=B|L2_x1=b4|L3_x2=b3，level=3，parent_id=L1_group=B|L2_x1=b4，split_name=L3_x2，split_type=numeric_bin，split_rule="b3"，n_samples=2214
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=B|L2_x1=b4|L3_x2=b4，level=3，parent_id=L1_group=B|L2_x1=b4，split_name=L3_x2，split_type=numeric_bin，split_rule="b4"，n_samples=1771
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=B|L2_x1=b4|L3_x2=b5，level=3，parent_id=L1_group=B|L2_x1=b4，split_name=L3_x2，split_type=numeric_bin，split_rule="b5"，n_samples=1446
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=B|L2_x1=b5|L3_x2=b1，level=3，parent_id=L1_group=B|L2_x1=b5，split_name=L3_x2，split_type=numeric_bin，split_rule="b1"，n_samples=1161
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=B|L2_x1=b5|L3_x2=b2，level=3，parent_id=L1_group=B|L2_x1=b5，split_name=L3_x2，split_type=numeric_bin，split_rule="b2"，n_samples=1915
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=B|L2_x1=b5|L3_x2=b3，level=3，parent_id=L1_group=B|L2_x1=b5，split_name=L3_x2，split_type=numeric_bin，split_rule="b3"，n_samples=1760
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=B|L2_x1=b5|L3_x2=b4，level=3，parent_id=L1_group=B|L2_x1=b5，split_name=L3_x2，split_type=numeric_bin，split_rule="b4"，n_samples=1356
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=B|L2_x1=b5|L3_x2=b5，level=3，parent_id=L1_group=B|L2_x1=b5，split_name=L3_x2，split_type=numeric_bin，split_rule="b5"，n_samples=1198
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=C|L2_x1=b1|L3_x2=b1，level=3，parent_id=L1_group=C|L2_x1=b1，split_name=L3_x2，split_type=numeric_bin，split_rule="b1"，n_samples=717
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=C|L2_x1=b1|L3_x2=b2，level=3，parent_id=L1_group=C|L2_x1=b1，split_name=L3_x2，split_type=numeric_bin，split_rule="b2"，n_samples=1247
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=C|L2_x1=b1|L3_x2=b3，level=3，parent_id=L1_group=C|L2_x1=b1，split_name=L3_x2，split_type=numeric_bin，split_rule="b3"，n_samples=1110
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=C|L2_x1=b1|L3_x2=b4，level=3，parent_id=L1_group=C|L2_x1=b1，split_name=L3_x2，split_type=numeric_bin，split_rule="b4"，n_samples=798
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=C|L2_x1=b1|L3_x2=b5，level=3，parent_id=L1_group=C|L2_x1=b1，split_name=L3_x2，split_type=numeric_bin，split_rule="b5"，n_samples=703
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=C|L2_x1=b2|L3_x2=b1，level=3，parent_id=L1_group=C|L2_x1=b2，split_name=L3_x2，split_type=numeric_bin，split_rule="b1"，n_samples=1509
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=C|L2_x1=b2|L3_x2=b2，level=3，parent_id=L1_group=C|L2_x1=b2，split_name=L3_x2，split_type=numeric_bin，split_rule="b2"，n_samples=2419
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=C|L2_x1=b2|L3_x2=b3，level=3，parent_id=L1_group=C|L2_x1=b2，split_name=L3_x2，split_type=numeric_bin，split_rule="b3"，n_samples=2210
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=C|L2_x1=b2|L3_x2=b4，level=3，parent_id=L1_group=C|L2_x1=b2，split_name=L3_x2，split_type=numeric_bin，split_rule="b4"，n_samples=1736
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=C|L2_x1=b2|L3_x2=b5，level=3，parent_id=L1_group=C|L2_x1=b2，split_name=L3_x2，split_type=numeric_bin，split_rule="b5"，n_samples=1473
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=C|L2_x1=b3|L3_x2=b1，level=3，parent_id=L1_group=C|L2_x1=b3，split_name=L3_x2，split_type=numeric_bin，split_rule="b1"，n_samples=1481
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=C|L2_x1=b3|L3_x2=b2，level=3，parent_id=L1_group=C|L2_x1=b3，split_name=L3_x2，split_type=numeric_bin，split_rule="b2"，n_samples=2543
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=C|L2_x1=b3|L3_x2=b3，level=3，parent_id=L1_group=C|L2_x1=b3，split_name=L3_x2，split_type=numeric_bin，split_rule="b3"，n_samples=2158
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=C|L2_x1=b3|L3_x2=b4，level=3，parent_id=L1_group=C|L2_x1=b3，split_name=L3_x2，split_type=numeric_bin，split_rule="b4"，n_samples=1777
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=C|L2_x1=b3|L3_x2=b5，level=3，parent_id=L1_group=C|L2_x1=b3，split_name=L3_x2，split_type=numeric_bin，split_rule="b5"，n_samples=1468
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=C|L2_x1=b4|L3_x2=b1，level=3，parent_id=L1_group=C|L2_x1=b4，split_name=L3_x2，split_type=numeric_bin，split_rule="b1"，n_samples=1520
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=C|L2_x1=b4|L3_x2=b2，level=3，parent_id=L1_group=C|L2_x1=b4，split_name=L3_x2，split_type=numeric_bin，split_rule="b2"，n_samples=2386
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=C|L2_x1=b4|L3_x2=b3，level=3，parent_id=L1_group=C|L2_x1=b4，split_name=L3_x2，split_type=numeric_bin，split_rule="b3"，n_samples=2207
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=C|L2_x1=b4|L3_x2=b4，level=3，parent_id=L1_group=C|L2_x1=b4，split_name=L3_x2，split_type=numeric_bin，split_rule="b4"，n_samples=1712
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=C|L2_x1=b4|L3_x2=b5，level=3，parent_id=L1_group=C|L2_x1=b4，split_name=L3_x2，split_type=numeric_bin，split_rule="b5"，n_samples=1515
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=C|L2_x1=b5|L3_x2=b1，level=3，parent_id=L1_group=C|L2_x1=b5，split_name=L3_x2，split_type=numeric_bin，split_rule="b1"，n_samples=1166
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=C|L2_x1=b5|L3_x2=b2，level=3，parent_id=L1_group=C|L2_x1=b5，split_name=L3_x2，split_type=numeric_bin，split_rule="b2"，n_samples=1940
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=C|L2_x1=b5|L3_x2=b3，level=3，parent_id=L1_group=C|L2_x1=b5，split_name=L3_x2，split_type=numeric_bin，split_rule="b3"，n_samples=1817
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=C|L2_x1=b5|L3_x2=b4，level=3，parent_id=L1_group=C|L2_x1=b5，split_name=L3_x2，split_type=numeric_bin，split_rule="b4"，n_samples=1394
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=C|L2_x1=b5|L3_x2=b5，level=3，parent_id=L1_group=C|L2_x1=b5，split_name=L3_x2，split_type=numeric_bin，split_rule="b5"，n_samples=1117
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=D|L2_x1=b1|L3_x2=b1，level=3，parent_id=L1_group=D|L2_x1=b1，split_name=L3_x2，split_type=numeric_bin，split_rule="b1"，n_samples=720
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=D|L2_x1=b1|L3_x2=b2，level=3，parent_id=L1_group=D|L2_x1=b1，split_name=L3_x2，split_type=numeric_bin，split_rule="b2"，n_samples=1163
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=D|L2_x1=b1|L3_x2=b3，level=3，parent_id=L1_group=D|L2_x1=b1，split_name=L3_x2，split_type=numeric_bin，split_rule="b3"，n_samples=1035
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=D|L2_x1=b1|L3_x2=b4，level=3，parent_id=L1_group=D|L2_x1=b1，split_name=L3_x2，split_type=numeric_bin，split_rule="b4"，n_samples=836
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=D|L2_x1=b1|L3_x2=b5，level=3，parent_id=L1_group=D|L2_x1=b1，split_name=L3_x2，split_type=numeric_bin，split_rule="b5"，n_samples=757
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=D|L2_x1=b2|L3_x2=b1，level=3，parent_id=L1_group=D|L2_x1=b2，split_name=L3_x2，split_type=numeric_bin，split_rule="b1"，n_samples=1466
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=D|L2_x1=b2|L3_x2=b2，level=3，parent_id=L1_group=D|L2_x1=b2，split_name=L3_x2，split_type=numeric_bin，split_rule="b2"，n_samples=2351
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=D|L2_x1=b2|L3_x2=b3，level=3，parent_id=L1_group=D|L2_x1=b2，split_name=L3_x2，split_type=numeric_bin，split_rule="b3"，n_samples=2175
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=D|L2_x1=b2|L3_x2=b4，level=3，parent_id=L1_group=D|L2_x1=b2，split_name=L3_x2，split_type=numeric_bin，split_rule="b4"，n_samples=1721
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=D|L2_x1=b2|L3_x2=b5，level=3，parent_id=L1_group=D|L2_x1=b2，split_name=L3_x2，split_type=numeric_bin，split_rule="b5"，n_samples=1518
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=D|L2_x1=b3|L3_x2=b1，level=3，parent_id=L1_group=D|L2_x1=b3，split_name=L3_x2，split_type=numeric_bin，split_rule="b1"，n_samples=1406
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=D|L2_x1=b3|L3_x2=b2，level=3，parent_id=L1_group=D|L2_x1=b3，split_name=L3_x2，split_type=numeric_bin，split_rule="b2"，n_samples=2522
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=D|L2_x1=b3|L3_x2=b3，level=3，parent_id=L1_group=D|L2_x1=b3，split_name=L3_x2，split_type=numeric_bin，split_rule="b3"，n_samples=2159
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=D|L2_x1=b3|L3_x2=b4，level=3，parent_id=L1_group=D|L2_x1=b3，split_name=L3_x2，split_type=numeric_bin，split_rule="b4"，n_samples=1817
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=D|L2_x1=b3|L3_x2=b5，level=3，parent_id=L1_group=D|L2_x1=b3，split_name=L3_x2，split_type=numeric_bin，split_rule="b5"，n_samples=1492
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=D|L2_x1=b4|L3_x2=b1，level=3，parent_id=L1_group=D|L2_x1=b4，split_name=L3_x2，split_type=numeric_bin，split_rule="b1"，n_samples=1442
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=D|L2_x1=b4|L3_x2=b2，level=3，parent_id=L1_group=D|L2_x1=b4，split_name=L3_x2，split_type=numeric_bin，split_rule="b2"，n_samples=2566
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=D|L2_x1=b4|L3_x2=b3，level=3，parent_id=L1_group=D|L2_x1=b4，split_name=L3_x2，split_type=numeric_bin，split_rule="b3"，n_samples=2256
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=D|L2_x1=b4|L3_x2=b4，level=3，parent_id=L1_group=D|L2_x1=b4，split_name=L3_x2，split_type=numeric_bin，split_rule="b4"，n_samples=1819
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=D|L2_x1=b4|L3_x2=b5，level=3，parent_id=L1_group=D|L2_x1=b4，split_name=L3_x2，split_type=numeric_bin，split_rule="b5"，n_samples=1515
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=D|L2_x1=b5|L3_x2=b1，level=3，parent_id=L1_group=D|L2_x1=b5，split_name=L3_x2，split_type=numeric_bin，split_rule="b1"，n_samples=1190
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=D|L2_x1=b5|L3_x2=b2，level=3，parent_id=L1_group=D|L2_x1=b5，split_name=L3_x2，split_type=numeric_bin，split_rule="b2"，n_samples=1938
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=D|L2_x1=b5|L3_x2=b3，level=3，parent_id=L1_group=D|L2_x1=b5，split_name=L3_x2，split_type=numeric_bin，split_rule="b3"，n_samples=1631
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=D|L2_x1=b5|L3_x2=b4，level=3，parent_id=L1_group=D|L2_x1=b5，split_name=L3_x2，split_type=numeric_bin，split_rule="b4"，n_samples=1332
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=D|L2_x1=b5|L3_x2=b5，level=3，parent_id=L1_group=D|L2_x1=b5，split_name=L3_x2，split_type=numeric_bin，split_rule="b5"，n_samples=1188
# [INFO][BT][2025-12-16 19:07:44] 桶 bucket_id=L1_group=A|L2_x1=b1|L3_x2=b1 样本不足（n=662 < min_bucket_size=250），不再细分
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b1|L3_x2=b2|L4_x3=b2，level=4，parent_id=L1_group=A|L2_x1=b1|L3_x2=b2，split_name=L4_x3，split_type=numeric_bin，split_rule="b2"，n_samples=387
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b1|L3_x2=b2|L4_x3=b3，level=4，parent_id=L1_group=A|L2_x1=b1|L3_x2=b2，split_name=L4_x3，split_type=numeric_bin，split_rule="b3"，n_samples=319
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b1|L3_x2=b2|L4_x3=others，level=4，parent_id=L1_group=A|L2_x1=b1|L3_x2=b2，split_name=L4_x3，split_type=numeric_bin，split_rule="others"，n_samples=530
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b1|L3_x2=b3|L4_x3=b2，level=4，parent_id=L1_group=A|L2_x1=b1|L3_x2=b3，split_name=L4_x3，split_type=numeric_bin，split_rule="b2"，n_samples=322
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b1|L3_x2=b3|L4_x3=b3，level=4，parent_id=L1_group=A|L2_x1=b1|L3_x2=b3，split_name=L4_x3，split_type=numeric_bin，split_rule="b3"，n_samples=282
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b1|L3_x2=b3|L4_x3=others，level=4，parent_id=L1_group=A|L2_x1=b1|L3_x2=b3，split_name=L4_x3，split_type=numeric_bin，split_rule="others"，n_samples=465
# [INFO][BT][2025-12-16 19:07:44] 桶 bucket_id=L1_group=A|L2_x1=b1|L3_x2=b4 样本不足（n=868 < min_bucket_size=250），不再细分
# [INFO][BT][2025-12-16 19:07:44] 桶 bucket_id=L1_group=A|L2_x1=b1|L3_x2=b5 样本不足（n=743 < min_bucket_size=250），不再细分
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b2|L3_x2=b1|L4_x3=b2，level=4，parent_id=L1_group=A|L2_x1=b2|L3_x2=b1，split_name=L4_x3，split_type=numeric_bin，split_rule="b2"，n_samples=418
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b2|L3_x2=b1|L4_x3=b3，level=4，parent_id=L1_group=A|L2_x1=b2|L3_x2=b1，split_name=L4_x3，split_type=numeric_bin，split_rule="b3"，n_samples=381
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b2|L3_x2=b1|L4_x3=others，level=4，parent_id=L1_group=A|L2_x1=b2|L3_x2=b1，split_name=L4_x3，split_type=numeric_bin，split_rule="others"，n_samples=603
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b2|L3_x2=b2|L4_x3=b1，level=4，parent_id=L1_group=A|L2_x1=b2|L3_x2=b2，split_name=L4_x3，split_type=numeric_bin，split_rule="b1"，n_samples=369
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b2|L3_x2=b2|L4_x3=b2，level=4，parent_id=L1_group=A|L2_x1=b2|L3_x2=b2，split_name=L4_x3，split_type=numeric_bin，split_rule="b2"，n_samples=770
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b2|L3_x2=b2|L4_x3=b3，level=4，parent_id=L1_group=A|L2_x1=b2|L3_x2=b2，split_name=L4_x3，split_type=numeric_bin，split_rule="b3"，n_samples=632
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b2|L3_x2=b2|L4_x3=b4，level=4，parent_id=L1_group=A|L2_x1=b2|L3_x2=b2，split_name=L4_x3，split_type=numeric_bin，split_rule="b4"，n_samples=382
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b2|L3_x2=b2|L4_x3=b5，level=4，parent_id=L1_group=A|L2_x1=b2|L3_x2=b2，split_name=L4_x3，split_type=numeric_bin，split_rule="b5"，n_samples=272
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b2|L3_x2=b3|L4_x3=b1，level=4，parent_id=L1_group=A|L2_x1=b2|L3_x2=b3，split_name=L4_x3，split_type=numeric_bin，split_rule="b1"，n_samples=347
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b2|L3_x2=b3|L4_x3=b2，level=4，parent_id=L1_group=A|L2_x1=b2|L3_x2=b3，split_name=L4_x3，split_type=numeric_bin，split_rule="b2"，n_samples=687
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b2|L3_x2=b3|L4_x3=b3，level=4，parent_id=L1_group=A|L2_x1=b2|L3_x2=b3，split_name=L4_x3，split_type=numeric_bin，split_rule="b3"，n_samples=533
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b2|L3_x2=b3|L4_x3=b4，level=4，parent_id=L1_group=A|L2_x1=b2|L3_x2=b3，split_name=L4_x3，split_type=numeric_bin，split_rule="b4"，n_samples=347
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b2|L3_x2=b3|L4_x3=others，level=4，parent_id=L1_group=A|L2_x1=b2|L3_x2=b3，split_name=L4_x3，split_type=numeric_bin，split_rule="others"，n_samples=232
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b2|L3_x2=b4|L4_x3=b1，level=4，parent_id=L1_group=A|L2_x1=b2|L3_x2=b4，split_name=L4_x3，split_type=numeric_bin，split_rule="b1"，n_samples=296
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b2|L3_x2=b4|L4_x3=b2，level=4，parent_id=L1_group=A|L2_x1=b2|L3_x2=b4，split_name=L4_x3，split_type=numeric_bin，split_rule="b2"，n_samples=466
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b2|L3_x2=b4|L4_x3=b3，level=4，parent_id=L1_group=A|L2_x1=b2|L3_x2=b4，split_name=L4_x3，split_type=numeric_bin，split_rule="b3"，n_samples=457
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b2|L3_x2=b4|L4_x3=b4，level=4，parent_id=L1_group=A|L2_x1=b2|L3_x2=b4，split_name=L4_x3，split_type=numeric_bin，split_rule="b4"，n_samples=267
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b2|L3_x2=b4|L4_x3=others，level=4，parent_id=L1_group=A|L2_x1=b2|L3_x2=b4，split_name=L4_x3，split_type=numeric_bin，split_rule="others"，n_samples=194
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b2|L3_x2=b5|L4_x3=b2，level=4，parent_id=L1_group=A|L2_x1=b2|L3_x2=b5，split_name=L4_x3，split_type=numeric_bin，split_rule="b2"，n_samples=448
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b2|L3_x2=b5|L4_x3=b3，level=4，parent_id=L1_group=A|L2_x1=b2|L3_x2=b5，split_name=L4_x3，split_type=numeric_bin，split_rule="b3"，n_samples=370
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b2|L3_x2=b5|L4_x3=others，level=4，parent_id=L1_group=A|L2_x1=b2|L3_x2=b5，split_name=L4_x3，split_type=numeric_bin，split_rule="others"，n_samples=627
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b3|L3_x2=b1|L4_x3=b2，level=4，parent_id=L1_group=A|L2_x1=b3|L3_x2=b1，split_name=L4_x3，split_type=numeric_bin，split_rule="b2"，n_samples=449
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b3|L3_x2=b1|L4_x3=b3，level=4，parent_id=L1_group=A|L2_x1=b3|L3_x2=b1，split_name=L4_x3，split_type=numeric_bin，split_rule="b3"，n_samples=364
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b3|L3_x2=b1|L4_x3=others，level=4，parent_id=L1_group=A|L2_x1=b3|L3_x2=b1，split_name=L4_x3，split_type=numeric_bin，split_rule="others"，n_samples=647
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b3|L3_x2=b2|L4_x3=b1，level=4，parent_id=L1_group=A|L2_x1=b3|L3_x2=b2，split_name=L4_x3，split_type=numeric_bin，split_rule="b1"，n_samples=405
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b3|L3_x2=b2|L4_x3=b2，level=4，parent_id=L1_group=A|L2_x1=b3|L3_x2=b2，split_name=L4_x3，split_type=numeric_bin，split_rule="b2"，n_samples=771
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b3|L3_x2=b2|L4_x3=b3，level=4，parent_id=L1_group=A|L2_x1=b3|L3_x2=b2，split_name=L4_x3，split_type=numeric_bin，split_rule="b3"，n_samples=668
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b3|L3_x2=b2|L4_x3=b4，level=4，parent_id=L1_group=A|L2_x1=b3|L3_x2=b2，split_name=L4_x3，split_type=numeric_bin，split_rule="b4"，n_samples=383
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b3|L3_x2=b2|L4_x3=b5，level=4，parent_id=L1_group=A|L2_x1=b3|L3_x2=b2，split_name=L4_x3，split_type=numeric_bin，split_rule="b5"，n_samples=286
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b3|L3_x2=b3|L4_x3=b1，level=4，parent_id=L1_group=A|L2_x1=b3|L3_x2=b3，split_name=L4_x3，split_type=numeric_bin，split_rule="b1"，n_samples=359
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b3|L3_x2=b3|L4_x3=b2，level=4，parent_id=L1_group=A|L2_x1=b3|L3_x2=b3，split_name=L4_x3，split_type=numeric_bin，split_rule="b2"，n_samples=645
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b3|L3_x2=b3|L4_x3=b3，level=4，parent_id=L1_group=A|L2_x1=b3|L3_x2=b3，split_name=L4_x3，split_type=numeric_bin，split_rule="b3"，n_samples=564
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b3|L3_x2=b3|L4_x3=b4，level=4，parent_id=L1_group=A|L2_x1=b3|L3_x2=b3，split_name=L4_x3，split_type=numeric_bin，split_rule="b4"，n_samples=354
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b3|L3_x2=b3|L4_x3=others，level=4，parent_id=L1_group=A|L2_x1=b3|L3_x2=b3，split_name=L4_x3，split_type=numeric_bin，split_rule="others"，n_samples=249
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b3|L3_x2=b4|L4_x3=b1，level=4，parent_id=L1_group=A|L2_x1=b3|L3_x2=b4，split_name=L4_x3，split_type=numeric_bin，split_rule="b1"，n_samples=280
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b3|L3_x2=b4|L4_x3=b2，level=4，parent_id=L1_group=A|L2_x1=b3|L3_x2=b4，split_name=L4_x3，split_type=numeric_bin，split_rule="b2"，n_samples=517
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b3|L3_x2=b4|L4_x3=b3，level=4，parent_id=L1_group=A|L2_x1=b3|L3_x2=b4，split_name=L4_x3，split_type=numeric_bin，split_rule="b3"，n_samples=471
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b3|L3_x2=b4|L4_x3=b4，level=4，parent_id=L1_group=A|L2_x1=b3|L3_x2=b4，split_name=L4_x3，split_type=numeric_bin，split_rule="b4"，n_samples=294
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b3|L3_x2=b4|L4_x3=others，level=4，parent_id=L1_group=A|L2_x1=b3|L3_x2=b4，split_name=L4_x3，split_type=numeric_bin，split_rule="others"，n_samples=188
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b3|L3_x2=b5|L4_x3=b2，level=4，parent_id=L1_group=A|L2_x1=b3|L3_x2=b5，split_name=L4_x3，split_type=numeric_bin，split_rule="b2"，n_samples=442
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b3|L3_x2=b5|L4_x3=b3，level=4，parent_id=L1_group=A|L2_x1=b3|L3_x2=b5，split_name=L4_x3，split_type=numeric_bin，split_rule="b3"，n_samples=366
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b3|L3_x2=b5|L4_x3=others，level=4，parent_id=L1_group=A|L2_x1=b3|L3_x2=b5，split_name=L4_x3，split_type=numeric_bin，split_rule="others"，n_samples=636
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b4|L3_x2=b1|L4_x3=b1，level=4，parent_id=L1_group=A|L2_x1=b4|L3_x2=b1，split_name=L4_x3，split_type=numeric_bin，split_rule="b1"，n_samples=258
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b4|L3_x2=b1|L4_x3=b2，level=4，parent_id=L1_group=A|L2_x1=b4|L3_x2=b1，split_name=L4_x3，split_type=numeric_bin，split_rule="b2"，n_samples=437
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b4|L3_x2=b1|L4_x3=b3，level=4，parent_id=L1_group=A|L2_x1=b4|L3_x2=b1，split_name=L4_x3，split_type=numeric_bin，split_rule="b3"，n_samples=415
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b4|L3_x2=b1|L4_x3=others，level=4，parent_id=L1_group=A|L2_x1=b4|L3_x2=b1，split_name=L4_x3，split_type=numeric_bin，split_rule="others"，n_samples=415
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b4|L3_x2=b2|L4_x3=b1，level=4，parent_id=L1_group=A|L2_x1=b4|L3_x2=b2，split_name=L4_x3，split_type=numeric_bin，split_rule="b1"，n_samples=380
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b4|L3_x2=b2|L4_x3=b2，level=4，parent_id=L1_group=A|L2_x1=b4|L3_x2=b2，split_name=L4_x3，split_type=numeric_bin，split_rule="b2"，n_samples=733
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b4|L3_x2=b2|L4_x3=b3，level=4，parent_id=L1_group=A|L2_x1=b4|L3_x2=b2，split_name=L4_x3，split_type=numeric_bin，split_rule="b3"，n_samples=685
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b4|L3_x2=b2|L4_x3=b4，level=4，parent_id=L1_group=A|L2_x1=b4|L3_x2=b2，split_name=L4_x3，split_type=numeric_bin，split_rule="b4"，n_samples=397
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b4|L3_x2=b2|L4_x3=b5，level=4，parent_id=L1_group=A|L2_x1=b4|L3_x2=b2，split_name=L4_x3，split_type=numeric_bin，split_rule="b5"，n_samples=297
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b4|L3_x2=b3|L4_x3=b1，level=4，parent_id=L1_group=A|L2_x1=b4|L3_x2=b3，split_name=L4_x3，split_type=numeric_bin，split_rule="b1"，n_samples=351
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b4|L3_x2=b3|L4_x3=b2，level=4，parent_id=L1_group=A|L2_x1=b4|L3_x2=b3，split_name=L4_x3，split_type=numeric_bin，split_rule="b2"，n_samples=686
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b4|L3_x2=b3|L4_x3=b3，level=4，parent_id=L1_group=A|L2_x1=b4|L3_x2=b3，split_name=L4_x3，split_type=numeric_bin，split_rule="b3"，n_samples=595
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b4|L3_x2=b3|L4_x3=b4，level=4，parent_id=L1_group=A|L2_x1=b4|L3_x2=b3，split_name=L4_x3，split_type=numeric_bin，split_rule="b4"，n_samples=343
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b4|L3_x2=b3|L4_x3=b5，level=4，parent_id=L1_group=A|L2_x1=b4|L3_x2=b3，split_name=L4_x3，split_type=numeric_bin，split_rule="b5"，n_samples=286
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b4|L3_x2=b4|L4_x3=b1，level=4，parent_id=L1_group=A|L2_x1=b4|L3_x2=b4，split_name=L4_x3，split_type=numeric_bin，split_rule="b1"，n_samples=302
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b4|L3_x2=b4|L4_x3=b2，level=4，parent_id=L1_group=A|L2_x1=b4|L3_x2=b4，split_name=L4_x3，split_type=numeric_bin，split_rule="b2"，n_samples=516
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b4|L3_x2=b4|L4_x3=b3，level=4，parent_id=L1_group=A|L2_x1=b4|L3_x2=b4，split_name=L4_x3，split_type=numeric_bin，split_rule="b3"，n_samples=436
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b4|L3_x2=b4|L4_x3=b4，level=4，parent_id=L1_group=A|L2_x1=b4|L3_x2=b4，split_name=L4_x3，split_type=numeric_bin，split_rule="b4"，n_samples=299
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b4|L3_x2=b4|L4_x3=others，level=4，parent_id=L1_group=A|L2_x1=b4|L3_x2=b4，split_name=L4_x3，split_type=numeric_bin，split_rule="others"，n_samples=211
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b4|L3_x2=b5|L4_x3=b2，level=4，parent_id=L1_group=A|L2_x1=b4|L3_x2=b5，split_name=L4_x3，split_type=numeric_bin，split_rule="b2"，n_samples=475
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b4|L3_x2=b5|L4_x3=b3，level=4，parent_id=L1_group=A|L2_x1=b4|L3_x2=b5，split_name=L4_x3，split_type=numeric_bin，split_rule="b3"，n_samples=379
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b4|L3_x2=b5|L4_x3=others，level=4，parent_id=L1_group=A|L2_x1=b4|L3_x2=b5，split_name=L4_x3，split_type=numeric_bin，split_rule="others"，n_samples=644
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b5|L3_x2=b1|L4_x3=b2，level=4，parent_id=L1_group=A|L2_x1=b5|L3_x2=b1，split_name=L4_x3，split_type=numeric_bin，split_rule="b2"，n_samples=337
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b5|L3_x2=b1|L4_x3=b3，level=4，parent_id=L1_group=A|L2_x1=b5|L3_x2=b1，split_name=L4_x3，split_type=numeric_bin，split_rule="b3"，n_samples=312
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b5|L3_x2=b1|L4_x3=others，level=4，parent_id=L1_group=A|L2_x1=b5|L3_x2=b1，split_name=L4_x3，split_type=numeric_bin，split_rule="others"，n_samples=510
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b5|L3_x2=b2|L4_x3=b1，level=4，parent_id=L1_group=A|L2_x1=b5|L3_x2=b2，split_name=L4_x3，split_type=numeric_bin，split_rule="b1"，n_samples=305
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b5|L3_x2=b2|L4_x3=b2，level=4，parent_id=L1_group=A|L2_x1=b5|L3_x2=b2，split_name=L4_x3，split_type=numeric_bin，split_rule="b2"，n_samples=569
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b5|L3_x2=b2|L4_x3=b3，level=4，parent_id=L1_group=A|L2_x1=b5|L3_x2=b2，split_name=L4_x3，split_type=numeric_bin，split_rule="b3"，n_samples=518
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b5|L3_x2=b2|L4_x3=b4，level=4，parent_id=L1_group=A|L2_x1=b5|L3_x2=b2，split_name=L4_x3，split_type=numeric_bin，split_rule="b4"，n_samples=309
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b5|L3_x2=b2|L4_x3=others，level=4，parent_id=L1_group=A|L2_x1=b5|L3_x2=b2，split_name=L4_x3，split_type=numeric_bin，split_rule="others"，n_samples=225
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b5|L3_x2=b3|L4_x3=b1，level=4，parent_id=L1_group=A|L2_x1=b5|L3_x2=b3，split_name=L4_x3，split_type=numeric_bin，split_rule="b1"，n_samples=279
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b5|L3_x2=b3|L4_x3=b2，level=4，parent_id=L1_group=A|L2_x1=b5|L3_x2=b3，split_name=L4_x3，split_type=numeric_bin，split_rule="b2"，n_samples=492
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b5|L3_x2=b3|L4_x3=b3，level=4，parent_id=L1_group=A|L2_x1=b5|L3_x2=b3，split_name=L4_x3，split_type=numeric_bin，split_rule="b3"，n_samples=445
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b5|L3_x2=b3|L4_x3=others，level=4，parent_id=L1_group=A|L2_x1=b5|L3_x2=b3，split_name=L4_x3，split_type=numeric_bin，split_rule="others"，n_samples=430
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b5|L3_x2=b4|L4_x3=b2，level=4，parent_id=L1_group=A|L2_x1=b5|L3_x2=b4，split_name=L4_x3，split_type=numeric_bin，split_rule="b2"，n_samples=414
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b5|L3_x2=b4|L4_x3=b3，level=4，parent_id=L1_group=A|L2_x1=b5|L3_x2=b4，split_name=L4_x3，split_type=numeric_bin，split_rule="b3"，n_samples=357
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b5|L3_x2=b4|L4_x3=others，level=4，parent_id=L1_group=A|L2_x1=b5|L3_x2=b4，split_name=L4_x3，split_type=numeric_bin，split_rule="others"，n_samples=615
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b5|L3_x2=b5|L4_x3=b2，level=4，parent_id=L1_group=A|L2_x1=b5|L3_x2=b5，split_name=L4_x3，split_type=numeric_bin，split_rule="b2"，n_samples=382
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b5|L3_x2=b5|L4_x3=b3，level=4，parent_id=L1_group=A|L2_x1=b5|L3_x2=b5，split_name=L4_x3，split_type=numeric_bin，split_rule="b3"，n_samples=326
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=A|L2_x1=b5|L3_x2=b5|L4_x3=others，level=4，parent_id=L1_group=A|L2_x1=b5|L3_x2=b5，split_name=L4_x3，split_type=numeric_bin，split_rule="others"，n_samples=495
# [INFO][BT][2025-12-16 19:07:44] 桶 bucket_id=L1_group=B|L2_x1=b1|L3_x2=b1 样本不足（n=735 < min_bucket_size=250），不再细分
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=B|L2_x1=b1|L3_x2=b2|L4_x3=b2，level=4，parent_id=L1_group=B|L2_x1=b1|L3_x2=b2，split_name=L4_x3，split_type=numeric_bin，split_rule="b2"，n_samples=372
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=B|L2_x1=b1|L3_x2=b2|L4_x3=b3，level=4，parent_id=L1_group=B|L2_x1=b1|L3_x2=b2，split_name=L4_x3，split_type=numeric_bin，split_rule="b3"，n_samples=345
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=B|L2_x1=b1|L3_x2=b2|L4_x3=others，level=4，parent_id=L1_group=B|L2_x1=b1|L3_x2=b2，split_name=L4_x3，split_type=numeric_bin，split_rule="others"，n_samples=529
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=B|L2_x1=b1|L3_x2=b3|L4_x3=b2，level=4，parent_id=L1_group=B|L2_x1=b1|L3_x2=b3，split_name=L4_x3，split_type=numeric_bin，split_rule="b2"，n_samples=361
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=B|L2_x1=b1|L3_x2=b3|L4_x3=b3，level=4，parent_id=L1_group=B|L2_x1=b1|L3_x2=b3，split_name=L4_x3，split_type=numeric_bin，split_rule="b3"，n_samples=292
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=B|L2_x1=b1|L3_x2=b3|L4_x3=others，level=4，parent_id=L1_group=B|L2_x1=b1|L3_x2=b3，split_name=L4_x3，split_type=numeric_bin，split_rule="others"，n_samples=482
# [INFO][BT][2025-12-16 19:07:44] 桶 bucket_id=L1_group=B|L2_x1=b1|L3_x2=b4 样本不足（n=834 < min_bucket_size=250），不再细分
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=B|L2_x1=b1|L3_x2=b5|L4_x3=b2，level=4，parent_id=L1_group=B|L2_x1=b1|L3_x2=b5，split_name=L4_x3，split_type=numeric_bin，split_rule="b2"，n_samples=256
# [INFO][BT][2025-12-16 19:07:44] 创建桶 bucket_id=L1_group=B|L2_x1=b1|L3_x2=b5|L4_x3=others，level=4，parent_id=L1_group=B|L2_x1=b1|L3_x2=b5，split_name=L4_x3，split_type=numeric_bin，split_rule="others"，n_samples=544
# ...
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=B: BAC=0.7599, Regret=0.2840, Precision=0.6849, Recall=0.5913
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=D|L2_x1=b1|L3_x2=b1: BAC=0.6946, Regret=0.3383, Precision=0.4146, Recall=0.5312
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=D|L2_x1=b1: BAC=0.7154, Regret=0.4105, Precision=0.6140, Recall=0.5530
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=C|L2_x1=b5|L3_x2=b3: BAC=0.7186, Regret=0.4050, Precision=0.5563, Recall=0.6512
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=A|L2_x1=b5|L3_x2=b3: BAC=0.6343, Regret=0.3429, Precision=0.6562, Recall=0.3000
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=A|L2_x1=b5: BAC=0.7689, Regret=0.3025, Precision=0.7371, Recall=0.6124
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=B|L2_x1=b4|L3_x2=b3: BAC=0.6837, Regret=0.3927, Precision=0.6500, Recall=0.4483
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=B|L2_x1=b4: BAC=0.7739, Regret=0.3152, Precision=0.6803, Recall=0.6567
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=B|L2_x1=b4|L3_x2=b4: BAC=0.7662, Regret=0.3803, Precision=0.6294, Recall=0.7702
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=B|L2_x1=b2|L3_x2=b3: BAC=0.5978, Regret=0.3011, Precision=0.4848, Recall=0.2319
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=C|L2_x1=b1|L3_x2=b1: BAC=0.5144, Regret=0.3131, Precision=0.0870, Recall=0.1429
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=C|L2_x1=b1: BAC=0.6084, Regret=0.3475, Precision=0.4352, Recall=0.2798
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=D|L2_x1=b2|L3_x2=b2: BAC=0.7490, Regret=0.4225, Precision=0.6789, Recall=0.6615
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=D|L2_x1=b2: BAC=0.7162, Regret=0.4074, Precision=0.5832, Recall=0.5945
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=C|L2_x1=b3|L3_x2=b4: BAC=0.6243, Regret=0.3582, Precision=0.5897, Recall=0.2911
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=C|L2_x1=b3: BAC=0.7439, Regret=0.3788, Precision=0.6800, Recall=0.6063
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=A|L2_x1=b4|L3_x2=b1: BAC=0.5304, Regret=0.1176, Precision=0.2000, Recall=0.0714
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=A|L2_x1=b4: BAC=0.6817, Regret=0.2815, Precision=0.6017, Recall=0.4108
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=B|L2_x1=b3|L3_x2=b5: BAC=0.7398, Regret=0.4135, Precision=0.7229, Recall=0.6897
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=B|L2_x1=b3: BAC=0.7070, Regret=0.3090, Precision=0.6210, Recall=0.4819
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=A|L2_x1=b1|L3_x2=b2: BAC=0.4983, Regret=0.1573, Precision=0.0000, Recall=0.0000
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=A|L2_x1=b1: BAC=0.4943, Regret=0.1797, Precision=0.0000, Recall=0.0000
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=D|L2_x1=b1|L3_x2=b3: BAC=0.6577, Regret=0.5519, Precision=0.6545, Recall=0.4186
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=D|L2_x1=b1|L3_x2=b2: BAC=0.7394, Regret=0.3559, Precision=0.5965, Recall=0.5763
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=B|L2_x1=b2|L3_x2=b5: BAC=0.6699, Regret=0.3006, Precision=0.5435, Recall=0.4098
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=D|L2_x1=b5|L3_x2=b1: BAC=0.5000, Regret=0.1082, Precision=0.8918, Recall=1.0000
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=D|L2_x1=b5: BAC=0.7960, Regret=0.2770, Precision=0.7796, Recall=0.9089
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=B|L2_x1=b4|L3_x2=b5: BAC=0.6874, Regret=0.3420, Precision=0.7390, Recall=0.8894
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=C|L2_x1=b2|L3_x2=b3: BAC=0.6213, Regret=0.3711, Precision=0.4769, Recall=0.3100
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=C|L2_x1=b2: BAC=0.6640, Regret=0.3537, Precision=0.5859, Recall=0.3901
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=A|L2_x1=b4|L3_x2=b4: BAC=0.6675, Regret=0.3787, Precision=0.4861, Recall=0.4375
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=D|L2_x1=b4|L3_x2=b5: BAC=0.6701, Regret=0.2540, Precision=0.3659, Recall=0.4167
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=C|L2_x1=b3|L3_x2=b5: BAC=0.6024, Regret=0.2572, Precision=0.6429, Recall=0.2195
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=A|L2_x1=b1|L3_x2=b4: BAC=0.4928, Regret=0.1315, Precision=0.0000, Recall=0.0000
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=D|L2_x1=b3|L3_x2=b2: BAC=0.6980, Regret=0.3948, Precision=0.6608, Recall=0.8976
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=D|L2_x1=b3: BAC=0.7651, Regret=0.3673, Precision=0.7052, Recall=0.8173
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=B|L2_x1=b5|L3_x2=b2: BAC=0.6517, Regret=0.3116, Precision=0.6136, Recall=0.3462
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=B|L2_x1=b5: BAC=0.8306, Regret=0.2768, Precision=0.7689, Recall=0.7948
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=B|L2_x1=b5|L3_x2=b4: BAC=0.7441, Regret=0.3172, Precision=0.7963, Recall=0.8776
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=C|L2_x1=b3|L3_x2=b1: BAC=0.7208, Regret=0.4331, Precision=0.6728, Recall=0.8295
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=D|L2_x1=b3|L3_x2=b1: BAC=0.6230, Regret=0.2486, Precision=0.7908, Recall=0.9772
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=D|L2_x1=b3|L3_x2=b5: BAC=0.7059, Regret=0.3721, Precision=0.5735, Recall=0.5065
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=C|L2_x1=b3|L3_x2=b3: BAC=0.7016, Regret=0.4306, Precision=0.6814, Recall=0.4968
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=A|L2_x1=b5|L3_x2=b1: BAC=0.5546, Regret=0.1855, Precision=0.1000, Recall=0.1429
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=D|L2_x1=b5|L3_x2=b3: BAC=0.7080, Regret=0.3804, Precision=0.6875, Recall=0.8779
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=D|L2_x1=b3|L3_x2=b4: BAC=0.6789, Regret=0.4438, Precision=0.6212, Recall=0.5256
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=B|L2_x1=b3|L3_x2=b3: BAC=0.6832, Regret=0.3034, Precision=0.5667, Recall=0.4250
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=D|L2_x1=b2|L3_x2=b4: BAC=0.5975, Regret=0.4173, Precision=0.3571, Recall=0.3571
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=B|L2_x1=b1|L3_x2=b4: BAC=0.6111, Regret=0.1797, Precision=0.3750, Recall=0.2500
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=B|L2_x1=b1: BAC=0.5628, Regret=0.2278, Precision=0.4643, Recall=0.1398
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=B|L2_x1=b3|L3_x2=b1: BAC=0.4973, Regret=0.0801, Precision=0.0000, Recall=0.0000
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=C|L2_x1=b5|L3_x2=b1: BAC=0.5345, Regret=0.0969, Precision=0.9059, Recall=1.0000
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=A|L2_x1=b4|L3_x2=b2: BAC=0.5419, Regret=0.2411, Precision=0.4545, Recall=0.0943
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=A|L2_x1=b3|L3_x2=b3: BAC=0.5778, Regret=0.2090, Precision=0.3684, Recall=0.1795
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=A|L2_x1=b3: BAC=0.6150, Regret=0.2313, Precision=0.4955, Recall=0.2570
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=A|L2_x1=b2|L3_x2=b4: BAC=0.5948, Regret=0.1573, Precision=0.5556, Recall=0.2000
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=C|L2_x1=b2|L3_x2=b1: BAC=0.7359, Regret=0.3585, Precision=0.6049, Recall=0.5833
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=C|L2_x1=b4|L3_x2=b3: BAC=0.7228, Regret=0.3832, Precision=0.5890, Recall=0.5931
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=A|L2_x1=b1|L3_x2=b3: BAC=0.4958, Regret=0.1554, Precision=0.0000, Recall=0.0000
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=B|L2_x1=b2|L3_x2=b2: BAC=0.6138, Regret=0.2109, Precision=0.5714, Recall=0.2449
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=D|L2_x1=b4|L3_x2=b2: BAC=0.6606, Regret=0.3118, Precision=0.7412, Recall=0.9326
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=A|L2_x1=b3|L3_x2=b2: BAC=0.5243, Regret=0.1779, Precision=0.3333, Recall=0.0556
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=B|L2_x1=b4|L3_x2=b2: BAC=0.6486, Regret=0.2647, Precision=0.5854, Recall=0.3288
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=A|L2_x1=b5|L3_x2=b2: BAC=0.6021, Regret=0.2307, Precision=0.4286, Recall=0.2308
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=D|L2_x1=b5|L3_x2=b2: BAC=0.5847, Regret=0.2220, Precision=0.8114, Recall=0.9675
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=C|L2_x1=b2|L3_x2=b5: BAC=0.6044, Regret=0.3722, Precision=0.7895, Recall=0.2206
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=A|L2_x1=b4|L3_x2=b3: BAC=0.6411, Regret=0.2455, Precision=0.5625, Recall=0.3103
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=C|L2_x1=b2|L3_x2=b4: BAC=0.6336, Regret=0.3243, Precision=0.5897, Recall=0.3108
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=A|L2_x1=b3|L3_x2=b5: BAC=0.6931, Regret=0.3165, Precision=0.6250, Recall=0.4412
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=C|L2_x1=b1|L3_x2=b5: BAC=0.6785, Regret=0.2922, Precision=0.6111, Recall=0.4074
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=C|L2_x1=b1|L3_x2=b3: BAC=0.6492, Regret=0.3515, Precision=0.6538, Recall=0.3400
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=C|L2_x1=b4|L3_x2=b4: BAC=0.6863, Regret=0.3853, Precision=0.6780, Recall=0.4301
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=C|L2_x1=b1|L3_x2=b4: BAC=0.5905, Regret=0.4239, Precision=0.6000, Recall=0.2195
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=B|L2_x1=b3|L3_x2=b4: BAC=0.6574, Regret=0.4210, Precision=0.5488, Recall=0.4245
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=B|L2_x1=b2|L3_x2=b1: BAC=0.5743, Regret=0.2018, Precision=0.8333, Recall=0.1515
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=C|L2_x1=b3|L3_x2=b2: BAC=0.7502, Regret=0.3917, Precision=0.7025, Recall=0.6800
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=B|L2_x1=b3|L3_x2=b2: BAC=0.5797, Regret=0.3083, Precision=0.4242, Recall=0.1944
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=A|L2_x1=b1|L3_x2=b5: BAC=0.4829, Regret=0.2514, Precision=0.0000, Recall=0.0000
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=D|L2_x1=b2|L3_x2=b5: BAC=0.6394, Regret=0.4254, Precision=0.4500, Recall=0.4235
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=D|L2_x1=b4|L3_x2=b3: BAC=0.7450, Regret=0.3585, Precision=0.7333, Recall=0.8295
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=B|L2_x1=b5|L3_x2=b5: BAC=0.6070, Regret=0.1690, Precision=0.8448, Recall=0.9957
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=D|L2_x1=b3|L3_x2=b3: BAC=0.7875, Regret=0.3459, Precision=0.7483, Recall=0.8199
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=D|L2_x1=b1|L3_x2=b5: BAC=0.7701, Regret=0.3624, Precision=0.7541, Recall=0.6765
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=B|L2_x1=b1|L3_x2=b5: BAC=0.5527, Regret=0.1722, Precision=0.2000, Recall=0.1250
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=A|L2_x1=b2|L3_x2=b3: BAC=0.6442, Regret=0.1204, Precision=0.6667, Recall=0.2963
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=A|L2_x1=b5|L3_x2=b5: BAC=0.6961, Regret=0.3268, Precision=0.8213, Recall=0.7944
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=B|L2_x1=b5|L3_x2=b3: BAC=0.7326, Regret=0.4021, Precision=0.6296, Recall=0.6296
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=A|L2_x1=b5|L3_x2=b4: BAC=0.7289, Regret=0.4294, Precision=0.7203, Recall=0.6204
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=B|L2_x1=b1|L3_x2=b2: BAC=0.5498, Regret=0.2644, Precision=0.7500, Recall=0.1034
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=D|L2_x1=b2|L3_x2=b3: BAC=0.7506, Regret=0.3726, Precision=0.5753, Recall=0.6614
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=A|L2_x1=b2|L3_x2=b5: BAC=0.6428, Regret=0.2416, Precision=0.4545, Recall=0.3226
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=A|L2_x1=b4|L3_x2=b5: BAC=0.7151, Regret=0.4539, Precision=0.7107, Recall=0.5811
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=B|L2_x1=b5|L3_x2=b1: BAC=0.5522, Regret=0.1055, Precision=0.3333, Recall=0.1111
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=C|L2_x1=b1|L3_x2=b2: BAC=0.5784, Regret=0.3473, Precision=0.3077, Recall=0.2222
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=A|L2_x1=b3|L3_x2=b1: BAC=0.4971, Regret=0.1439, Precision=0.0000, Recall=0.0000
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=C|L2_x1=b4|L3_x2=b5: BAC=0.6337, Regret=0.1879, Precision=0.3571, Recall=0.2941
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=A|L2_x1=b3|L3_x2=b4: BAC=0.6130, Regret=0.3389, Precision=0.4444, Recall=0.2857
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=B|L2_x1=b4|L3_x2=b1: BAC=0.5500, Regret=0.1840, Precision=1.0000, Recall=0.1000
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=C|L2_x1=b5|L3_x2=b4: BAC=0.7830, Regret=0.3118, Precision=0.5068, Recall=0.6852
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=C|L2_x1=b2|L3_x2=b2: BAC=0.6950, Regret=0.3425, Precision=0.6022, Recall=0.4667
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=D|L2_x1=b2|L3_x2=b1: BAC=0.7547, Regret=0.4025, Precision=0.6794, Recall=0.6953
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=B|L2_x1=b1|L3_x2=b3: BAC=0.5294, Regret=0.1618, Precision=0.3333, Recall=0.0667
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=D|L2_x1=b5|L3_x2=b4: BAC=0.7495, Regret=0.4138, Precision=0.6364, Recall=0.6562
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=D|L2_x1=b1|L3_x2=b4: BAC=0.7237, Regret=0.4151, Precision=0.5862, Recall=0.5965
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=D|L2_x1=b5|L3_x2=b5: BAC=0.6377, Regret=0.2472, Precision=0.3913, Recall=0.3333
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=B|L2_x1=b1|L3_x2=b1: BAC=0.5761, Regret=0.3870, Precision=0.6250, Recall=0.1724
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=A|L2_x1=b2|L3_x2=b1: BAC=0.5294, Regret=0.1455, Precision=1.0000, Recall=0.0588
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=D|L2_x1=b4|L3_x2=b4: BAC=0.7077, Regret=0.4275, Precision=0.6226, Recall=0.6188
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=A|L2_x1=b1|L3_x2=b1: BAC=0.5000, Regret=0.2407, Precision=0.0000, Recall=0.0000
# 【INFO】【2025-12-16 19:15:04】[BASELINE] 桶 L1_group=C|L2_x1=b4|L3_x2=b1: BAC=0.6393, Regret=0.2068, Precision=0.8257, Recall=0.9797
# 【INFO】【2025-12-16 19:15:04】[BASELINE] baseline_bucket_metrics.csv 写出完成
# 【INFO】【2025-12-16 19:15:04】[BASELINE] baseline 指标成功合并到 bucket_metrics_gain.csv
#           model  Precision_mean  Precision_std  Recall_mean  Recall_std  \
# 0         BTTWD        0.589161       0.003902     0.779273    0.005359
# 1        LogReg        0.523174       0.004491     0.693192    0.004472
# 2  RandomForest        0.601121       0.002090     0.778179    0.003758
# 3           KNN        0.467856       0.003497     0.735522    0.006312
# 4       XGBoost        0.623738       0.004028     0.767625    0.004069
#
#     F1_mean    F1_std  BAC_mean   BAC_std  AUC_mean  ...  MCC_mean   MCC_std  \
# 0  0.670993  0.002251  0.793877  0.001786  0.868271  ...  0.542862  0.003286
# 1  0.596300  0.004555  0.735274  0.003516  0.811006  ...  0.434423  0.006709
# 2  0.678284  0.002531  0.798107  0.002068  0.871166  ...  0.553529  0.003640
# 3  0.571919  0.004382  0.720357  0.003838  0.785755  ...  0.393377  0.006793
# 4  0.688238  0.003830  0.802219  0.002812  0.878252  ...  0.568449  0.005467
#
#    Kappa_mean  Kappa_std  BND_ratio_mean  BND_ratio_std  POS_Coverage_mean  \
# 0    0.532146   0.003546        0.118205       0.014392           0.275585
# 1    0.425750   0.006716        0.000000       0.000000                NaN
# 2    0.544300   0.003494        0.000000       0.000000                NaN
# 3    0.371830   0.006344        0.000000       0.000000                NaN
# 4    0.562427   0.005504        0.000000       0.000000                NaN
#
#    POS_Coverage_std  Regret_mean  Regret_std
# 0          0.005134     0.314587    0.002497
# 1               NaN     0.404465    0.005390
# 2               NaN     0.307950    0.003213
# 3               NaN     0.424735    0.005932
# 4               NaN     0.302315    0.004323
#
# [5 rows x 21 columns]
# 【INFO】【2025-12-16 19:15:04】【步骤6摘要】BTTWD 与基线的 k 折结果已生成并保存。

# %%
# 步骤7：桶级别分析
bucket_metrics_path = os.path.join(root_path, cfg['OUTPUT']['results_dir'], 'bucket_metrics.csv')
if os.path.exists(bucket_metrics_path):
    bucket_metrics_df = pd.read_csv(bucket_metrics_path)
    display(bucket_metrics_df.head())
    bucket_metrics_df.plot(x='bucket_id', y='pos_rate_all', kind='bar', figsize=(12,4), title='桶正类比例')
    plt.ylabel('正类比例')
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.savefig(fig_bucket, bbox_inches='tight')
    plt.close()
log_info('【步骤7摘要】桶级指标已整理，可用于局部化分析。')
# Out:
#     bucket_id layer parent_bucket_id  n_train  n_val  pos_rate_train  \
# 0        ROOT    L1              NaN    22398   9599        0.260202
# 1  L1_group=C    L1             ROOT     5603   2417        0.273782
# 2  L1_group=D    L1             ROOT     5627   2372        0.431491
# 3  L1_group=B    L1             ROOT     5591   2403        0.212127
# 4  L1_group=A    L1             ROOT     5570   2402        0.138600
#
#    pos_rate_val  alpha  beta  regret_val  ...  is_weak  \
# 0      0.260548    0.4   0.2    0.396500  ...    False
# 1      0.288788    0.4   0.2    0.376707  ...    False
# 2      0.413997    0.4   0.3    0.416948  ...    False
# 3      0.223887    0.4   0.2    0.315855  ...    False
# 4      0.119484    0.4   0.2    0.233139  ...    False
#
#    threshold_source_bucket  parent_with_threshold  n_test  pos_rate_test  \
# 0                     ROOT                    NaN     NaN            NaN
# 1               L1_group=C                    NaN     NaN            NaN
# 2               L1_group=D                    NaN     NaN            NaN
# 3               L1_group=B                    NaN     NaN            NaN
# 4               L1_group=A                    NaN     NaN            NaN
#
#    BND_ratio_test  POS_Coverage_test  regret_test  fold  pos_rate
# 0             NaN                NaN          NaN     1  0.260575
# 1             NaN                NaN          NaN     1  0.283827
# 2             NaN                NaN          NaN     1  0.424416
# 3             NaN                NaN          NaN     1  0.208438
# 4             NaN                NaN          NaN     1  0.125044
#
# [5 rows x 36 columns]
# 【INFO】【2025-12-16 19:15:24】【步骤7摘要】桶级指标已整理，可用于局部化分析。

# %%
# 步骤8：结果汇总
log_info('【步骤8】检查结果文件与图表。')
print(os.listdir(os.path.join(root_path, cfg['OUTPUT']['results_dir'])))
print(os.listdir(os.path.join(root_path, cfg['OUTPUT']['figs_dir'])))
log_info('【全部步骤完成】Adult 数据集上的 BT-TWD 可行性实验结束。')
# Out:
# 【INFO】【2025-12-16 19:15:24】【步骤8】检查结果文件与图表。
# ['baseline_bucket_metrics.csv', 'bucket_fallback_stats.csv', 'bucket_metrics.csv', 'bucket_metrics_gain.csv', 'bucket_thresholds.csv', 'bucket_thresholds_per_fold.csv', 'bucket_tree_structure.csv', 'metrics_kfold_per_fold.csv', 'metrics_kfold_summary.csv', 'metrics_overview.csv']
# ['bank_class_distribution.png', 'bucket_metrics_bar.png', 'class_distribution.png', 'metrics_compare.png']
# 【INFO】【2025-12-16 19:15:24】【全部步骤完成】Adult 数据集上的 BT-TWD 可行性实验结束。
